# %% [markdown]
# # NO Scattering Analysis — Notebook Documentation
#
# ## Purpose
# Analyze diatomic scattering trajectories on a graphite slab.
# Compute center-of-mass (COM) kinematics, rotational/vibrational energies, bond geometry, and outcome labels.
# Export per-frame metrics and a batch summary for all input files.
#
# ---
#
# ## Scope and Assumptions
# - **System:** Diatomic molecule, default `NO` (supports homonuclear like `O2`).
# - **Formats:** VASP `vasprun.xml` and text LAMMPS dumps (`.lammpstrj` / `.dump`). XYZ supported for positions.
# - **Velocities:** Uses stored velocities if present. Falls back to finite-difference if missing.
# - **Surface:** Graphite slab. Top reference plane estimated from top C layer.
#
# ---
#
# ## Inputs
# - Directory pattern:
#   `base_dir = "{Incidence}_{Temperature}K_{Energy}eV_vasp_files/"`
# - Files discovered by extension: `.xyz`, `.lammpstrj`, `.xml`, `OUTCAR`, `.dump`
# - Key user config (edit in the header cell):
#   - `incidence` (`'Normal'`), `temperature` (K), `energy` (eV string like `'01'`)
#   - `file_format` (`'VASP'` info only)
#   - `molecule` (`'NO'`, `'CO'`, `'O2'`, `'N2'`)
#   - `DETECTOR_A` (Å): height threshold to count as “scattered”
#   - `DIATOM_IDS` (tuple or `None`): force atom indices if known
#   - `N_MIN_FRAMES` (int): require sufficient frames before labeling scatter
#   - **LAMMPS helpers:** `SPECORDER`, `TIMESTEP_FS`, `DUMP_STRIDE`, `VEL_UNITS`
#
# ---
#
# ## Outputs
# Writes to `OUT_DIR = "{Incidence}_{Temperature}K_{Energy}eV_results"`:
#
# 1. **Per-trajectory CSV:** `<file>_metrics.csv`
#    Per-frame measurements with labeled “Start/Turn/End/Frame”.
# 2. **Batch summary:** `batch_summary.csv`
#    One line per trajectory with final-frame indicators.
#
# Old files are removed before writing.
#
# ---
#
# ## Dependencies
# - Python 3, NumPy, ASE
# - Optional: MDAnalysis (reads velocities from LAMMPS dumps), `tabulate` (prettified console tables)
#
# ```bash
# pip install numpy ase MDAnalysis tabulate

# %%
import os, sys, numpy as np
from math import sqrt
from ase.io import read
from ase.io.vasp import read_vasp_xml
from ase.data import atomic_masses, chemical_symbols
# Optional tabulate helper
sys.path.append(os.path.expanduser('~/bin/tabulate'))
try:
    from tabulate import tabulate
except Exception:
    tabulate = None

# %%
###########################################
# Units and constants
###########################################
# ========================================
# CONSTANTES CORRECTES (du code original)
# ========================================
# Conversions FROM atomic units
autoev   = 27.211383858491185
autofs   = 0.02418884326505      # a.u. time → fs
autoan   = 0.52917720859         # bohr → Å
autoamu  = 0.0005485799092659504
autoanf  = 21.876912541518593    # a.u. velocity → Å/fs

# Conversions TO atomic units
evtoau   = 0.03674932540
fstoau   = 41.341373336561364
antoau   = 1.8897261328856432
amutoau  = 1822.888485540950
anftoau  = 0.045710289242239875  # Å/fs → a.u. velocity

# %%
###########################################
# User config
###########################################

incidence   = 'Normal'
temperature = 100        # K
energy      = '18'       # eV
file_format = 'LAMMPS'     # 'LAMMPS'   # info only
molecule    = 'NO'       # e.g. 'NO','CO','O2','N2'
DETECTOR_A  = 7.0        # Å
DIATOM_IDS  = None      # e.g., (0,1)
N_MIN_FRAMES = 50   # require at least 50 frames before counting as scattered

# --- LAMMPS mapping and timing ---
SPECORDER   = ['N','O','C']  # type 1=N, 2=O, 3=C. Adjust to your dump.
TIMESTEP_FS = 1.0            # MD timestep in fs
DUMP_STRIDE = 1             # steps between dumped frames
DT_FS       = TIMESTEP_FS * DUMP_STRIDE  # finite-diff dt if no velocities
VEL_UNITS   = 'A_per_ps'     # 'A_per_fs' or 'A_per_ps'

#base_dir = f"{incidence}_{int(temperature)}K_{energy}eV_vasp_files/"
base_dir = f"TS5_results/AL1/{incidence}_{int(temperature)}K_{energy}eV/"

INPUT_FILES = [
    os.path.join(base_dir, f)
    for f in os.listdir(base_dir)
    if f.endswith(('.xyz', '.lammpstrj', '.xml', 'OUTCAR', '.dump'))
]
print(f"Found {len(INPUT_FILES)} input files. format={file_format}")
OUT_DIR = f"results/{incidence}_{temperature}K_{energy}eV_results"
os.makedirs(OUT_DIR, exist_ok=True)

# Define element composition from molecule string
molecule = molecule.strip().upper()
if len(molecule) == 2 and not molecule[1].isdigit():  # e.g. 'NO'
    elemA, elemB = molecule[0], molecule[1]
elif len(molecule) == 2 and molecule[1].isdigit():    # e.g. 'O2'
    elemA, elemB = molecule[0], molecule[0]
else:
    raise ValueError(f"Unsupported diatomic format: {molecule}")
print(f"Molecule: {elemA}-{elemB}")

mA_default = atomic_masses[chemical_symbols.index(elemA)]
mB_default = atomic_masses[chemical_symbols.index(elemB)]
print(f"Masses: {elemA}={mA_default:.4f} amu, {elemB}={mB_default:.4f} amu")
# Out:
# Found 1975 input files. format=LAMMPS
# Molecule: N-O
# Masses: N=14.0070 amu, O=15.9990 amu

# %%
###########################################
# Helpers  (PBC-aware, NO only outputs)
###########################################

def file_kind(path):
    n = os.path.basename(path).lower()
    if n.endswith('.lammpstrj') or n.endswith('.dump') or 'lammpstrj' in n:
        return 'lammps-dump-text'
        #return "LAMMPSDUMP"
    if n == 'outcar':
        return 'vasp-outcar'
    if n.endswith('.xml') or n == 'vasprun.xml':
        return 'vasp-xml'
    if n.endswith('.xyz'):
        return 'xyz'
    return 'auto'

def load_frames(path):
    """Return list[Atoms]. Uses ASE readers. Adds no extra arrays."""
    kind = file_kind(path)

    if kind == 'lammps-dump-text':
        frames = read(path, format='lammps-dump-text', index=":", specorder=SPECORDER)
        # Try to get velocities via MDAnalysis
        import MDAnalysis as mda
        u = mda.Universe(path, format="LAMMPSDUMP")
        n_frames = len(u.trajectory)
        n_atoms = u.atoms.n_atoms
        V = np.empty((n_frames, n_atoms, 3), dtype=np.float64) if u.trajectory.ts.has_velocities else None

        for i, ts in enumerate(u.trajectory):
            if V is not None:
                vel = u.atoms.velocities
                if vel is None:
                    if i == 0:
                        print("No velocities found; skipping velocity extraction.")
                    V = None
                else:
                    V[i] = vel
        for i, atoms in enumerate(frames):
            atoms.set_velocities(V[i])

    if kind == 'vasp-xml':
        frames = read(path, index=":")
    return frames if isinstance(frames, list) else [frames]



def get_velocities(at, vel_units='A_per_ps'):
    """
    Return per-atom velocities in Å/fs.

    Order of preference:
      1) ASE internal velocities (Atoms.get_velocities)
      2) vx,vy,vz arrays (LAMMPS, usually Å/ps)
      3) 'velocities' or 'velocity' arrays (Å/fs)
      4) 'momenta' (amu·Å/fs) divided by atomic masses
    """
    import numpy as np

        # static attribute to avoid re-printing
    if not hasattr(get_velocities, "_ase_vel_printed"):
        get_velocities._ase_vel_printed = False

    arr = at.arrays
    v = None

    # 1) ASE internal velocities
    try:
        v = at.get_velocities()
        if v is not None and np.any(v): # si v est pas "None" et different de 0
            if not get_velocities._ase_vel_printed:
                print("Using ASE internal velocities.")
                get_velocities._ase_vel_printed = True
                
            if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
                v = np.asarray(v, float) / 1000.0
            return np.asarray(v, float)
        else:
            if not get_velocities._ase_vel_printed:
                print("No ASE velocities found — choosing another method.")
                get_velocities._ase_vel_printed = True
    except Exception:
        if not get_velocities._ase_vel_printed:
            print("No ASE velocities found — choosing another method.")
            get_velocities._ase_vel_printed = True

    # 2) explicit vx,vy,vz (LAMMPS)
    if all(k in arr for k in ('vx', 'vy', 'vz')):
        if not get_velocities._ase_vel_printed:
            print("Using 'vx','vy','vz' arrays.")
            get_velocities._ase_vel_printed = True
        v = np.column_stack((arr['vx'], arr['vy'], arr['vz'])).astype(float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 3) velocities arrays (ASE)
    if 'velocities' in arr or 'velocity' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'velocities' or 'velocity' array.")
            get_velocities._ase_vel_printed = True
        v = np.asarray(arr.get('velocities', arr.get('velocity')), float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 4) momenta → velocities
    if 'momenta' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'momenta' array to compute velocities.")
            get_velocities._ase_vel_printed = True
        m = at.get_masses()[:, None]
        p = np.asarray(arr['momenta'], float)
        v = p / m
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    if not get_velocities._ase_vel_printed:
        print("No velocity data found in any source.")
        get_velocities._ase_vel_printed = True
        
    return None

def _mic(dr, cell, pbc):
    if cell is None or not np.any(pbc):
        return dr
    from ase.geometry import find_mic
    mic_dr, _ = find_mic(dr, cell=cell, pbc=pbc)
    return mic_dr

def finite_diff_vel(frames, dt_fs, vel_units='A_per_fs'):
    print("CAREFUL - using finite-difference velocities!")
    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()
    pos = [f.get_positions() for f in frames]
    v = [np.zeros_like(pos[0])]
    for k in range(1, len(frames)-1):
        dr = pos[k+1] - pos[k-1]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/(2.0*dt_fs))
    if len(frames) > 1:
        dr = pos[-1] - pos[-2]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/dt_fs)
    if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
        v /= 1000.
    return v

def _lz(at) -> float:
    # Works for non-orthorhombic too
    return float(np.linalg.norm(at.cell[2]))

def slab_reference_z(at, simple=False, top_tol=0.10, probe_z=None):
    """
    Reference z for a graphite slab.

    If probe_z is None:
        Original behavior (simple=True: mean near global zmax; else k=3 z-clustering).
    If probe_z is not None:
        Return the average z of C atoms within top_tol Å of the highest C layer
        that is *below or equal to* probe_z, using minimum-image wrapping on z.
        Excludes atoms 0 and 1.
    """
    pos = at.get_positions()
    Z   = at.get_atomic_numbers()

    Cidx = np.where(Z == 6)[0]
    Cidx = Cidx[(Cidx != 0) & (Cidx != 1)]
    if Cidx.size == 0:
        return float(np.percentile(pos[:, 2], 10))

    Cz = pos[Cidx, 2].astype(float)

    # ---- New path: reference layer below a probe, PBC-safe
    if probe_z is not None:
        pbc = at.get_pbc()
        Lz  = _lz(at)
        dz = Cz - float(probe_z)
        if pbc[2] and Lz > 0.0:
            dz -= np.rint(dz / Lz) * Lz  # minimum-image along z

        below = dz <= 0.0
        if not np.any(below):
            # Edge case: everything wrapped above. Shift once.
            dz -= Lz
            below = dz <= 0.0
            if not np.any(below):
                # Fallback: use classic top-of-C around global max
                zmax = float(Cz.max())
                band = Cz[Cz >= zmax - float(top_tol)]
                return float(band.mean() if band.size else zmax)

        dz_below = dz[below]
        z_ref = float(probe_z + np.max(dz_below))

        # Average a thin band for robustness
        Cz_unwrapped_below = probe_z + dz_below
        band = np.abs(Cz_unwrapped_below - z_ref) <= float(top_tol)
        return float(Cz_unwrapped_below[band].mean()) if np.any(band) else z_ref

    # ---- Old behavior unchanged below
    if Cz.size < 3:
        return float(Cz.mean())

    if simple:
        zmax = float(Cz.max())
        top = Cz[Cz >= zmax - float(top_tol)]
        return float(top.mean()) if top.size else zmax

    # k=3 clustering on z
    k = 3
    cent = np.percentile(Cz, [10, 50, 90]).astype(float)
    for _ in range(15):
        d = np.abs(Cz[:, None] - cent[None, :])
        lab = np.argmin(d, axis=1)
        new_cent = np.array([Cz[lab == i].mean() if np.any(lab == i) else cent[i] for i in range(k)])
        if np.allclose(new_cent, cent):
            break
        cent = new_cent
    top_cluster = int(np.argmax(cent))
    top_vals = Cz[lab == top_cluster]
    if top_vals.size == 0:
        top_vals = Cz[Cz >= np.percentile(Cz, 80)]
    return float(top_vals.mean() if top_vals.size else Cz.mean())

def pick_NO_indices(at, id_pair=(1, 2), type_pair=(1, 2), elem_pair=('N','O')):
    ids   = at.arrays.get('id')
    types = at.arrays.get('type')
    if ids is not None and id_pair is not None:
        wN = np.where(ids == id_pair[0])[0]
        wO = np.where(ids == id_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if types is not None and type_pair is not None:
        wN = np.where(types == type_pair[0])[0]
        wO = np.where(types == type_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if elem_pair is not None:
        sym = at.get_chemical_symbols()
        try:
            iN = next(i for i,s in enumerate(sym) if s == elem_pair[0])
            iO = next(i for i,s in enumerate(sym) if s == elem_pair[1])
            return (iN, iO)
        except StopIteration:
            pass
    return None

def com(masses, pos):
    M = np.sum(masses)
    return (pos * masses[:,None]).sum(0) / M

def safe_acos_deg(x):
    return np.degrees(np.arccos(np.clip(x, -1.0, 1.0)))

# %%
def diatomic_properties(Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, slab_z_ref,
                        detector_A=None, cell=None, pbc=None, De=None, a=None, re=None):
    # MIC bond in Å
    dAB = Bpos - Apos
    rAB_A = dAB if (cell is None or pbc is None) else _mic(dAB, cell, pbc)
    Bpos_contig = Apos + rAB_A

    # to a.u.
    qA, qB = Apos * antoau, Bpos_contig * antoau
    vA, vB = Avel * anftoau, Bvel * anftoau
    mA, mB = mA_amu * amutoau, mB_amu * amutoau

    # geometry + COM
    rAB  = qB - qA
    r    = np.linalg.norm(rAB) if np.any(rAB) else 1.0
    rhat = rAB / r
    M    = mA + mB
    Rcm  = (mA*qA + mB*qB) / M
    Vcm  = (mA*vA + mB*vB) / M

    # reduced motion
    mu    = (mA*mB) / M
    vrel  = vB - vA
    p_rel = mu * vrel
    p_par = float(np.dot(p_rel, rhat))
    #L_vec = np.cross(p_rel, rAB)
    L_vec = np.cross(rAB, p_rel)
    L2    = float(np.dot(L_vec, L_vec))

    # energies (a.u.)
    Ecm_au  = 0.5 * M * np.dot(Vcm, Vcm)
    Evib_au = 0.5 * (p_par**2) / mu
    Erot_au = 0.5 * L2 / (mu * r**2)

    # optional Morse (eV): r in Å here
    mol_Epot_eV = De * (1.0 - np.exp(-a * (r/antoau - re)))**2 if (De is not None and a is not None and re is not None) else 0.0
    #print(f"DEBUG: r={r/antoau:.4f} Å, Epot={mol_Epot_eV:.4f} eV")

    # back to lab
    com_A   = (Rcm / antoau).tolist()
    vcm_Af  = (Vcm / anftoau).tolist()  # <--- CORRECT : utiliser anftoau pour reconvertir
    d_NO1_A = r / antoau
    heightA = (Rcm / antoau)[2] - slab_z_ref

    # orientations
    def cart2sph(v):
        R = np.linalg.norm(v)
        if R == 0:
            return (0.0, 0.0, 0.0)
            #return None
        theta = np.degrees(np.arccos(np.clip(v[2]/R, -1.0, 1.0)))  # angle from +z
        phi   = np.degrees(np.arctan2(v[1], v[0])) % 360.0
        return (R, theta, phi)

    # match get_Params:
    # - NO1_theta/phi from O position relative to COM
    O_rel_cm = qB - Rcm
    _, NO1_theta_deg, NO1_phi_deg = cart2sph(O_rel_cm)

    # - *_a variants from the bond vector rAB
    NO1_theta_a = safe_acos_deg(rAB[2] / r)
    #NO1_phi_a   = np.degrees(np.arccos(np.clip(rAB[0] / np.linalg.norm([rAB[0], rAB[1], 0.0]), -1.0, 1.0))) if (rAB[0] or rAB[1]) else 0.0
    NO1_phi_a = float((np.degrees(np.arctan2(rAB[1], rAB[0])) + 360.0) % 360.0) if (rAB[0] or rAB[1]) else 0.0

    # velocity orientation from COM velocity
    _, vel_theta_deg, vel_phi_deg = cart2sph(Vcm)
    Vcm_norm = np.linalg.norm(Vcm)
    vel_theta_a = safe_acos_deg(Vcm[2] / Vcm_norm) if Vcm_norm > 0 else 0.0
    #vel_phi_a   = np.degrees(np.arccos(np.clip(Vcm[0] / np.linalg.norm([Vcm[0], Vcm[1], 0.0]), -1.0, 1.0))) if (Vcm[0] or Vcm[1]) else 0.0
    vel_phi_a = float((np.degrees(np.arctan2(Vcm[1], Vcm[0])) + 360.0) % 360.0) if (Vcm[0] or Vcm[1]) else 0.0

    # j from |L| (ħ=1 in a.u.)
    L_norm    = np.sqrt(L2)
    jrot_cont = 0.5 * (-1.0 + np.sqrt(1.0 + 4.0 * L_norm**2))
    jrot      = float(np.ceil(jrot_cont))

    # channel: 1 emitted, 0 adsorbed
    output_CH = 1 if (detector_A is not None and heightA >= detector_A) else 0

    return {
        'output'          : output_CH,
        'mol_massCenter'  : com_A,
        'mol_mCenter_vel' : vcm_Af,
        'mol_jrot'        : jrot,
        'NO1_theta'       : round(NO1_theta_deg, 2),   # O relative to COM
        'NO1_phi'         : round(NO1_phi_deg, 2),
        'NO1_theta_a'     : round(NO1_theta_a, 2),     # bond-based
        'NO1_phi_a'       : round(NO1_phi_a, 2),
        'd_NO1'           : round(d_NO1_A, 4),
        'd_mol_L3'        : round(heightA, 4),
        'mol_vel_theta'   : round(vel_theta_deg, 2),
        'mol_vel_phi'     : round(vel_phi_deg, 2),
        'mol_vel_theta_a' : round(vel_theta_a, 2),
        'mol_vel_phi_a'   : round(vel_phi_a, 2),
        'mol_Ekin'        : round(Ecm_au * autoev, 4),  # COM kinetic (Ecm)
        'mol_Epot'        : round(mol_Epot_eV, 4),
        'mol_Evib_cin'   : round(Evib_au * autoev, 4),
        'mol_Erot'       : round(Erot_au * autoev, 4),
        'mol_Evib_tot'   : round((Evib_au * autoev + mol_Epot_eV), 4)
    }

# %%
###########################################
# Load and analyze  (NO only, PBC-aware)
###########################################

summary_rows = []

for INPUT_FILE in INPUT_FILES:
    print(f"\nProcessing: {os.path.basename(INPUT_FILE)}")
    kind   = file_kind(INPUT_FILE)
    frames = load_frames(INPUT_FILE)
    print()

    if frames is None:
        print("Skip: no frames loaded.")
        continue
    
    if len(frames) < 2:
        print("Skip: need ≥2 frames.")
        continue

    # --- Identify NO atoms
    if DIATOM_IDS is not None:
        iA, iB = DIATOM_IDS
    else:
        ids = pick_NO_indices(frames[0], id_pair=(1,2), type_pair=(1,2), elem_pair=('N','O'))
        if ids is None:
            raise RuntimeError("NO atoms not found")
        iA, iB = ids

    sym = frames[0].get_chemical_symbols()
    print(f"Using diatomic atoms {iA},{iB} ({sym[iA]}-{sym[iB]})")

    # --- Masses (amu)
    mA_amu = mA_default
    mB_amu = mB_default

    # --- Velocities (Å/fs)
    vel_list, need_fd = [], []
    for k, at in enumerate(frames):
        v = get_velocities(at, vel_units=VEL_UNITS)
        bad = (v is None) or (not np.isfinite(v).all()) or np.allclose(v, 0.0)
        vel_list.append(None if bad else v)
        need_fd.append(bad)
    if any(need_fd):
        print("Computing finite-difference velocities for missing frames.")
        fd = finite_diff_vel(frames, DT_FS)
        for k, bad in enumerate(need_fd):
            if bad:
                vel_list[k] = fd[k]

    # --- Helper: probe_z = lower NO atom or COM
    def probe_z(at, use_min_atom=True):
        zA, zB = at.positions[iA, 2], at.positions[iB, 2]
        if use_min_atom:
            return float(min(zA, zB))
        masses = np.array([mA_amu, mB_amu], float)
        return float(com(masses, at.positions[[iA, iB]])[2])

    # --- Reference z for first frame (for reporting)
    zref0 = slab_reference_z(frames[0], top_tol=0.10, probe_z=probe_z(frames[0]))

    # --- Heights of probe over the slab (per frame)
    heights = []
    for at in frames:
        z_probe = probe_z(at, use_min_atom=True)
        zref_k  = slab_reference_z(at, top_tol=0.10, probe_z=z_probe)
        heights.append(max(0.0, z_probe - zref_k))
    heights  = np.array(heights, float)
    turn_idx = int(np.argmin(heights))

    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()

    # --- Optional Morse parameters for NO
    De, a, re = [7.645438936565258, 2.565143344509797, 1.17028471793808]

    # --- Frame-wise properties
    def props_at(k):
        at = frames[k]
        pos = at.get_positions()
        Apos, Bpos = pos[iA], pos[iB]
        Avel, Bvel = vel_list[k][iA], vel_list[k][iB]
        z_probe = probe_z(at, use_min_atom=True)
        zref_k  = slab_reference_z(at, top_tol=0.10, probe_z=z_probe)
        return diatomic_properties(
            Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, zref_k,
            detector_A=DETECTOR_A, cell=cell, pbc=pbc,
            De=De, a=a, re=re
        )

    props = [props_at(k) for k in range(len(frames))]
    pf = props[-1]

    # --- Scatter criterion
    far_enough = pf["d_mol_L3"] >= DETECTOR_A
    after_50frames = len(frames) > N_MIN_FRAMES
    outcome = 1 if (far_enough and after_50frames) else 0  # 1=scatter, 0=stick

    # --- Output headers
    header = [
        "state","t_idx","d_NO(Å)","COM_z-ztop(Å)","NO_theta(°)","NO_phi(°)",
        "Vcm_x(Å/fs)","Vcm_y(Å/fs)","Vcm_z(Å/fs)",
        "Vcm_theta(°)","Vcm_phi(°)",
        "Ecm(eV)","E_pot(eV)","Evib_cin(eV)","Evib_tot(eV)",
        "Erot(eV)","j_rot","output"
    ]

    # --- Row builder
    def row(label, idx, p):
        out_flag = 1 if (p["d_mol_L3"] >= DETECTOR_A and idx > N_MIN_FRAMES) else 0
        return [
            label, idx,
            round(p["d_NO1"],4), round(p["d_mol_L3"],3),
            round(p["NO1_theta"],2), round(p["NO1_phi"],2),
            round(p["mol_mCenter_vel"][0],5), round(p["mol_mCenter_vel"][1],5), round(p["mol_mCenter_vel"][2],5),
            round(p["mol_vel_theta"],2), round(p["mol_vel_phi"],2),
            round(p["mol_Ekin"],4), round(p["mol_Epot"],4),
            round(p["mol_Evib_cin"],4), round(p["mol_Evib_tot"],4), round(p["mol_Erot"],4),
            int(p["mol_jrot"]), out_flag
        ]

    rows_all = [
        row(
            "Start" if k == 0 else "Turn" if k == turn_idx else "End" if k == len(frames)-1 else "Frame",
            k, props[k]
        )
        for k in range(len(frames))
    ]
    rows_key = [rows_all[0], rows_all[turn_idx], rows_all[-1]]

    # --- Summary
    summary = [
        ["file", os.path.basename(INPUT_FILE)],
        ["molecule", f"{elemA}-{elemB}"],
        ["diatomic", f"{iA},{iB} ({sym[iA]}-{sym[iB]})"],
        ["detector_A", DETECTOR_A],
        ["graphite_zref_A", round(zref0,3)],
        ["outcome", "scattered(1)" if outcome == 1 else "stuck(0)"],
    ]

    if tabulate:
        print("\n== Summary ==")
        print(tabulate(summary, tablefmt="plain"))
        print("\n== Trajectory metrics (key frames) ==")
        print(tabulate(rows_key, headers=header, tablefmt="plain"))
    else:
        print(summary)
        print([header] + rows_key)

    # --- Write per-frame CSV
    base = os.path.splitext(os.path.basename(INPUT_FILE))[0]
    out_csv = os.path.join(OUT_DIR, f"{base}_metrics.csv")
    if os.path.exists(out_csv):
        os.remove(out_csv)
        print(f"Removed existing file: {out_csv}")

    np.savetxt(
        out_csv,
        np.array(rows_all, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(header),
        comments='',
        encoding='utf-8'
    )

    # --- Batch summary row
    summary_rows.append([
        base, f"{elemA}-{elemB}", f"{sym[iA]}-{sym[iB]}", DETECTOR_A, round(zref0,3),
        outcome,
        round(pf["d_mol_L3"],3), round(pf["mol_Ekin"],4), int(pf["mol_jrot"]),
        round(pf["d_NO1"],4), round(pf["mol_mCenter_vel"][2],5), round(pf["mol_vel_theta"],2),
        round(pf["mol_Evib_tot"],4)
    ])

# --- Batch summary file
if summary_rows:
    sum_csv = os.path.join(OUT_DIR, "batch_summary.csv")
    if os.path.exists(sum_csv):
        os.remove(sum_csv)
        print(f"Removed existing file: {sum_csv}")
    hdr = [
        "file","molecule","diatomic","detector_A","zref_A","outcome(1=scat,0=stick)",
        "final_COMheight_A","final_Ecm_eV","final_jrot","final_d(Å)",
        "final_Vcm_z(Å/fs)","final_Vcm_θ°","final_Evib_tot_eV"
    ]
    np.savetxt(
        sum_csv,
        np.array(summary_rows, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(hdr),
        comments='',
        encoding='utf-8'
    )
    print(f"\nWrote {len(summary_rows)} records to {sum_csv}")
# Out:
# Processing: nve_110.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
# Using ASE internal velocities.
#
# == Summary ==
# file             nve_110.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.191             7.126          58.33       179.25        0             -0             -0.03402          180           359.23     1.8          0.0205          0.0977          0.1182      0             1         0
# Turn         174     1.1399            1.85          104.83       167.56        0.0028         0.00109        0.00425           35.23         21.27     0.0421       0.0501          0.0819          0.132       0.1529       27         0
# End          750     1.1276            9.928         128.68       164.09        0.00177        0.00162        0.01463            9.32         42.45     0.3418       0.1023          0.0139          0.1162      0.0717       18         1
# Removed existing file: results/Normal_100K_18eV_results/nve_110_metrics.csv
#
# Processing: nve_1208.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1208.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1386            7.131          46.47       121.47        0             -0             -0.03402          180           302.11     1.8          0.055           0.0633          0.1183      0             1         0
# Turn         175     1.1808            1.831         105.53       129.04       -0.00231       -0.00093        0.00365           34.34        201.95     0.0304       0.0054          0.1032          0.1086      0.0605       17         0
# End          800     1.2189           10.47          134.41       129.36       -0.00205       -0.00074        0.01444            8.58        199.84     0.3318       0.1049          0.0179          0.1228      0.0504       16         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1208_metrics.csv
#
# Processing: nve_1722.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1722.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2093            7.129          53.35       219.35       -0             -0             -0.03402          180           223.25     1.8          0.0695          0.0486          0.1181      0             1         0
# Turn         154     1.1538            1.91           73.94       213.27        0.00206        0.00126       -0.01648          171.67         31.53     0.4312       0.0143          0.0652          0.0795      0.3048       38         0
# End          850     1.1414            9.994         140.06       296.4        -0.00323        0.00142        0.01258           15.67        156.2      0.2655       0.0453          0.0691          0.1144      0.0278       11         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1722_metrics.csv
#
# Processing: nve_921.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_921.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1861            7.1            98.02       154.62       -0              0             -0.03402          180           155.63     1.8          0.0121          0.1061          0.1182      0             1         0
# Turn         171     1.1496            1.866          86.05       149.31        0.00056       -0.00108        0.00374           18.02        297.48     0.0241       0.0227          0.0941          0.1167      0.0275       11         0
# End          850     1.1256           10.318         107.49       183.25       -0.00032       -0.00124        0.01316            5.57        255.75     0.272        0.1128          0.0042          0.117       0.0402       14         1
# Removed existing file: results/Normal_100K_18eV_results/nve_921_metrics.csv
#
# Processing: nve_326.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_326.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1583            7.133          43.15       183.39       -0             -0             -0.03402          180           183.51     1.8          0.0075          0.1107          0.1182      0             1         0
# Turn         153     1.1985            1.995          65.48       197.51       -0.00173        0.00202       -0.01347          168.82        130.61     0.293        0.0374          0.0865          0.1239      0.358        43         0
# End          750     1.2238           10.076         123.41       249.5        -0.00333       -0.00068        0.01502           12.73        191.59     0.3689       0.1257          0.0011          0.1268      0.0718       20         1
# Removed existing file: results/Normal_100K_18eV_results/nve_326_metrics.csv
#
# Processing: nve_1514.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1514.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1465            7.119          69.35        91.79        0             -0             -0.03402          180           271.83     1.8          0.0303          0.0879          0.1182      0             1         0
# Turn         154     1.1951            1.935          71.83        91.7        -0.00148        0.00185       -0.01296          169.64        128.6      0.2698       0.0292          0.0876          0.1167      0.0252       11         0
# End          750     1.1417           10.657          55.74       140.28       -0.00293        0.00185        0.01612           12.14        147.76     0.4229       0.0442          0.0747          0.1189      0.045        14         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1514_metrics.csv
#
# Processing: nve_867.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_867.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1939            7.086         119.23       150.92       -0              0             -0.03402          180           150.05     1.8          0.0265          0.0917          0.1182      0             1         0
# Turn         177     1.2193            2.014          58.56       151.71        0.00255        1e-05          0.00705           19.89          0.12     0.0873       0.1068          0.0077          0.1145      0.1423       27         0
# End          800     1.1426           10.152         123.61        93.98        0.00335       -0.00188        0.01386           15.49        330.71     0.3218       0.0415          0.0702          0.1117      0.0959       21         1
# Removed existing file: results/Normal_100K_18eV_results/nve_867_metrics.csv
#
# Processing: nve_1387.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1387.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1535            7.138          31.86       100.11       -0              0             -0.03402          180           100.41     1.8          0.0148          0.1034          0.1182      0             1         0
# Turn         154     1.201             2.083          33.74        87.53       -0.00203        0.00759       -0.00789          135.14        104.97     0.1929       0.0438          0.0064          0.0502      0.0205       10         0
# End          850     1.2063           10.436          19.21       182.59       -0.00011        0.01126        0.0129            41.12         90.58     0.4562       0.0594          0.0646          0.124       0.0345       13         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1387_metrics.csv
#
# Processing: nve_1664.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1664.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1249            7.095         105.19       219.04        0              0             -0.03402          180            37.61     1.8          0.1167          0.0014          0.1181      0             1         0
# Turn         172     1.2188            1.754          71.72       218.88        0.00323       -0.00217        0.00489           38.5         326.18     0.0607       0.1046          0               0.1046      0.0143        9         0
# End          700     1.1317           10.058          40.22       102.13        0.00489       -0.00098        0.01697           16.39        348.62     0.4863       0.0825          0.0015          0.084       0.0433       14         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1664_metrics.csv
#
# Processing: nve_44.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_44.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.898
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1521            7.062         139.25       213.74       -0             -0             -0.03402          180           214.75     1.8          0.0175          0.1007          0.1182      0             1         0
# Turn         194     1.2235            2.078          49.79       208.31       -0.00154        0.00084        0.01278            7.83        151.44     0.2587       0.1246          0.004           0.1286      0.3015       40         0
# End          650     1.1464           10.591          20.47       113.87       -0.00037       -0.00014        0.01953            1.15        200.55     0.5935       0.0306          0.0837          0.1144      0.1352       25         1
# Removed existing file: results/Normal_100K_18eV_results/nve_44_metrics.csv
#
# Processing: nve_1178.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1178.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.126             7.104          92.6        105.24        0             -0             -0.03402          180           287.07     1.8          0.1104          0.0078          0.1182      0             1         0
# Turn         174     1.2156            1.815          65.6        113.31        0.0005         0.00404        0.005             39.12         82.94     0.0646       0.0919          0.0459          0.1378      0.1243       26         0
# End          800     1.2204           10.369         106.86       182.62        0.00239        0.00408        0.01452           18.02         59.65     0.3624       0.1111          0.0155          0.1266      0.0768       20         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1178_metrics.csv
#
# Processing: nve_1452.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1452.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1314            7.128          53.16       314.83       -0              0             -0.03402          180           137.49     1.8          0.0842          0.034           0.1182      0             1         0
# Turn         155     1.2216            1.891          70.44       315.64       -0.00238       -0.00052       -0.01533          170.97        192.38     0.3746       0.1164          0.0526          0.1691      0.1369       27         0
# End          850     1.1971           10.013         111.57       268.86        0.0001        -0.00439        0.01267           19.13        271.24     0.2797       0.0338          0.0904          0.1242      0.0333       13         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1452_metrics.csv
#
# Processing: nve_1980.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1980.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2116            7.119          69.79       228.69       -0             -0             -0.03402          180           227.36     1.8          0.0773          0.0409          0.1181      0             1         0
# Turn         176     1.1894            1.841         100.4        211.83        0.00264        0.00212        0.00739           24.63         38.68     0.1027       0.0174          0.0817          0.0991      0.1144       24         0
# End          750     1.1759           10.136          60.47       139.99        0.00165        0.002          0.01502            9.8          50.4      0.3611       0.0015          0.1038          0.1053      0.0976       22         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1980_metrics.csv
#
# Processing: nve_1949.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1949.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.137             7.091         111.68       284.07       -0              0             -0.03402          180           100.56     1.8          0.0608          0.0575          0.1183      0             1         0
# Turn         190     1.2198            1.964          52.41       284.41        0.00041       -0.0024         0.00923           14.76        279.72     0.1416       0.1086          0.024           0.1326      0.2162       34         0
# End          700     1.1296           10.342          61.41       307.04       -0.00117       -0.00012        0.01742            3.88        185.94     0.474        0.0924          0.0187          0.1111      0.116        23         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1949_metrics.csv
#
# Processing: nve_783.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_783.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2005            7.088         115.24        65.42       -0             -0             -0.03402          180           246.68     1.8          0.0426          0.0756          0.1182      0             1         0
# Turn         180     1.1772            1.864          72.23        63.53        0.00045       -0.00275        0.00655           23.06        279.37     0.0788       0.0024          0.1008          0.1032      0.0811       20         0
# End          800     1.1694           10.536          85.99        12.51       -0.00076       -0.00269        0.01479           10.71        254.31     0.3524       0               0.1144          0.1144      0.0748       19         1
# Removed existing file: results/Normal_100K_18eV_results/nve_783_metrics.csv
#
# Processing: nve_260.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_260.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2172            7.1            98.02       131.94       -0              0             -0.03402          180           130.26     1.8          0.0982          0.02            0.1182      0             1         0
# Turn         171     1.1227            1.937          84.38       139.66        0.00345       -0.00016        0.00523           33.48        357.37     0.0611       0.1289          0.0016          0.1305      0.0601       16         0
# End          900     1.2133           10.128          85.01       230.41        0.0049        -1e-05          0.01182           22.52        359.91     0.2547       0.0833          0.0439          0.1272      0.0585       18         1
# Removed existing file: results/Normal_100K_18eV_results/nve_260_metrics.csv
#
# Processing: nve_1334.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1334.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1927            7.103          92.67        40.34       -0             -0             -0.03402          180           220.78     1.8          0.0238          0.0944          0.1182      0             1         0
# Turn         172     1.1636            1.821          73.22        48           0.00453        0.00067        0.00431           46.73          8.44     0.0614       0.0023          0.1069          0.1091      0.0908       21         0
# End          800     1.1658            9.906          52.99        19.52        0.00627        0.00027        0.01362           24.74          2.43     0.3494       0.001           0.1136          0.1146      0.0471       15         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1334_metrics.csv
#
# Processing: nve_506.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_506.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1572            7.106          88.92       234.58       -0             -0             -0.03402          180           235.81     1.8          0.0088          0.1094          0.1182      0             1         0
# Turn         173     1.2035            1.778          80.88       225.02        0.00258       -0.00055        0.0045            30.37        348.02     0.0423       0.0511          0.0656          0.1168      0.0434       15         0
# End          800     1.1756           10.192          97.98       193.02        0.00355       -0.00044        0.01424           14.09        352.89     0.3353       0.0014          0.1134          0.1149      0.0647       18         1
# Removed existing file: results/Normal_100K_18eV_results/nve_506_metrics.csv
#
# Processing: nve_1102.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1102.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1471            7.122          63.01       319.88       -0              0             -0.03402          180           142.11     1.8          0.0288          0.0894          0.1182      0             1         0
# Turn         152     1.2374            1.92           68.38       319.57       -0.00164       -0.00062       -0.01702          174.11        200.63     0.4554       0.1911          0.006           0.197       0.036        14         0
# End          950     1.1287           10.421          70.58       115.36        0.00061       -0.00462        0.01126           22.5         277.49     0.231        0.0967          0.0161          0.1128      0.0069        6         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1102_metrics.csv
#
# Processing: nve_1428.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1428.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1668            7.071         151.11       116.48       -0              0             -0.03402          180           115.84     1.8          0.0006          0.1176          0.1182      0             1         0
# Turn         151     1.1635            2.178         137.2        121.25       -0.00061       -0.00217       -0.00745          163.18        254.26     0.0941       0.0024          0.1206          0.123       0.2317       33         0
# End          850     1.2125           10.587          52.97       308.9        -0.00103       -0.00136        0.01312            7.42        232.81     0.2722       0.0806          0.0536          0.1342      0.5092       52         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1428_metrics.csv
#
# Processing: nve_1933.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1933.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1246            7.118          70.2        214.71        0              0             -0.03402          180            38.21     1.8          0.1182          0               0.1182      0             1         0
# Turn         169     1.2009            1.854          63.53       207.23       -0.00679       -0.0037         0.00489           57.69        208.57     0.1303       0.0436          0.0664          0.11        0.0253       11         0
# End          800     1.2221           10.062          53.3        225.27       -0.00773       -0.00335        0.01381           31.39        203.39     0.4069       0.1183          0.0003          0.1186      0.0458       16         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1933_metrics.csv
#
# Processing: nve_730.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_730.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.221             7.102          94.8          7.66        0              0             -0.03402          180             8.37     1.8          0.1136          0.0046          0.1182      0             1         0
# Turn         168     1.1549            1.796          97.42        11.53       -0.00664        0.00064        0.00319           64.48        174.46     0.085        0.0125          0.1048          0.1173      0.0201       10         0
# End          900     1.2217           10.153          77.2         57.55       -0.00723        0.00061        0.01169           31.84        175.21     0.2944       0.1165          0.0168          0.1334      0.0505       16         1
# Removed existing file: results/Normal_100K_18eV_results/nve_730_metrics.csv
#
# Processing: nve_489.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_489.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.221             7.127          57.61        79.5        -0             -0             -0.03402          180           258.78     1.8          0.1136          0.0046          0.1182      0             1         0
# Turn         186     1.189             1.956         118.92        69.92       -0.00029       -0.00205        0.00913           12.76        261.89     0.1361       0.0168          0.0908          0.1076      0.1472       27         0
# End          650     1.2134           10.574          58.91       199.37       -0.00017       -0.00261        0.01924            7.75        266.21     0.5861       0.0837          0.0351          0.1188      0.0352       14         1
# Removed existing file: results/Normal_100K_18eV_results/nve_489_metrics.csv
#
# Processing: nve_440.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_440.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.213             7.127          57.04       169.57       -0              0             -0.03402          180           169.82     1.8          0.0824          0.0357          0.1181      0             1         0
# Turn         156     1.1817            1.872          76.91       167.56        0.0009        -0.002         -0.01466          171.47        294.26     0.3417       0.0064          0.0948          0.1012      0.2439       35         0
# End          800     1.1264           10.346          65.67        91.07       -0.00118       -0.00011        0.01456            4.67        185.17     0.3317       0.1085          0.0013          0.1098      0.0895       20         1
# Removed existing file: results/Normal_100K_18eV_results/nve_440_metrics.csv
#
# Processing: nve_1791.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1791.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1621            7.108          86.46       325.24       -0              0             -0.03402          180           144.2      1.8          0.0034          0.1148          0.1182      0             1         0
# Turn         169     1.2248            1.868          97.22       317.17       -0.00624        0.00198        0.00424           57.08        162.43     0.0946       0.1301          0.0017          0.1319      0.0707       19         0
# End          850     1.2211           10.396          66.48       247.09       -0.00632        0.00149        0.01302           26.51        166.74     0.3294       0.1143          0.0013          0.1156      0.0647       19         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1791_metrics.csv
#
# Processing: nve_1272.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1272.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2102            7.103          93.68       263.92       -0             -0             -0.03402          180           264.09     1.8          0.0725          0.0457          0.1182      0             1         0
# Turn         168     1.143             1.777          83.72       269.6         0.00293        0.00358       -1e-05             90.13         50.76     0.0333       0.0403          0.0711          0.1114      0.037        13         0
# End          900     1.2207           10.182          75.44        16.32        0.00361        0.00429        0.01208           24.9          49.89     0.2757       0.1126          0.0195          0.1321      0.0617       18         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1272_metrics.csv
#
# Processing: nve_1758.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1758.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1797            7.119          68.95       178.52        0             -0             -0.03402          180           358.55     1.8          0.0044          0.1138          0.1182      0             1         0
# Turn         160     1.1392            1.921          75.29       169.11        4e-05         -0.00113       -0.00456          166.05        272.07     0.0343       0.0528          0.0352          0.088       0.1187       23         0
# End          850     1.2222           10.127          89.77         9.23       -0.00214        0.00079        0.01273           10.15        159.66     0.26         0.1187          0.0013          0.12        0.086        21         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1758_metrics.csv
#
# Processing: nve_992.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_992.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1293            7.142          13.16       293.19        0             -0             -0.03402          180           292.52     1.8          0.0942          0.0238          0.118       0             1         0
# Turn         156     1.2045            2.146          33.81       303.92        0.00074       -0.00114       -0.00622          167.65        302.84     0.063        0.0539          0.0516          0.1055      0.3534       43         0
# End          700     1.2165           10.469         124.54       132.86       -0.0004        -0.00129        0.01756            4.41        252.74     0.4822       0.0956          0.0545          0.1501      0.4382       48         1
# Removed existing file: results/Normal_100K_18eV_results/nve_992_metrics.csv
#
# Processing: nve_395.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_395.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2126            7.114          77.79       346.18        0             -0             -0.03402          180           347.28     1.8          0.0808          0.0373          0.1181      0             1         0
# Turn         169     1.1423            1.769          62.86       351.25        0.00548       -0.00304        0.0016            75.64        330.99     0.0651       0.0423          0.0594          0.1017      0.0274       11         0
# End          800     1.1252           10.34           63.82       339.16        0.0056        -0.00331        0.01461           24           329.46     0.3979       0.1151          0.0016          0.1168      0.0524       15         1
# Removed existing file: results/Normal_100K_18eV_results/nve_395_metrics.csv
#
# Processing: nve_676.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_676.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.217             7.137          38.33        46.62        0              0             -0.03402          180            48.21     1.8          0.0975          0.0208          0.1183      0             1         0
# Turn         155     1.1525            1.934          59.28        34.41        0.00025        0.00164       -0.01321          172.83         81.21     0.2758       0.0166          0.0821          0.0987      0.172        29         0
# End          800     1.1446           10.562          48.56       107.99        0.00565        0.0031         0.01476           23.57         28.73     0.4035       0.0355          0.0759          0.1113      0.0332       12         1
# Removed existing file: results/Normal_100K_18eV_results/nve_676_metrics.csv
#
# Processing: nve_1875.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1875.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.145             7.114          76.91       236.58        0              0             -0.03402          180            55.74     1.8          0.0343          0.0839          0.1182      0             1         0
# Turn         174     1.1875            1.831          96.41       220.27        0.00237        0.00398        0.00469           44.62         59.27     0.0676       0.0143          0.1038          0.1181      0.1329       26         0
# End          850     1.1862            9.917          80.34         5.27        0.00106        0.00427        0.0125            19.4          76.05     0.2729       0.0122          0.1056          0.1178      0.115        24         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1875_metrics.csv
#
# Processing: nve_1044.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1044.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1422            7.127          55.2        273.63        0             -0             -0.03402          180           273.93     1.8          0.0427          0.0756          0.1183      0             1         0
# Turn         154     1.2219            1.97           69.6        274.99        0.00067        0.0003        -0.01125          176.27         23.83     0.1975       0.1174          0.0251          0.1425      0.2701       38         0
# End          650     1.1266           10.467          58.37       307.26       -5e-05          0.00331        0.01904            9.87         90.91     0.5809       0.1074          0.0041          0.1115      0.0618       17         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1044_metrics.csv
#
# Processing: nve_1050.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1050.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2012            7.077         134.74       300.19        0             -0             -0.03402          180           298.13     1.8          0.0445          0.0736          0.1181      0             1         0
# Turn         195     1.2141            2.178          40.9        295.63       -0.00132       -0.00113        0.01223            8.08        220.44     0.2373       0.0865          0.0357          0.1222      0.1738       30         0
# End          650     1.1717           10.321         144.25        31.47        7e-05         -0.00031        0.01859            0.97        282.02     0.5376       0.0001          0.1181          0.1182      0.0398       14         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1050_metrics.csv
#
# Processing: nve_1099.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1099.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2134            7.101          95.82       244.66        0              0             -0.03402          180            63.63     1.8          0.0837          0.0345          0.1182      0             1         0
# Turn         182     1.2197            1.852          63.96       255.13       -0.00095       -0.00285        0.00813           20.29        251.62     0.1169       0.1085          0.0185          0.127       0.0971       23         0
# End          800     1.1669           10.572          96.08       322.13       -0.00108       -0.00201        0.0151             8.6         241.89     0.3625       0.0006          0.1196          0.1202      0.082        20         1
# Removed existing file: results/Normal_100K_18eV_results/nve_1099_metrics.csv
#
# Processing: nve_348.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_348.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1821            7.123          62.59       264.2          0             0             -0.03402          180            83.96     1.8          0.0068          0.1114          0.1182      0             1         0
# Turn         189     1.1991            2.051         122.93       270.21        -0.0004        0.00319        0.01039           17.2          97.13     0.184        0.0388          0.0841          0.1229      0.2021       32         0
# End          650     1.2098           10.296          46.3        229.26         1e-05         0.00333        0.01858           10.16         89.85     0.5539       0.0709          0.0526          0.1236      0.0494       16         1
# Removed existing file: results/Normal_100K_18eV_results/nve_348_metrics.csv
#
# Processing: nve_662.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_662.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1642            7.142          15.21       104.1         0             -0             -0.03402          180           284.16     1.8          0.0019          0.1163          0.1182      0             1         0
# Turn         167     1.198             2.099           6.05       165.56       -0.00204        0.00931        0.00063           86.2         102.35     0.1418       0.0361          0.0349          0.0709      0.0638       18         0
# End          700     1.2169            9.976         131.55       197.61       -0.00283        0.00427        0.01599           17.76        123.58     0.4385       0.097           0.0039          0.1008      0.0075        6         1
# Removed existing file: results/Normal_100K_18eV_results/nve_662_metrics.csv
#
# Processing: nve_381.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_381.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2218            7.082         123.99       306.93        0             -0             -0.03402          180           307.68     1.8          0.1172          0.001           0.1183      0             1         0
# Turn         195     1.178             2.008          47.06       310.43       -1e-05          0.00066        0.0115             3.27         90.68     0.2065       0.003           0.1119          0.1149      0.0914       21         0
# End          650     1.2124            9.982          94.45       165.55       -0.00061        0.00017        0.01795            2.02        164.01     0.5015       0.0802          0.0453          0.1255      0.0433       15         1
# Removed existing file: results/Normal_100K_18eV_results/nve_381_metrics.csv
#
# Processing: nve_1861.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1861.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# ...
#
# Processing: nve_1309.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1309.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2211            7.075         138.06       220.29        0              0             -0.03402          180            41.08     1.8          0.1143          0.0039          0.1182      0             1         0
# Turn         197     1.201             2.122          45.68       215.43       -0.00122        3e-05          0.01092            6.39        178.54     0.1876       0.0439          0.0722          0.116       0.1973       32         0
# End          650     1.221             9.852          88.85       295.21        0.00094       -0.00057        0.01796            3.51        328.86     0.5035       0.1138          0.0107          0.1245      0.0595       18         1
#
# Processing: nve_1623.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1623.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2218            7.131          50.05       220.1         0              0             -0.03402          180            41.74     1.8          0.1171          0.0012          0.1184      0             1         0
# Turn         156     1.1457            1.869          76.06       221.99        0.0027         0.00087       -0.01676          170.38         17.89     0.4493       0.0324          0.0253          0.0577      0.2957       37         0
# End          750     1.154            10.048         118.32        32.9        -0.00018       -0.00284        0.01519           10.59        266.36     0.3715       0.014           0.0842          0.0981      0.0233       11         1
#
# Processing: nve_820.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_820.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.128             7.113          78.55       309.98        0             -0             -0.03402          180           308.63     1.8          0.1002          0.0179          0.1182      0             1         0
# Turn         170     1.187             1.77           75.89       315.65       -0.00252       -0.0024         0.00312           48.08        223.58     0.0339       0.0134          0.0925          0.106       0.0244       11         0
# End          800     1.2123           10.044          90.81       225.42       -0.00319       -0.00345        0.01406           18.48        227.22     0.3417       0.0798          0.0381          0.1178      0.0284       12         1
#
# Processing: nve_1079.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1079.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1983            7.066         171.22       354.12       -0              0             -0.03402          180           175.42     1.8          0.0369          0.0812          0.1181      0             1         0
# Turn         149     1.1816            2.13          160.34         8.47        0.00261        0.00217       -0.00936          160.06         39.81     0.1543       0.0063          0.0861          0.0924      0.1398       26         0
# End          850     1.134            10.273          49.74        18.52        0.00239        0.00212        0.01258           14.25         41.48     0.262        0.0727          0.0038          0.0765      0.5244       49         1
#
# Processing: nve_1553.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1553.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1954            7.143          18.79       204.78        0              0             -0.03402          180            22.77     1.8          0.0298          0.0885          0.1183      0             1         0
# Turn         161     1.1961            2.098          16.5        270.68       -0.00787       -0.00241       -0.00099           96.89        197        0.1068       0.0313          0.0339          0.0652      0.0968       22         0
# End          800     1.1307           10.226         156.45       115.33       -0.00421       -0.00483        0.01358           25.26        228.9      0.3506       0.0873          0.0038          0.0911      0.1357       25         1
#
# Processing: nve_1881.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1881.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1293            7.091         111.66       180.12        0              0             -0.03402          180             0.12     1.8          0.0941          0.024           0.1182      0             1         0
# Turn         171     1.2207            1.838          86.03       177.67        0.00584        0.00101        0.00573           45.96          9.79     0.1056       0.1126          0.0006          0.1132      0.0247       11         0
# End          850     1.2175           10.131          80.58       283.81        0.00769        0.00084        0.01296           30.83          6.25     0.3543       0.0996          0.0156          0.1152      0.0213       11         1
#
# Processing: nve_1848.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1848.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1945            7.073         144.77        83.42        0              0             -0.03402          180            83.52     1.8          0.0278          0.0903          0.1181      0             1         0
# Turn         153     1.1699            2.067         127.6         89.87       -0.00156        0.00032       -0.00626          165.73        168.44     0.0648       0               0.1151          0.1151      0.2824       37         0
# End          750     1.1481           10.578          24.96       112.65       -0.00172        0.00111        0.01574            7.4         147.11     0.3918       0.0262          0.0627          0.0889      0.3124       38         1
#
# Processing: nve_682.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_682.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2213            7.137          37.78        38.84       -0             -0             -0.03402          180           219.01     1.8          0.1149          0.0033          0.1182      0             1         0
# Turn         166     1.1961            1.827          64.62        27.84        0.00324        0.00316       -0.00103          102.82         44.23     0.0335       0.0315          0.0676          0.0991      0.0823       21         0
# End          750     1.1811           10.229          80.91       195.33        0.00594        0.00487        0.01553           26.31         39.36     0.4668       0.0058          0.1043          0.11        0.0192       10         1
#
# Processing: nve_361.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_361.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1704            7.081         128.84       147.12        0             -0             -0.03402          180           325.77     1.8          0               0.1182          0.1182      0             1         0
# Turn         151     1.2137            1.967         111.31       145.1         0.00119       -0.00013       -0.0149           175.42        353.87     0.3476       0.0847          0.0421          0.1268      0.26         37         0
# End          650     1.2072            9.938         144.03       188.58        0.00154        0.00057        0.01806            5.19         20.48     0.5112       0.0625          0.049           0.1115      0.0468       16         1
#
# Processing: nve_966.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_966.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1591            7.071         152.5        284.11       -0              0             -0.03402          180           104.22     1.8          0.0064          0.1118          0.1182      0             1         0
# Turn         203     1.2197            2.271          28.16       294.73        0.00176       -0.00038        0.00998           10.23        347.8      0.1599       0.1083          0.037           0.1453      0.5001       52         0
# End          650     1.1345           10.23          152.64       264.89        0.00059        0.0013         0.01831            4.45         65.58     0.5247       0.0708          0.0195          0.0904      0.3151       38         1
#
# Processing: nve_1286.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1286.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2075            7.089         113.5        260.52       -0             -0             -0.03402          180           260.66     1.8          0.0634          0.0548          0.1182      0             1         0
# Turn         198     1.2241            2.118          46.3        255.95       -0.00093       -0.00108        0.01195            6.82        229.3      0.2251       0.127           0.0063          0.1333      0.1337       27         0
# End          650     1.1747            9.866         141.22        54.89       -5e-05         -0.00013        0.01776            0.46        250.4      0.4906       0.001           0.1137          0.1147      0.0308       12         1
#
# Processing: nve_1765.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1765.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1351            7.091         111.62       322.68        0             -0             -0.03402          180           322.34     1.8          0.0683          0.05            0.1182      0             1         0
# Turn         155     1.2266            1.906         100.08       322.2        -0.00219        0.00206       -0.01055          164.08        136.78     0.1871       0.1383          0               0.1383      0.0729       20         0
# End          850     1.1643           10.097          95.52       262.21       -0.00568        0.00312        0.01257           27.28        151.2      0.3112       0.0018          0.1201          0.1219      0.0319       12         1
#
# Processing: nve_157.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_157.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1692            7.108          85.68       156.68       -0              0             -0.03402          180           156.28     1.8          0.0001          0.1181          0.1182      0             1         0
# Turn         174     1.2052            1.813          62.7        159.16       -0.00596        0.00312        0.00724           42.89        152.37     0.1518       0.0561          0.0619          0.118       0.0231       11         0
# End          850     1.1255           10.471          59.05       164.75       -0.00559        0.00358        0.01334           26.46        147.4      0.3452       0.1134          0.0018          0.1152      0.0526       15         1
#
# Wrote 1975 records to results/Normal_100K_18eV_results/batch_summary.csv
