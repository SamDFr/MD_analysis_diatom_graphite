# %% [markdown]
# # NO Scattering Analysis — Notebook Documentation
#
# ## Purpose
# Analyze diatomic scattering trajectories on a graphite slab.
# Compute center-of-mass (COM) kinematics, rotational/vibrational energies, bond geometry, and outcome labels.
# Export per-frame metrics and a batch summary for all input files.
#
# ---
#
# ## Scope and Assumptions
# - **System:** Diatomic molecule, default `NO` (supports homonuclear like `O2`).
# - **Formats:** VASP `vasprun.xml` and text LAMMPS dumps (`.lammpstrj` / `.dump`). XYZ supported for positions.
# - **Velocities:** Uses stored velocities if present. Falls back to finite-difference if missing.
# - **Surface:** Graphite slab. Top reference plane estimated from top C layer.
#
# ---
#
# ## Inputs
# - Directory pattern:
#   `base_dir = "{Incidence}_{Temperature}K_{Energy}eV_vasp_files/"`
# - Files discovered by extension: `.xyz`, `.lammpstrj`, `.xml`, `OUTCAR`, `.dump`
# - Key user config (edit in the header cell):
#   - `incidence` (`'Normal'`), `temperature` (K), `energy` (eV string like `'01'`)
#   - `file_format` (`'VASP'` info only)
#   - `molecule` (`'NO'`, `'CO'`, `'O2'`, `'N2'`)
#   - `DETECTOR_A` (Å): height threshold to count as “scattered”
#   - `DIATOM_IDS` (tuple or `None`): force atom indices if known
#   - `N_MIN_FRAMES` (int): require sufficient frames before labeling scatter
#   - **LAMMPS helpers:** `SPECORDER`, `TIMESTEP_FS`, `DUMP_STRIDE`, `VEL_UNITS`
#
# ---
#
# ## Outputs
# Writes to `OUT_DIR = "{Incidence}_{Temperature}K_{Energy}eV_results"`:
#
# 1. **Per-trajectory CSV:** `<file>_metrics.csv`
#    Per-frame measurements with labeled “Start/Turn/End/Frame”.
# 2. **Batch summary:** `batch_summary.csv`
#    One line per trajectory with final-frame indicators.
#
# Old files are removed before writing.
#
# ---
#
# ## Dependencies
# - Python 3, NumPy, ASE
# - Optional: MDAnalysis (reads velocities from LAMMPS dumps), `tabulate` (prettified console tables)
#
# ```bash
# pip install numpy ase MDAnalysis tabulate

# %%
import os, sys, numpy as np
from math import sqrt
from ase.io import read
from ase.io.vasp import read_vasp_xml
from ase.data import atomic_masses, chemical_symbols
# Optional tabulate helper
sys.path.append(os.path.expanduser('~/bin/tabulate'))
try:
    from tabulate import tabulate
except Exception:
    tabulate = None

# %%
###########################################
# Units and constants
###########################################
# ========================================
# CONSTANTES CORRECTES (du code original)
# ========================================
# Conversions FROM atomic units
autoev   = 27.211383858491185
autofs   = 0.02418884326505      # a.u. time → fs
autoan   = 0.52917720859         # bohr → Å
autoamu  = 0.0005485799092659504
autoanf  = 21.876912541518593    # a.u. velocity → Å/fs

# Conversions TO atomic units
evtoau   = 0.03674932540
fstoau   = 41.341373336561364
antoau   = 1.8897261328856432
amutoau  = 1822.888485540950
anftoau  = 0.045710289242239875  # Å/fs → a.u. velocity

# %%
###########################################
# User config
###########################################

incidence   = 'Normal'
temperature = 100        # K
energy      = '15'       # eV
file_format = 'LAMMPS'     # 'LAMMPS'   # info only
molecule    = 'NO'       # e.g. 'NO','CO','O2','N2'
DETECTOR_A  = 7.0        # Å
DIATOM_IDS  = None      # e.g., (0,1)
N_MIN_FRAMES = 50   # require at least 50 frames before counting as scattered

# --- LAMMPS mapping and timing ---
SPECORDER   = ['N','O','C']  # type 1=N, 2=O, 3=C. Adjust to your dump.
TIMESTEP_FS = 1.0            # MD timestep in fs
DUMP_STRIDE = 1             # steps between dumped frames
DT_FS       = TIMESTEP_FS * DUMP_STRIDE  # finite-diff dt if no velocities
VEL_UNITS   = 'A_per_ps'     # 'A_per_fs' or 'A_per_ps'

#base_dir = f"{incidence}_{int(temperature)}K_{energy}eV_vasp_files/"
base_dir = f"TS5_results/AL1/{incidence}_{int(temperature)}K_{energy}eV/10000traj"

INPUT_FILES = [
    os.path.join(base_dir, f)
    for f in os.listdir(base_dir)
    if f.endswith(('.xyz', '.lammpstrj', '.xml', 'OUTCAR', '.dump'))
]
print(f"Found {len(INPUT_FILES)} input files. format={file_format}")
OUT_DIR = f"results/{incidence}_{temperature}K_{energy}eV_results"
os.makedirs(OUT_DIR, exist_ok=True)

# Define element composition from molecule string
molecule = molecule.strip().upper()
if len(molecule) == 2 and not molecule[1].isdigit():  # e.g. 'NO'
    elemA, elemB = molecule[0], molecule[1]
elif len(molecule) == 2 and molecule[1].isdigit():    # e.g. 'O2'
    elemA, elemB = molecule[0], molecule[0]
else:
    raise ValueError(f"Unsupported diatomic format: {molecule}")
print(f"Molecule: {elemA}-{elemB}")

mA_default = atomic_masses[chemical_symbols.index(elemA)]
mB_default = atomic_masses[chemical_symbols.index(elemB)]
print(f"Masses: {elemA}={mA_default:.4f} amu, {elemB}={mB_default:.4f} amu")
# Out:
# Found 2998 input files. format=LAMMPS
# Molecule: N-O
# Masses: N=14.0070 amu, O=15.9990 amu

# %%
###########################################
# Helpers  (PBC-aware, NO only outputs)
###########################################

def file_kind(path):
    n = os.path.basename(path).lower()
    if n.endswith('.lammpstrj') or n.endswith('.dump') or 'lammpstrj' in n:
        return 'lammps-dump-text'
        #return "LAMMPSDUMP"
    if n == 'outcar':
        return 'vasp-outcar'
    if n.endswith('.xml') or n == 'vasprun.xml':
        return 'vasp-xml'
    if n.endswith('.xyz'):
        return 'xyz'
    return 'auto'

def load_frames(path):
    """Return list[Atoms]. Uses ASE readers. Adds no extra arrays."""
    kind = file_kind(path)

    if kind == 'lammps-dump-text':
        frames = read(path, format='lammps-dump-text', index=":", specorder=SPECORDER)
        # Try to get velocities via MDAnalysis
        import MDAnalysis as mda
        u = mda.Universe(path, format="LAMMPSDUMP")
        n_frames = len(u.trajectory)
        n_atoms = u.atoms.n_atoms
        V = np.empty((n_frames, n_atoms, 3), dtype=np.float64) if u.trajectory.ts.has_velocities else None

        for i, ts in enumerate(u.trajectory):
            if V is not None:
                vel = u.atoms.velocities
                if vel is None:
                    if i == 0:
                        print("No velocities found; skipping velocity extraction.")
                    V = None
                else:
                    V[i] = vel
        for i, atoms in enumerate(frames):
            atoms.set_velocities(V[i])

    if kind == 'vasp-xml':
        frames = read(path, index=":")
    return frames if isinstance(frames, list) else [frames]



def get_velocities(at, vel_units='A_per_ps'):
    """
    Return per-atom velocities in Å/fs.

    Order of preference:
      1) ASE internal velocities (Atoms.get_velocities)
      2) vx,vy,vz arrays (LAMMPS, usually Å/ps)
      3) 'velocities' or 'velocity' arrays (Å/fs)
      4) 'momenta' (amu·Å/fs) divided by atomic masses
    """
    import numpy as np

        # static attribute to avoid re-printing
    if not hasattr(get_velocities, "_ase_vel_printed"):
        get_velocities._ase_vel_printed = False

    arr = at.arrays
    v = None

    # 1) ASE internal velocities
    try:
        v = at.get_velocities()
        if v is not None and np.any(v): # si v est pas "None" et different de 0
            if not get_velocities._ase_vel_printed:
                print("Using ASE internal velocities.")
                get_velocities._ase_vel_printed = True
                
            if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
                v = np.asarray(v, float) / 1000.0
            return np.asarray(v, float)
        else:
            if not get_velocities._ase_vel_printed:
                print("No ASE velocities found — choosing another method.")
                get_velocities._ase_vel_printed = True
    except Exception:
        if not get_velocities._ase_vel_printed:
            print("No ASE velocities found — choosing another method.")
            get_velocities._ase_vel_printed = True

    # 2) explicit vx,vy,vz (LAMMPS)
    if all(k in arr for k in ('vx', 'vy', 'vz')):
        if not get_velocities._ase_vel_printed:
            print("Using 'vx','vy','vz' arrays.")
            get_velocities._ase_vel_printed = True
        v = np.column_stack((arr['vx'], arr['vy'], arr['vz'])).astype(float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 3) velocities arrays (ASE)
    if 'velocities' in arr or 'velocity' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'velocities' or 'velocity' array.")
            get_velocities._ase_vel_printed = True
        v = np.asarray(arr.get('velocities', arr.get('velocity')), float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 4) momenta → velocities
    if 'momenta' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'momenta' array to compute velocities.")
            get_velocities._ase_vel_printed = True
        m = at.get_masses()[:, None]
        p = np.asarray(arr['momenta'], float)
        v = p / m
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    if not get_velocities._ase_vel_printed:
        print("No velocity data found in any source.")
        get_velocities._ase_vel_printed = True
        
    return None

def _mic(dr, cell, pbc):
    if cell is None or not np.any(pbc):
        return dr
    from ase.geometry import find_mic
    mic_dr, _ = find_mic(dr, cell=cell, pbc=pbc)
    return mic_dr

def finite_diff_vel(frames, dt_fs, vel_units='A_per_fs'):
    print("CAREFUL - using finite-difference velocities!")
    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()
    pos = [f.get_positions() for f in frames]
    v = [np.zeros_like(pos[0])]
    for k in range(1, len(frames)-1):
        dr = pos[k+1] - pos[k-1]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/(2.0*dt_fs))
    if len(frames) > 1:
        dr = pos[-1] - pos[-2]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/dt_fs)
    if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
        v /= 1000.
    return v

def _lz(at) -> float:
    # Works for non-orthorhombic too
    return float(np.linalg.norm(at.cell[2]))

def slab_reference_z(at, simple=False, top_tol=0.10, probe_z=None):
    """
    Reference z for a graphite slab.

    If probe_z is None:
        Original behavior (simple=True: mean near global zmax; else k=3 z-clustering).
    If probe_z is not None:
        Return the average z of C atoms within top_tol Å of the highest C layer
        that is *below or equal to* probe_z, using minimum-image wrapping on z.
        Excludes atoms 0 and 1.
    """
    pos = at.get_positions()
    Z   = at.get_atomic_numbers()

    Cidx = np.where(Z == 6)[0]
    Cidx = Cidx[(Cidx != 0) & (Cidx != 1)]
    if Cidx.size == 0:
        return float(np.percentile(pos[:, 2], 10))

    Cz = pos[Cidx, 2].astype(float)

    # ---- New path: reference layer below a probe, PBC-safe
    if probe_z is not None:
        pbc = at.get_pbc()
        Lz  = _lz(at)
        dz = Cz - float(probe_z)
        if pbc[2] and Lz > 0.0:
            dz -= np.rint(dz / Lz) * Lz  # minimum-image along z

        below = dz <= 0.0
        if not np.any(below):
            # Edge case: everything wrapped above. Shift once.
            dz -= Lz
            below = dz <= 0.0
            if not np.any(below):
                # Fallback: use classic top-of-C around global max
                zmax = float(Cz.max())
                band = Cz[Cz >= zmax - float(top_tol)]
                return float(band.mean() if band.size else zmax)

        dz_below = dz[below]
        z_ref = float(probe_z + np.max(dz_below))

        # Average a thin band for robustness
        Cz_unwrapped_below = probe_z + dz_below
        band = np.abs(Cz_unwrapped_below - z_ref) <= float(top_tol)
        return float(Cz_unwrapped_below[band].mean()) if np.any(band) else z_ref

    # ---- Old behavior unchanged below
    if Cz.size < 3:
        return float(Cz.mean())

    if simple:
        zmax = float(Cz.max())
        top = Cz[Cz >= zmax - float(top_tol)]
        return float(top.mean()) if top.size else zmax

    # k=3 clustering on z
    k = 3
    cent = np.percentile(Cz, [10, 50, 90]).astype(float)
    for _ in range(15):
        d = np.abs(Cz[:, None] - cent[None, :])
        lab = np.argmin(d, axis=1)
        new_cent = np.array([Cz[lab == i].mean() if np.any(lab == i) else cent[i] for i in range(k)])
        if np.allclose(new_cent, cent):
            break
        cent = new_cent
    top_cluster = int(np.argmax(cent))
    top_vals = Cz[lab == top_cluster]
    if top_vals.size == 0:
        top_vals = Cz[Cz >= np.percentile(Cz, 80)]
    return float(top_vals.mean() if top_vals.size else Cz.mean())

def pick_NO_indices(at, id_pair=(1, 2), type_pair=(1, 2), elem_pair=('N','O')):
    ids   = at.arrays.get('id')
    types = at.arrays.get('type')
    if ids is not None and id_pair is not None:
        wN = np.where(ids == id_pair[0])[0]
        wO = np.where(ids == id_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if types is not None and type_pair is not None:
        wN = np.where(types == type_pair[0])[0]
        wO = np.where(types == type_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if elem_pair is not None:
        sym = at.get_chemical_symbols()
        try:
            iN = next(i for i,s in enumerate(sym) if s == elem_pair[0])
            iO = next(i for i,s in enumerate(sym) if s == elem_pair[1])
            return (iN, iO)
        except StopIteration:
            pass
    return None

def com(masses, pos):
    M = np.sum(masses)
    return (pos * masses[:,None]).sum(0) / M

def safe_acos_deg(x):
    return np.degrees(np.arccos(np.clip(x, -1.0, 1.0)))

# %%
def diatomic_properties(Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, slab_z_ref,
                        detector_A=None, cell=None, pbc=None, De=None, a=None, re=None):
    # MIC bond in Å
    dAB = Bpos - Apos
    rAB_A = dAB if (cell is None or pbc is None) else _mic(dAB, cell, pbc)
    Bpos_contig = Apos + rAB_A

    # to a.u.
    qA, qB = Apos * antoau, Bpos_contig * antoau
    vA, vB = Avel * anftoau, Bvel * anftoau
    mA, mB = mA_amu * amutoau, mB_amu * amutoau

    # geometry + COM
    rAB  = qB - qA
    r    = np.linalg.norm(rAB) if np.any(rAB) else 1.0
    rhat = rAB / r
    M    = mA + mB
    Rcm  = (mA*qA + mB*qB) / M
    Vcm  = (mA*vA + mB*vB) / M

    # reduced motion
    mu    = (mA*mB) / M
    vrel  = vB - vA
    p_rel = mu * vrel
    p_par = float(np.dot(p_rel, rhat))
    #L_vec = np.cross(p_rel, rAB)
    L_vec = np.cross(rAB, p_rel)
    L2    = float(np.dot(L_vec, L_vec))

    # energies (a.u.)
    Ecm_au  = 0.5 * M * np.dot(Vcm, Vcm)
    Evib_au = 0.5 * (p_par**2) / mu
    Erot_au = 0.5 * L2 / (mu * r**2)

    # optional Morse (eV): r in Å here
    mol_Epot_eV = De * (1.0 - np.exp(-a * (r/antoau - re)))**2 if (De is not None and a is not None and re is not None) else 0.0
    #print(f"DEBUG: r={r/antoau:.4f} Å, Epot={mol_Epot_eV:.4f} eV")

    # back to lab
    com_A   = (Rcm / antoau).tolist()
    vcm_Af  = (Vcm / anftoau).tolist()  # <--- CORRECT : utiliser anftoau pour reconvertir
    d_NO1_A = r / antoau
    heightA = (Rcm / antoau)[2] - slab_z_ref

    # orientations
    def cart2sph(v):
        R = np.linalg.norm(v)
        if R == 0:
            return (0.0, 0.0, 0.0)
            #return None
        theta = np.degrees(np.arccos(np.clip(v[2]/R, -1.0, 1.0)))  # angle from +z
        phi   = np.degrees(np.arctan2(v[1], v[0])) % 360.0
        return (R, theta, phi)

    # match get_Params:
    # - NO1_theta/phi from O position relative to COM
    O_rel_cm = qB - Rcm
    _, NO1_theta_deg, NO1_phi_deg = cart2sph(O_rel_cm)

    # - *_a variants from the bond vector rAB
    NO1_theta_a = safe_acos_deg(rAB[2] / r)
    #NO1_phi_a   = np.degrees(np.arccos(np.clip(rAB[0] / np.linalg.norm([rAB[0], rAB[1], 0.0]), -1.0, 1.0))) if (rAB[0] or rAB[1]) else 0.0
    NO1_phi_a = float((np.degrees(np.arctan2(rAB[1], rAB[0])) + 360.0) % 360.0) if (rAB[0] or rAB[1]) else 0.0

    # velocity orientation from COM velocity
    _, vel_theta_deg, vel_phi_deg = cart2sph(Vcm)
    Vcm_norm = np.linalg.norm(Vcm)
    vel_theta_a = safe_acos_deg(Vcm[2] / Vcm_norm) if Vcm_norm > 0 else 0.0
    #vel_phi_a   = np.degrees(np.arccos(np.clip(Vcm[0] / np.linalg.norm([Vcm[0], Vcm[1], 0.0]), -1.0, 1.0))) if (Vcm[0] or Vcm[1]) else 0.0
    vel_phi_a = float((np.degrees(np.arctan2(Vcm[1], Vcm[0])) + 360.0) % 360.0) if (Vcm[0] or Vcm[1]) else 0.0

    # j from |L| (ħ=1 in a.u.)
    L_norm    = np.sqrt(L2)
    jrot_cont = 0.5 * (-1.0 + np.sqrt(1.0 + 4.0 * L_norm**2))
    jrot      = float(np.ceil(jrot_cont))

    # channel: 1 emitted, 0 adsorbed
    output_CH = 1 if (detector_A is not None and heightA >= detector_A) else 0

    return {
        'output'          : output_CH,
        'mol_massCenter'  : com_A,
        'mol_mCenter_vel' : vcm_Af,
        'mol_jrot'        : jrot,
        'NO1_theta'       : round(NO1_theta_deg, 2),   # O relative to COM
        'NO1_phi'         : round(NO1_phi_deg, 2),
        'NO1_theta_a'     : round(NO1_theta_a, 2),     # bond-based
        'NO1_phi_a'       : round(NO1_phi_a, 2),
        'd_NO1'           : round(d_NO1_A, 4),
        'd_mol_L3'        : round(heightA, 4),
        'mol_vel_theta'   : round(vel_theta_deg, 2),
        'mol_vel_phi'     : round(vel_phi_deg, 2),
        'mol_vel_theta_a' : round(vel_theta_a, 2),
        'mol_vel_phi_a'   : round(vel_phi_a, 2),
        'mol_Ekin'        : round(Ecm_au * autoev, 4),  # COM kinetic (Ecm)
        'mol_Epot'        : round(mol_Epot_eV, 4),
        'mol_Evib_cin'   : round(Evib_au * autoev, 4),
        'mol_Erot'       : round(Erot_au * autoev, 4),
        'mol_Evib_tot'   : round((Evib_au * autoev + mol_Epot_eV), 4)
    }

# %%
###########################################
# Load and analyze  (NO only, PBC-aware)
###########################################

summary_rows = []

for INPUT_FILE in INPUT_FILES:
    print(f"\nProcessing: {os.path.basename(INPUT_FILE)}")
    kind   = file_kind(INPUT_FILE)
    frames = load_frames(INPUT_FILE)
    print()

    if frames is None:
        print("Skip: no frames loaded.")
        continue
    
    if len(frames) < 2:
        print("Skip: need ≥2 frames.")
        continue

    # --- Identify NO atoms
    if DIATOM_IDS is not None:
        iA, iB = DIATOM_IDS
    else:
        ids = pick_NO_indices(frames[0], id_pair=(1,2), type_pair=(1,2), elem_pair=('N','O'))
        if ids is None:
            raise RuntimeError("NO atoms not found")
        iA, iB = ids

    sym = frames[0].get_chemical_symbols()
    print(f"Using diatomic atoms {iA},{iB} ({sym[iA]}-{sym[iB]})")

    # --- Masses (amu)
    mA_amu = mA_default
    mB_amu = mB_default

    # --- Velocities (Å/fs)
    vel_list, need_fd = [], []
    for k, at in enumerate(frames):
        v = get_velocities(at, vel_units=VEL_UNITS)
        bad = (v is None) or (not np.isfinite(v).all()) or np.allclose(v, 0.0)
        vel_list.append(None if bad else v)
        need_fd.append(bad)
    if any(need_fd):
        print("Computing finite-difference velocities for missing frames.")
        fd = finite_diff_vel(frames, DT_FS)
        for k, bad in enumerate(need_fd):
            if bad:
                vel_list[k] = fd[k]

    # --- Helper: probe_z = lower NO atom or COM
    def probe_z(at, use_min_atom=True):
        zA, zB = at.positions[iA, 2], at.positions[iB, 2]
        if use_min_atom:
            return float(min(zA, zB))
        masses = np.array([mA_amu, mB_amu], float)
        return float(com(masses, at.positions[[iA, iB]])[2])

    # --- Reference z for first frame (for reporting)
    zref0 = slab_reference_z(frames[0], top_tol=0.10, probe_z=probe_z(frames[0]))

    # --- Heights of probe over the slab (per frame)
    heights = []
    for at in frames:
        z_probe = probe_z(at, use_min_atom=True)
        zref_k  = slab_reference_z(at, top_tol=0.10, probe_z=z_probe)
        heights.append(max(0.0, z_probe - zref_k))
    heights  = np.array(heights, float)
    turn_idx = int(np.argmin(heights))

    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()

    # --- Optional Morse parameters for NO
    De, a, re = [7.645438936565258, 2.565143344509797, 1.17028471793808]

    # --- Frame-wise properties
    def props_at(k):
        at = frames[k]
        pos = at.get_positions()
        Apos, Bpos = pos[iA], pos[iB]
        Avel, Bvel = vel_list[k][iA], vel_list[k][iB]
        z_probe = probe_z(at, use_min_atom=True)
        zref_k  = slab_reference_z(at, top_tol=0.10, probe_z=z_probe)
        return diatomic_properties(
            Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, zref_k,
            detector_A=DETECTOR_A, cell=cell, pbc=pbc,
            De=De, a=a, re=re
        )

    props = [props_at(k) for k in range(len(frames))]
    pf = props[-1]

    # --- Scatter criterion
    far_enough = pf["d_mol_L3"] >= DETECTOR_A
    after_50frames = len(frames) > N_MIN_FRAMES
    outcome = 1 if (far_enough and after_50frames) else 0  # 1=scatter, 0=stick

    # --- Output headers
    header = [
        "state","t_idx","d_NO(Å)","COM_z-ztop(Å)","NO_theta(°)","NO_phi(°)",
        "Vcm_x(Å/fs)","Vcm_y(Å/fs)","Vcm_z(Å/fs)",
        "Vcm_theta(°)","Vcm_phi(°)",
        "Ecm(eV)","E_pot(eV)","Evib_cin(eV)","Evib_tot(eV)",
        "Erot(eV)","j_rot","output"
    ]

    # --- Row builder
    def row(label, idx, p):
        out_flag = 1 if (p["d_mol_L3"] >= DETECTOR_A and idx > N_MIN_FRAMES) else 0
        return [
            label, idx,
            round(p["d_NO1"],4), round(p["d_mol_L3"],3),
            round(p["NO1_theta"],2), round(p["NO1_phi"],2),
            round(p["mol_mCenter_vel"][0],5), round(p["mol_mCenter_vel"][1],5), round(p["mol_mCenter_vel"][2],5),
            round(p["mol_vel_theta"],2), round(p["mol_vel_phi"],2),
            round(p["mol_Ekin"],4), round(p["mol_Epot"],4),
            round(p["mol_Evib_cin"],4), round(p["mol_Evib_tot"],4), round(p["mol_Erot"],4),
            int(p["mol_jrot"]), out_flag
        ]

    rows_all = [
        row(
            "Start" if k == 0 else "Turn" if k == turn_idx else "End" if k == len(frames)-1 else "Frame",
            k, props[k]
        )
        for k in range(len(frames))
    ]
    rows_key = [rows_all[0], rows_all[turn_idx], rows_all[-1]]

    # --- Summary
    summary = [
        ["file", os.path.basename(INPUT_FILE)],
        ["molecule", f"{elemA}-{elemB}"],
        ["diatomic", f"{iA},{iB} ({sym[iA]}-{sym[iB]})"],
        ["detector_A", DETECTOR_A],
        ["graphite_zref_A", round(zref0,3)],
        ["outcome", "scattered(1)" if outcome == 1 else "stuck(0)"],
    ]

    if tabulate:
        print("\n== Summary ==")
        print(tabulate(summary, tablefmt="plain"))
        print("\n== Trajectory metrics (key frames) ==")
        print(tabulate(rows_key, headers=header, tablefmt="plain"))
    else:
        print(summary)
        print([header] + rows_key)

    # --- Write per-frame CSV
    base = os.path.splitext(os.path.basename(INPUT_FILE))[0]
    out_csv = os.path.join(OUT_DIR, f"{base}_metrics.csv")
    if os.path.exists(out_csv):
        os.remove(out_csv)
        print(f"Removed existing file: {out_csv}")

    np.savetxt(
        out_csv,
        np.array(rows_all, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(header),
        comments='',
        encoding='utf-8'
    )

    # --- Batch summary row
    summary_rows.append([
        base, f"{elemA}-{elemB}", f"{sym[iA]}-{sym[iB]}", DETECTOR_A, round(zref0,3),
        outcome,
        round(pf["d_mol_L3"],3), round(pf["mol_Ekin"],4), int(pf["mol_jrot"]),
        round(pf["d_NO1"],4), round(pf["mol_mCenter_vel"][2],5), round(pf["mol_vel_theta"],2),
        round(pf["mol_Evib_tot"],4)
    ])

# --- Batch summary file
if summary_rows:
    sum_csv = os.path.join(OUT_DIR, "batch_summary.csv")
    if os.path.exists(sum_csv):
        os.remove(sum_csv)
        print(f"Removed existing file: {sum_csv}")
    hdr = [
        "file","molecule","diatomic","detector_A","zref_A","outcome(1=scat,0=stick)",
        "final_COMheight_A","final_Ecm_eV","final_jrot","final_d(Å)",
        "final_Vcm_z(Å/fs)","final_Vcm_θ°","final_Evib_tot_eV"
    ]
    np.savetxt(
        sum_csv,
        np.array(summary_rows, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(hdr),
        comments='',
        encoding='utf-8'
    )
    print(f"\nWrote {len(summary_rows)} records to {sum_csv}")
# Out:
# Processing: nve_9096.lammpstrj
# /Users/samuel/Desktop/postdoc_PhLAM/codes/MD_analysis/.venv/lib/python3.9/site-packages/MDAnalysis/topology/LAMMPSParser.py:632: UserWarning: Guessed all Masses to 1.0
#   warnings.warn('Guessed all Masses to 1.0')
# /Users/samuel/Desktop/postdoc_PhLAM/codes/MD_analysis/.venv/lib/python3.9/site-packages/MDAnalysis/coordinates/LAMMPS.py:598: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data['time'] = step_num * ts.dt
# Using diatomic atoms 0,1 (N-O)
# Using ASE internal velocities.
#
# == Summary ==
# file             nve_9096.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1359            7.097         103.03       227.31        0              0             -0.03106          180            47        1.5          0.065           0.0531          0.1182      0             1         0
# Turn         187     1.2175            1.889          69.2        226.8        -0.00217        0.00413        0.00552           40.18        117.71     0.0811       0.0994          0.032           0.1315      0.001         2         0
# End          800     1.2225           10.145          37.94        33.63       -0.00117        0.0046         0.01437           18.29        104.25     0.3561       0.1203          0.0084          0.1287      0.0229       11         1
#
# Processing: nve_9575.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_9575.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1263            7.105          89.68        79.68        0              0             -0.03106          180            79.69     1.5          0.109           0.0092          0.1182      0             1         0
# Turn         173     1.2206            1.927          86.04        82.77        0.00049       -0.00137       -0.00542          164.98        289.75     0.0489       0.1123          0.0091          0.1213      0.0092        7         0
# End          850     1.1854           10.432         108.33        72.99        0.00101       -0.00311        0.01333           13.79        288.02     0.2931       0.0111          0.1066          0.1177      0.0447       15         1
#
# Processing: nve_5047.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_5047.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1812            7.073         144.31       247.25        0              0             -0.03106          180            66.89     1.5          0.0059          0.1123          0.1182      0             1         0
# Turn         206     1.2072            2.051          51.69       246.54       -0.00051        0.00031        0.00837            4.07        148.84     0.1095       0.0625          0.0609          0.1234      0.3008       40         0
# End          650     1.1961           10.102          18.72       250.38        0.00174       -0.0008         0.01865            5.85        335.29     0.5464       0.0314          0.0893          0.1207      0.1135       24         1
#
# Processing: nve_2451.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_2451.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1761            7.126          58.07       312.57        0             -0             -0.03106          180           314.02     1.5          0.0017          0.1165          0.1182       0            1         0
# Turn         193     1.2067            2.031         106.68       318.63       -0.00252        0.00154        0.00775           20.88        148.68     0.1069       0.0608          0.043           0.1037       0.079       20         0
# End          800     1.1895           10.055          74.5        173.95       -0.00228        0.0019         0.01393           12.03        140.21     0.3156       0.0177          0.0941          0.1118       0.021       10         1
#
# Processing: nve_2667.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_2667.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1337            7.101          96.23        90.52        0             -0             -0.03106          180           270.49     1.5          0.0739          0.0443          0.1182      0             1         0
# Turn         186     1.1956            1.909          64.77        92.26       -0.00158        0.00442        0.00564           39.77        109.71     0.0838       0.0303          0.0673          0.0976      0.0068        6         0
# End          800     1.2209            9.973          76.5         94.3        -0.00084        0.00247        0.01411           10.49        108.69     0.3202       0.1134          0.0027          0.1161      0.0517       17         1
#
# Processing: nve_5792.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_5792.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1878            7.109          85.17       260.9         0              0             -0.03106          180            80.93     1.5          0.0148          0.1034          0.1182      0             1         0
# Turn         194     1.1221            1.934         102.49       246.75        0.00039        0.00635        0.0071            41.87         86.5      0.1414       0.1323          0.0008          0.1331      0.0803       19         0
# End          900     1.1917           10.141          42.48       129.64       -0.00029        0.00613        0.01212           26.86         92.7      0.2869       0.0219          0.1015          0.1235      0.0787       20         1
#
# Processing: nve_7935.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_7935.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1616            7.11           82.98       197.16       -0             -0             -0.03106          180           197.66     1.5          0.0039          0.1143          0.1182      0             1         0
# Turn         191     1.2005            1.971          59.74       203.22       -0.00287       -0.00137        0.00722           23.76        205.45     0.0969       0.0424          0.0665          0.1089      0.0354       14         0
# End          950     1.1991           10.029          64.43       224.74       -0.00269       -0.00145        0.0107            15.94        208.28     0.1924       0.0389          0.0776          0.1165      0.0398       14         1
#
# Processing: nve_4331.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_4331.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2003            7.096         104.08       301.82        0             -0             -0.03106          180           301.12     1.5          0.042           0.0762          0.1182      0             1         0
# Turn         191     1.1572            1.837          66.89       299.92        0.00281        0.0036         0.00533           40.62         52.03     0.0767       0.009           0.1004          0.1094      0.0091        7         0
# End          800     1.1446           10.439          51.76       143.81        0.00286        0.00452        0.01497           19.67         57.67     0.3928       0.0354          0.0816          0.1171      0.0253       11         1
#
# Processing: nve_3727.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3727.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1399            7.083         125.78       100.44        0             -0             -0.03106          180           279.98     1.5          0.0502          0.068           0.1182      0             1         0
# Turn         203     1.1975            2.118          64.11       102.74       -5e-05         -0.00179        0.01104            9.23        268.35     0.1944       0.0347          0.0781          0.1127      0.0487       16         0
# End          850     1.2227           10.415         118.1        276.07        0.00026       -0.001          0.01322            4.46        284.63     0.2734       0.1211          0.0046          0.1257      0.0102        7         1
#
# Processing: nve_3511.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3511.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2169            7.085         119.42       118.91        0             -0             -0.03106          180           296.77     1.5          0.097           0.0211          0.1181      0             1         0
# Turn         169     1.1561            2.015         106.11       117.74        0.00091       -0.0005        -0.00698          171.54        331.14     0.0774       0.0105          0.0966          0.1072      0.1135       23         0
# End          650     1.2199           10.064          89.65       301.22        0.00078       -0.00013        0.01881            2.42        350.5      0.5514       0.109           0.0105          0.1195      0.0107        8         1
#
# Processing: nve_326.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_326.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2221            7.145           7.68        23.32        0              0             -0.03106          180            24.71     1.5          0.1183          0.0002          0.1185      0             1         0
# Turn         164     1.1945            2.348          21.11       334.45        0.00097        0.00342       -0.00698          153            74.13     0.0954       0.0277          0.0739          0.1016      0.2253       34         0
# End          800     1.2265            9.999         102.92       136.33        0.00262        0.00405        0.01371           19.38         57.12     0.3284       0.1377          0.0205          0.1582      0.3457       43         1
# Removed existing file: results/Normal_100K_15eV_results/nve_326_metrics.csv
#
# Processing: nve_6272.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6272.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1992            7.084         121.53       149.09        0             -0             -0.03106          180           329.8      1.5          0.039           0.0792          0.1182      0             1         0
# Turn         197     1.1547            1.888          58.9        150.47        0.00189       -0.00083        0.00793           14.59        336.34     0.1043       0.0127          0.1115          0.1242      0.0347       13         0
# End          750     1.1366           10.592         145.76       231.04        0.0038        -0.00138        0.01646           13.8         340.06     0.4464       0.0622          0.0553          0.1175      0.1263       24         1
#
# Processing: nve_3382.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3382.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1256            7.108          85.73       231.2        -0             -0             -0.03106          180           236.97     1.5          0.113           0.0052          0.1182      0             1         0
# Turn         173     1.2254            1.904          85.11       236.08        0.00216        0.00114       -0.00655          159.58         27.75     0.076        0.1327          0.0067          0.1394      0.0398       15         0
# End          950     1.1866           10.392          78.15        93.75        0.00451        0.00096        0.01139           22.04         11.99     0.2346       0.0129          0.1071          0.1199      0.0883       21         1
#
# Processing: nve_4794.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_4794.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.132             7.13           47.6        185.9        -0             -0             -0.03106          180           186.92     1.5          0.0813          0.037           0.1184      0             1         0
# Turn         192     1.2212            1.906         102.07       186.86       -0.00184       -0.00125        0.00621           19.7         214.2      0.0677       0.1147          0.0001          0.1148      0.0873       22         0
# End          700     1.1439            9.905          54.71         9.04       -0.00126       -0.0009         0.01677            5.25        215.5      0.4411       0.0376          0.0714          0.109       0.0215       10         1
#
# Processing: nve_4870.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_4870.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2189            7.111          81.54        12.15       -0             -0             -0.03106          180           193.15     1.5          0.1052          0.013           0.1182      0             1         0
# Turn         175     1.1466            1.784          76.24        10.29        0.00182        0.00197       -0.0045           149.16         47.27     0.0427       0.03            0.0276          0.0576      0.0055        5         0
# End          800     1.1313            9.976          85.37       151.68        0.00137        0.00229        0.01381           10.92         59.03     0.3077       0.0845          0.0244          0.1089      0.0226       10         1
#
# Processing: nve_1452.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_1452.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1712            7.135          40.45        23.15        0              0             -0.03106          180            23.58     1.5          0               0.1182          0.1182      0             1         0
# Turn         174     1.2112            1.923          69.24        10.02        0.00344        0.00212       -0.00598          145.96         31.59     0.0809       0.076           0.0281          0.1041      0.1135       24         0
# End          850     1.1518           10.243          68.57       237.46        0.00752        0.00232        0.01302           31.16         17.17     0.3601       0.0181          0.0877          0.1058      0.0068        6         1
#
# Processing: nve_6044.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6044.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.152             7.121          66.17       264           0              0             -0.03106          180            83.89     1.5          0.0176          0.1005          0.1182      0             1         0
# Turn         176     1.129             1.909          59.79       268.1         0.00024       -0.00613       -0.00113          100.48        272.2      0.0606       0.0956          0.0352          0.1308      0.021        10         0
# End          950     1.1286           10.245          54.52       275.01        0.00034       -0.00781        0.01106           35.24        272.52     0.2853       0.0975          0.0223          0.1198      0.0407       14         1
#
# Processing: nve_5498.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_5498.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1402            7.137          31.77        60.76        0              0             -0.03106          180            65.55     1.5          0.0493          0.0689          0.1182      0             1         0
# Turn         171     1.2081            2.062          60.57        82.48        0.0025         0.00126       -0.00722          158.8          26.68     0.0932       0.0652          0.0464          0.1115      0.2172       34         0
# End          750     1.2161           10.065         116.5        108.24        0.00248        0.00363        0.01511           16.22         55.72     0.3853       0.0939          0.0232          0.1171      0.0711       19         1
#
# Processing: nve_7454.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_7454.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2047            7.067         163.94        96.53       -0              0             -0.03106          180            95.73     1.5          0.0545          0.0637          0.1182      0             1         0
# Turn         158     1.2086            2.265         156.72       110.86       -0.00297       -0.00034       -0.01049          164.09        186.48     0.185        0.0671          0               0.0671      0.0905       22         0
# End          950     1.133            10.297          94          125.98       -0.00266       -0.00087        0.01074           14.6         198.12     0.1915       0.0772          0.0251          0.1023      0.3733       41         1
#
# Processing: nve_5667.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_5667.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1336            7.101          96.85       248.38        0              0             -0.03106          180            67.64     1.5          0.0742          0.044           0.1182      0             1         0
# Turn         191     1.2125            1.865          66.64       256.63       -0.0002        -0.00186        0.00407           24.68        263.88     0.0311       0.0806          0.0453          0.1259      0.0961       22         0
# End          850     1.1928           10.56           96.54       325.87       -0.00031       -0.001          0.01392            4.31        253.02     0.303        0.024           0.0912          0.1152      0.0686       19         1
#
# Processing: nve_2792.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_2792.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1971            7.11           83.16         8.08       -0             -0             -0.03106          180           188.52     1.5          0.0338          0.0844          0.1182      0             1         0
# Turn         176     1.1301            1.904          79.67         7.82        0.00052       -0.00329       -0.00105          107.41        278.96     0.019        0.0899          0.022           0.112       0.0006        2         0
# End          850     1.188            10.185          69.47       331.74        0.00049       -0.00532        0.01285           22.57        275.31     0.3012       0.015           0.1006          0.1156      0.0006        2         1
#
# Processing: nve_9355.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_9355.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1322            7.11           81.91        25.87        0              0             -0.03106          180            23.84     1.5          0.0805          0.0377          0.1182      0             1         0
# Turn         189     1.1985            1.974          61.82        34.38        0.00248        0.00478        0.00663           39.06         62.58     0.1135       0.0373          0.0701          0.1073      0.031        13         0
# End         1000     1.2201            9.962         111.95       128.34        0.00246        0.00515        0.00995           29.86         64.45     0.2048       0.1098          0.0097          0.1195      0.0481       16         1
#
# Processing: nve_7662.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_7662.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1256            7.094         107.29        90.22         -0            0             -0.03106          180            90.23     1.5          0.1127          0.0055          0.1181      0             1         0
# Turn         172     1.2215            1.95           96.77        90.59         -6e-05       -0.00145       -0.00452          162.21        267.51     0.0351       0.116           0.0005          0.1166      0.0404       15         0
# End          850     1.1982           10.597         101.93       269.77          4e-05       -0.00012        0.01351            0.55        286.93     0.2838       0.0364          0.083           0.1194      0.0106        7         1
#
# Processing: nve_7348.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_7348.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1722            7.136          37.5        200.41        0              0             -0.03106          180            18.48     1.5          0.0002          0.118           0.1182      0             1         0
# Turn         197     1.1246            1.975         119.32       199.93       -0.00015        0.00147        0.00558           14.81         95.75     0.0518       0.1181          0.0264          0.1446      0.1401       25         0
# End          650     1.2108           10.217         132.82       116.86        0.00031        0.00112        0.01884            3.52         74.54     0.5541       0.0743          0.0481          0.1224      0.0024        4         1
#
# Processing: nve_7512.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_7512.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1933            7.068         161.1        256.49       -0             -0             -0.03106          180           257.73     1.5          0.025           0.0931          0.1181      0             1         0
# Turn         158     1.2077            2.303         154.63       257.8         0.00081        0.00163       -0.01062          170.25         63.48     0.1807       0.064           0.0052          0.0692      0.0632       18         0
# End          800     1.139            10.252           9.85        63.5         0.00022        0.00349        0.01428           13.75         86.44     0.3359       0.0534          0.0373          0.0907      0.3287       39         1
#
# Processing: nve_7724.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_7724.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1974            7.09          112.2        107.16       -0              0             -0.03106          180           105.96     1.5          0.0346          0.0837          0.1182      0             1         0
# Turn         181     1.2012            1.949          75.78       108.55       -0.00067       -0.00398        0.0025            58.2         260.41     0.0351       0.0446          0.0898          0.1344      0.0206       10         0
# End          800     1.1498           10.006          21.18        17.53        0.00101       -0.00619        0.01395           24.19        279.23     0.3638       0.0222          0.1003          0.1226      0.0334       13         1
#
# Processing: nve_9213.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_9213.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2195            7.115          76.56       271.27       -0              0             -0.03106          180            91.27     1.5          0.1076          0.0106          0.1182      0             1         0
# Turn         181     1.2185            1.827          96.82       264.48       -0.00083        0.00613        0.00032           87.06         97.74     0.0596       0.1034          0.0074          0.1108      0.0363       14         0
# End          800     1.1295           10.155         123.92        25.2        -0.00098        0.00489        0.01422           19.31        101.36     0.3532       0.0928          0.0108          0.1035      0.0251       11         1
#
# Processing: nve_5721.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_5721.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1262            7.073         148.8        279.68       -0              0             -0.03106          180           100.71     1.5          0.1098          0.0083          0.1181      0             1         0
# Turn         210     1.2205            2.207          44.01       285.32        0.00119       -0.00054        0.00656           11.3         335.47     0.0696       0.1116          0.0446          0.1562      0.5099       52         0
# End          600     1.2052           10.425         173.96       304.6         0.00118        0.00202        0.02181            6.11         59.75     0.7481       0.0561          0.0614          0.1175      0.044        15         1
#
# Processing: nve_6208.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6208.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1629            7.074         144.2        173.14        0             -0             -0.03106          180           353.3      1.5          0.0028          0.1154          0.1182      0             1         0
# Turn         167     1.216             2.133         129.63       169.02        0.00191        0.00043       -0.00294          146.38         12.6      0.0194       0.0937          0.0088          0.1025      0.204        33         0
# End          800     1.2133           10.139          53.68       347.97        0.00065        0.00039        0.01375            3.14         31.08     0.2948       0.0836          0.0596          0.1432      0.3085       40         1
#
# Processing: nve_4661.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_4661.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.21              7.075         138.22       148.3        -0              0             -0.03106          180           149.57     1.5          0.0718          0.0463          0.1181      0             1         0
# Turn         206     1.1195            2.006          51.43       149.22       -0.00013       -3e-05          0.00866            0.89        194.1      0.1166       0.1479          0.0018          0.1497      0.124        24         0
# End          700     1.2243           10.027         153.62       311.88       -0.00122        0.00099        0.01706            5.26        140.76     0.4566       0.1282          0.0035          0.1317      0.0179       10         1
#
# Processing: nve_489.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_489.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1378            7.09          114.37        48.88       -0             -0             -0.03106          180           230.18     1.5          0.0578          0.0603          0.1182      0             1         0
# Turn         190     1.2146            1.872          70.74        47.75       -0.00116       -0.00434        0.00457           44.5         255        0.0638       0.0881          0.0297          0.1179      0.0351       14         0
# End          800     1.22              9.949          95.55        17.78       -0.00236       -0.00473        0.014             20.69        243.45     0.3482       0.1094          0.0111          0.1206      0.063        18         1
# Removed existing file: results/Normal_100K_15eV_results/nve_489_metrics.csv
#
# Processing: nve_8353.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_8353.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2117            7.066         168.13        68.57       -0             -0             -0.03106          180           246.47     1.5          0.0777          0.0405          0.1182      0             1         0
# Turn         165     1.1882            2.221         164.33        48.89        0.0009        -0.00254       -0.00404          146.28        289.49     0.0366       0.0154          0.0698          0.0852      0.032        13         0
# End          950     1.1781            9.924         105.62        32.83        0.00044       -0.00265        0.01001           15           279.52     0.167        0.003           0.1225          0.1255      0.1639       29         1
#
# Processing: nve_6387.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6387.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1268            7.102          94.95        74.97        0              0             -0.03106          180            73.71     1.5          0.1064          0.0118          0.1182      0             1         0
# Turn         192     1.223             1.949          59.23        67.97       -0.00048        0.00513        0.00685           36.92         95.36     0.1142       0.1223          0.0071          0.1293      0.1013       23         0
# End          850     1.1513           10.07          114.58        19.32       -0.00185        0.00415        0.0128            19.55        114.04     0.287        0.019           0.0966          0.1156      0.0769       19         1
#
# Processing: nve_3041.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3041.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1266            7.124          59.41       304.55       -0              0             -0.03106          180           121.75     1.5          0.1073          0.0109          0.1182      0             1         0
# Turn         188     1.2099            1.862         109.17       307.28       -0.0011         0.00284        0.00422           35.79        111.11     0.0421       0.0715          0.032           0.1036      0.0154        9         0
# End          750     1.209            10.259          71.13       308.18       -0.00027        0.00164        0.01555            6.11         99.25     0.3801       0.0684          0.0592          0.1275      0.0747       20         1
#
# Processing: nve_676.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_676.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.126             7.116          72.51        83.62        0              0             -0.03106          180            83.95     1.5          0.1105          0.0077          0.1182      0             1         0
# Turn         173     1.2145            1.948          72.38        84.98        0.00178        0.0034        -0.00319          129.78         62.36     0.0387       0.0881          0.0136          0.1017      0.0086        7         0
# End          850     1.2119            9.954         107.59       234.33        0.00306        0.00564        0.01247           27.22         61.56     0.306        0.0785          0.0321          0.1106      0.0072        6         1
# Removed existing file: results/Normal_100K_15eV_results/nve_676_metrics.csv
#
# Processing: nve_8954.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_8954.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2099            7.082         125.74        33.47       -0             -0             -0.03106          180           216.78     1.5          0.0715          0.0467          0.1182      0             1         0
# Turn         204     1.2059            2.106          48.12        31.78        0.00128        0.00015        0.01014            7.24          6.77     0.1625       0.0584          0.0511          0.1095      0.1263       26         0
# End          700     1.2072           10.431          33.23       338.44        0.00178        0.00054        0.01758            6.05         16.99     0.4858       0.0625          0.0466          0.1091      0.0007        2         1
#
# Processing: nve_6452.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6452.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1349            7.131          47.19        93.78        0             -0             -0.03106          180           273.94     1.5          0.0689          0.0493          0.1182      0             1         0
# Turn         171     1.2274            1.918          73.76        82.94       -0.00072        0.00088       -0.01186          174.53        129.38     0.2208       0.142           0.0144          0.1564      0.2107       34         0
# End          800     1.218            10.086         124.92       171.24        0.00046        0.0054         0.01412           20.99         85.11     0.3556       0.1016          0.0252          0.1268      0.0318       13         1
#
# Processing: nve_6178.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6178.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1954            7.099          99.25       313.35       -0              0             -0.03106          180           132.9      1.5          0.0298          0.0884          0.1182      0             1         0
# Turn         184     1.2216            1.885          96.64       312.16       -0.00489        0.00428        0.00287           66.14        138.86     0.0785       0.1161          0               0.1161      0.0044        5         0
# End          800     1.1414            9.914          78.84       123.63       -0.00591        0.00586        0.01374           31.2         135.24     0.401        0.0452          0.0697          0.1149      0.0208       10         1
#
# Processing: nve_3870.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3870.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2214            7.103          92.54       268.4          0             0             -0.03106          180            88.1      1.5          0.1154          0.0028          0.1182      0             1         0
# Turn         178     1.1964            1.839          78.22       270.81         0.0022        0.00121        8e-05             88.27         28.8      0.0098       0.032           0.0818          0.1138      0.0079        6         0
# ...
#
# == Summary ==
# file             nve_5129.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2107            7.132          47.29       265.7         0              0             -0.03106          180            85.48     1.5          0.0742          0.044           0.1182      0             1         0
# Turn         168     1.1958            2.021          64.96       275.13        0.00019       -0.00307       -0.01095          164.29        273.44     0.2013       0.0307          0.0941          0.1248      0.1735       30         0
# End          800     1.1306           10.585          61.63       119.87        0.00178       -0.0054         0.01496           20.82        288.2      0.3984       0.0879          0.034           0.122       0.0194        9         1
#
# Processing: nve_2824.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_2824.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.125             7.096         104.21       339.54        0             -0             -0.03106          180           330.72     1.5          0.116           0.0022          0.1182      0             1         0
# Turn         206     1.1961            2.124          45.2        333.11        0.00194       -0.00042        0.00933           11.99        347.85     0.1415       0.0313          0.0735          0.1048      0.0304       12         0
# End          850     1.1742           10.389          92.37       330.49        0.00026       -0.00016        0.01325            1.31        327.95     0.273        0.0008          0.1082          0.1089      0.0717       19         1
#
# Processing: nve_5635.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_5635.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1915            7.1            97.93       276.69        0             -0             -0.03106          180           276.53     1.5          0.0215          0.0967          0.1182      0             1         0
# Turn         182     1.1929            1.778          77.41       277.76        0.00323        0.00052       -0.00077          103.32          9.07     0.0176       0.0243          0.1147          0.139       0.0303       12         0
# End          800     1.1382           10.617          72.78       199.38        0.00356        0.00216        0.01515           15.37         31.31     0.384        0.0563          0.0695          0.1258      0.0362       13         1
#
# Processing: nve_9307.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_9307.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1251            7.113          78.15       245.26        0              0             -0.03106          180            65.12     1.5          0.1152          0.0029          0.1181      0             1         0
# Turn         191     1.2218            1.84           94.32       233.52       -0.00083        0.00564        0.0062            42.6          98.37     0.1102       0.1174          0.0046          0.1219      0.0192       10         0
# End          850     1.1861           10.274         117.79         7.37       -0.00144        0.00485        0.0132            20.96        106.55     0.3106       0.0121          0.1009          0.113       0.0184       10         1
#
# Processing: nve_138.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_138.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1566            7.12           67.19        71.2        -0             -0             -0.03106          180           250.8      1.5          0.0098          0.1085          0.1182      0             1         0
# Turn         185     1.2058            1.849          95.65        76.68       -0.00133       -0.00069        0.00445           18.66        207.48     0.0343       0.058           0.0536          0.1116      0.0019        3         0
# End          750     1.1456           10.193          69.45       256.7        -0.00082        0.00036        0.01551            3.32        156.3      0.3755       0.0326          0.0797          0.1122      0.0108        7         1
# Removed existing file: results/Normal_100K_15eV_results/nve_138_metrics.csv
#
# Processing: nve_412.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_412.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1819            7.142          20.41       329.65       -0              0             -0.03106          180           143.41     1.5          0.0066          0.1117          0.1182      0             1         0
# Turn         206     1.2214            2.148         132.48       337.93       -0.00119       -8e-05          0.00723            9.39        183.61     0.0835       0.1153          0.0357          0.151       0.349        43         0
# End          650     1.1582           10.096         102.91       147.18       -0.00059       -0.00037        0.01869            2.13        212.45     0.5438       0.0076          0.1188          0.1264      0.2004       31         1
# Removed existing file: results/Normal_100K_15eV_results/nve_412_metrics.csv
#
# Processing: nve_3225.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3225.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1755            7.08          130.49        12.65        0              0             -0.03106          180            12.38     1.5          0.0013          0.1169          0.1182      0             1         0
# Turn         214     1.2229            2.274          42.21        20.66        3e-05          0.00131        0.01109            6.72         88.55     0.1939       0.1219          0.0136          0.1355      0.2099       33         0
# End          650     1.1562           10.028          87.45        12.64        0.00101        0.00186        0.01818            6.63         61.47     0.5207       0.0104          0.1099          0.1204      0.0843       20         1
#
# Processing: nve_6636.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6636.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1405            7.085         121.83        45.77        0              0             -0.03106          180            44.47     1.5          0.0482          0.0699          0.1181      0             1         0
# Turn         197     1.1796            1.988          55.43        46.31        0.00194       -0.00074        0.00811           14.38        339.04     0.1091       0.0042          0.1287          0.1329      0.1827       30         0
# End          700     1.1792           10.286           7.05       347           0.0006        -0.00211        0.01729            7.22        285.78     0.4723       0.0039          0.1212          0.1251      0.0726       19         1
#
# Processing: nve_624.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_624.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1254            7.101          97.15       140.32       -0              0             -0.03106          180           141.88     1.5          0.114           0.0042          0.1182      0             1         0
# Turn         191     1.2264            1.826          71.37       146.45        0.00092       -0.00035        0.00519           10.71        339.25     0.0435       0.1374          0.0002          0.1377      0.0254       12         0
# End          800     1.2188           10.138          84.74        24.49        0.00142       -0.00085        0.01455            6.5         329.03     0.3336       0.1049          0.0189          0.1238      0.0236       11         1
# Removed existing file: results/Normal_100K_15eV_results/nve_624_metrics.csv
#
# Processing: nve_4405.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_4405.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2088            7.092         109.6        340.22        0             -0             -0.03106          180           337.88     1.5          0.0677          0.0504          0.1182      0             1         0
# Turn         198     1.2206            2.031          72.98       339.15       -0.00107        0.00073        0.0103             7.19        145.74     0.1676       0.1119          0.0118          0.1237      0.1008       23         0
# End          750     1.2063           10.083          72.03        61.65       -0.00021       -0.00017        0.01541            1           218.03     0.3694       0.0595          0.0621          0.1216      0.0027        4         1
#
# Processing: nve_3822.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_3822.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1892            7.09          112.82       251.45        0              0             -0.03106          180            71.44     1.5          0.0172          0.101           0.1182      0             1         0
# Turn         200     1.1956            2.142          51.15       248.96        0.00168       -0.00196        0.00961           15.05        310.63     0.1539       0.0302          0.0783          0.1085      0.0342       13         0
# End          850     1.2209           10.043          90.29       274.88        0.00113       -0.00113        0.01249            7.31        315.05     0.2467       0.1134          0.0111          0.1245      0.0648       19         1
#
# Processing: nve_8137.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_8137.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1422            7.116          72.89       334.51       -0              0             -0.03106          180           152.9      1.5          0.0427          0.0755          0.1182      0             1         0
# Turn         171     1.231             1.91           83.53       336.77       -0.00268        0.00262       -0.00899          157.4         135.65     0.1476       0.1589          0.0195          0.1785      0.114        25         0
# End          950     1.1267           10.131         132.05       338.83       -0.00108        0.00443        0.01087           22.78        103.75     0.2161       0.107           0.0106          0.1176      0.0364       13         1
#
# Processing: nve_6770.lammpstrj
#
# Using diatomic atoms 0,1 (N-O)
#
# == Summary ==
# file             nve_6770.lammpstrj
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  6.828
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1263            7.139          24.7        110.05        0             -0             -0.03106          180           287.07     1.5          0.1091          0.0089          0.1181      0             1         0
# Turn         207     1.2167            2.08          129.69        94.23       -0.00014       -0.00076        0.0101             4.38        259.66     0.1596       0.0962          0.0145          0.1107      0.172        30         0
# End          650     1.1489           10.526          35.55       178.81       -2e-05         -0.00122        0.01976            3.52        269.09     0.6093       0.0243          0.0852          0.1095      0.0464       15         1
#
# Processing: nve_6293.lammpstrj
