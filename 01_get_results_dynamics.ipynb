# %%
import os, sys, numpy as np
from math import sqrt
from ase.io import read
from ase.io.vasp import read_vasp_xml
from ase.data import atomic_masses, chemical_symbols
# Optional tabulate helper
sys.path.append(os.path.expanduser('~/bin/tabulate'))
try:
    from tabulate import tabulate
except Exception:
    tabulate = None

# %%
###########################################
# Units and constants
###########################################
# ========================================
# CONSTANTES CORRECTES (du code original)
# ========================================
# Conversions FROM atomic units
autoev   = 27.211383858491185
autofs   = 0.02418884326505      # a.u. time → fs
autoan   = 0.52917720859         # bohr → Å
autoamu  = 0.0005485799092659504
autoanf  = 21.876912541518593    # a.u. velocity → Å/fs

# Conversions TO atomic units
evtoau   = 0.03674932540
fstoau   = 41.341373336561364
antoau   = 1.8897261328856432
amutoau  = 1822.888485540950
anftoau  = 0.045710289242239875  # Å/fs → a.u. velocity

# %%
###########################################
# User config
###########################################

incidence   = 'Normal'
temperature = 300        # K
energy      = '01'       # eV
file_format = 'VASP'     # 'LAMMPS'   # info only
molecule    = 'NO'       # e.g. 'NO','CO','O2','N2'
DETECTOR_A  = 7.0        # Å
DIATOM_IDS  = None      # e.g., (0,1)
N_MIN_FRAMES = 50   # require at least 50 frames before counting as scattered

# --- LAMMPS mapping and timing ---
SPECORDER   = ['N','O','C']  # type 1=N, 2=O, 3=C. Adjust to your dump.
TIMESTEP_FS = 1.0            # MD timestep in fs
DUMP_STRIDE = 1             # steps between dumped frames
DT_FS       = TIMESTEP_FS * DUMP_STRIDE  # finite-diff dt if no velocities
VEL_UNITS   = 'A_per_fs'     # 'A_per_fs' or 'A_per_ps'

base_dir = f"{incidence}_{int(temperature)}K_{energy}eV_vasp_files/"
#base_dir = f"{incidence}_{int(temperature)}K_{energy}eV/"

INPUT_FILES = [
    os.path.join(base_dir, f)
    for f in os.listdir(base_dir)
    if f.endswith(('.xyz', '.lammpstrj', '.xml', 'OUTCAR', '.dump'))
]
print(f"Found {len(INPUT_FILES)} input files. format={file_format}")
OUT_DIR = f"{incidence}_{temperature}K_{energy}eV_results"
os.makedirs(OUT_DIR, exist_ok=True)

# Define element composition from molecule string
molecule = molecule.strip().upper()
if len(molecule) == 2 and not molecule[1].isdigit():  # e.g. 'NO'
    elemA, elemB = molecule[0], molecule[1]
elif len(molecule) == 2 and molecule[1].isdigit():    # e.g. 'O2'
    elemA, elemB = molecule[0], molecule[0]
else:
    raise ValueError(f"Unsupported diatomic format: {molecule}")
print(f"Molecule: {elemA}-{elemB}")

mA_default = atomic_masses[chemical_symbols.index(elemA)]
mB_default = atomic_masses[chemical_symbols.index(elemB)]
print(f"Masses: {elemA}={mA_default:.4f} amu, {elemB}={mB_default:.4f} amu")
# Out:
# Found 100 input files. format=VASP
# Molecule: N-O
# Masses: N=14.0070 amu, O=15.9990 amu

# %%
###########################################
# Helpers  (PBC-aware, NO only outputs)
###########################################

def file_kind(path):
    n = os.path.basename(path).lower()
    if n.endswith('.lammpstrj') or n.endswith('.dump') or 'lammpstrj' in n:
        return 'lammps-dump-text'
        #return "LAMMPSDUMP"
    if n == 'outcar':
        return 'vasp-outcar'
    if n.endswith('.xml') or n == 'vasprun.xml':
        return 'vasp-xml'
    if n.endswith('.xyz'):
        return 'xyz'
    return 'auto'

def load_frames(path):
    """Return list[Atoms]. Uses ASE readers. Adds no extra arrays."""
    kind = file_kind(path)

    if kind == 'lammps-dump-text':
        frames = read(path, format='lammps-dump-text', index=":", specorder=SPECORDER)
        # Try to get velocities via MDAnalysis
        import MDAnalysis as mda
        u = mda.Universe(path, format="LAMMPSDUMP")
        n_frames = len(u.trajectory)
        n_atoms = u.atoms.n_atoms
        V = np.empty((n_frames, n_atoms, 3), dtype=np.float64) if u.trajectory.ts.has_velocities else None

        for i, ts in enumerate(u.trajectory):
            if V is not None:
                vel = u.atoms.velocities
                if vel is None:
                    if i == 0:
                        print("No velocities found; skipping velocity extraction.")
                    V = None
                else:
                    V[i] = vel
        for i, atoms in enumerate(frames):
            atoms.set_velocities(V[i])

    if kind == 'vasp-xml':
        frames = read(path, index=":")
    return frames if isinstance(frames, list) else [frames]



def get_velocities(at, vel_units='A_per_ps'):
    """
    Return per-atom velocities in Å/fs.

    Order of preference:
      1) ASE internal velocities (Atoms.get_velocities)
      2) vx,vy,vz arrays (LAMMPS, usually Å/ps)
      3) 'velocities' or 'velocity' arrays (Å/fs)
      4) 'momenta' (amu·Å/fs) divided by atomic masses
    """
    import numpy as np

        # static attribute to avoid re-printing
    if not hasattr(get_velocities, "_ase_vel_printed"):
        get_velocities._ase_vel_printed = False

    arr = at.arrays
    v = None

    # 1) ASE internal velocities
    try:
        v = at.get_velocities()
        if v is not None and np.any(v): # si v est pas "None" et different de 0
            if not get_velocities._ase_vel_printed:
                print("Using ASE internal velocities.")
                get_velocities._ase_vel_printed = True
                
            if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
                v = np.asarray(v, float) / 1000.0
            return np.asarray(v, float)
        else:
            if not get_velocities._ase_vel_printed:
                print("No ASE velocities found — choosing another method.")
                get_velocities._ase_vel_printed = True
    except Exception:
        if not get_velocities._ase_vel_printed:
            print("No ASE velocities found — choosing another method.")
            get_velocities._ase_vel_printed = True

    # 2) explicit vx,vy,vz (LAMMPS)
    if all(k in arr for k in ('vx', 'vy', 'vz')):
        if not get_velocities._ase_vel_printed:
            print("Using 'vx','vy','vz' arrays.")
            get_velocities._ase_vel_printed = True
        v = np.column_stack((arr['vx'], arr['vy'], arr['vz'])).astype(float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 3) velocities arrays (ASE)
    if 'velocities' in arr or 'velocity' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'velocities' or 'velocity' array.")
            get_velocities._ase_vel_printed = True
        v = np.asarray(arr.get('velocities', arr.get('velocity')), float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 4) momenta → velocities
    if 'momenta' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'momenta' array to compute velocities.")
            get_velocities._ase_vel_printed = True
        m = at.get_masses()[:, None]
        p = np.asarray(arr['momenta'], float)
        v = p / m
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    if not get_velocities._ase_vel_printed:
        print("No velocity data found in any source.")
        get_velocities._ase_vel_printed = True
        
    return None

def _mic(dr, cell, pbc):
    if cell is None or not np.any(pbc):
        return dr
    from ase.geometry import find_mic
    mic_dr, _ = find_mic(dr, cell=cell, pbc=pbc)
    return mic_dr

def finite_diff_vel(frames, dt_fs, vel_units='A_per_fs'):
    print("CAREFUL - using finite-difference velocities!")
    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()
    pos = [f.get_positions() for f in frames]
    v = [np.zeros_like(pos[0])]
    for k in range(1, len(frames)-1):
        dr = pos[k+1] - pos[k-1]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/(2.0*dt_fs))
    if len(frames) > 1:
        dr = pos[-1] - pos[-2]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/dt_fs)
    if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
        v /= 1000.
    return v

def slab_reference_z(at, simple=False, top_tol=0.10):
    """
    Reference z for a 3-layer graphite slab.
    If simple=True: return mean z of atoms within top_tol Å of the highest C atom (horizontal plane through top C layer).
    Else: k=3 z-clustering over C to find the top layer centroid.
    Excludes atoms 0 and 1.
    """
    import numpy as np

    pos = at.get_positions()
    Z   = at.get_atomic_numbers()

    Cidx = np.where(Z == 6)[0]
    Cidx = Cidx[(Cidx != 0) & (Cidx != 1)]
    if Cidx.size == 0:
        return float(np.percentile(pos[:, 2], 10))

    Cz = pos[Cidx, 2].astype(float)
    if Cz.size < 3:
        return float(Cz.mean())

    if simple:
        zmax = float(Cz.max())
        top = Cz[Cz >= zmax - float(top_tol)]
        return float(top.mean()) if top.size else zmax

    # k=3 clustering on z
    k = 3
    cent = np.percentile(Cz, [10, 50, 90]).astype(float)
    for _ in range(15):
        d = np.abs(Cz[:, None] - cent[None, :])
        lab = np.argmin(d, axis=1)
        new_cent = np.array([Cz[lab == i].mean() if np.any(lab == i) else cent[i] for i in range(k)])
        if np.allclose(new_cent, cent):
            break
        cent = new_cent
    top_cluster = int(np.argmax(cent))
    top_vals = Cz[lab == top_cluster]
    if top_vals.size == 0:
        top_vals = Cz[Cz >= np.percentile(Cz, 80)]
    return float(top_vals.mean() if top_vals.size else Cz.mean())

def pick_NO_indices(at, id_pair=(1, 2), type_pair=(1, 2), elem_pair=('N','O')):
    ids   = at.arrays.get('id')
    types = at.arrays.get('type')
    if ids is not None and id_pair is not None:
        wN = np.where(ids == id_pair[0])[0]
        wO = np.where(ids == id_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if types is not None and type_pair is not None:
        wN = np.where(types == type_pair[0])[0]
        wO = np.where(types == type_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if elem_pair is not None:
        sym = at.get_chemical_symbols()
        try:
            iN = next(i for i,s in enumerate(sym) if s == elem_pair[0])
            iO = next(i for i,s in enumerate(sym) if s == elem_pair[1])
            return (iN, iO)
        except StopIteration:
            pass
    return None

def com(masses, pos):
    M = np.sum(masses)
    return (pos * masses[:,None]).sum(0) / M

def safe_acos_deg(x):
    return np.degrees(np.arccos(np.clip(x, -1.0, 1.0)))

# %%
def diatomic_properties(Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, slab_z_ref,
                        detector_A=None, cell=None, pbc=None, De=None, a=None, re=None):
    # MIC bond in Å
    dAB = Bpos - Apos
    rAB_A = dAB if (cell is None or pbc is None) else _mic(dAB, cell, pbc)
    Bpos_contig = Apos + rAB_A

    # to a.u.
    qA, qB = Apos * antoau, Bpos_contig * antoau
    vA, vB = Avel * anftoau, Bvel * anftoau
    mA, mB = mA_amu * amutoau, mB_amu * amutoau

    # geometry + COM
    rAB  = qB - qA
    r    = np.linalg.norm(rAB) if np.any(rAB) else 1.0
    rhat = rAB / r
    M    = mA + mB
    Rcm  = (mA*qA + mB*qB) / M
    Vcm  = (mA*vA + mB*vB) / M

    # reduced motion
    mu    = (mA*mB) / M
    vrel  = vB - vA
    p_rel = mu * vrel
    p_par = float(np.dot(p_rel, rhat))
    #L_vec = np.cross(p_rel, rAB)
    L_vec = np.cross(rAB, p_rel)
    L2    = float(np.dot(L_vec, L_vec))

    # energies (a.u.)
    Ecm_au  = 0.5 * M * np.dot(Vcm, Vcm)
    Evib_au = 0.5 * (p_par**2) / mu
    Erot_au = 0.5 * L2 / (mu * r**2)

    # optional Morse (eV): r in Å here
    mol_Epot_eV = De * (1.0 - np.exp(-a * (r/antoau - re)))**2 if (De is not None and a is not None and re is not None) else 0.0
    #print(f"DEBUG: r={r/antoau:.4f} Å, Epot={mol_Epot_eV:.4f} eV")

    # back to lab
    com_A   = (Rcm / antoau).tolist()
    vcm_Af  = (Vcm / anftoau).tolist()  # <--- CORRECT : utiliser anftoau pour reconvertir
    d_NO1_A = r / antoau
    heightA = (Rcm / antoau)[2] - slab_z_ref

    # orientations
    def cart2sph(v):
        R = np.linalg.norm(v)
        if R == 0:
            return (0.0, 0.0, 0.0)
            #return None
        theta = np.degrees(np.arccos(np.clip(v[2]/R, -1.0, 1.0)))  # angle from +z
        phi   = np.degrees(np.arctan2(v[1], v[0])) % 360.0
        return (R, theta, phi)

    # match get_Params:
    # - NO1_theta/phi from O position relative to COM
    O_rel_cm = qB - Rcm
    _, NO1_theta_deg, NO1_phi_deg = cart2sph(O_rel_cm)

    # - *_a variants from the bond vector rAB
    NO1_theta_a = safe_acos_deg(rAB[2] / r)
    #NO1_phi_a   = np.degrees(np.arccos(np.clip(rAB[0] / np.linalg.norm([rAB[0], rAB[1], 0.0]), -1.0, 1.0))) if (rAB[0] or rAB[1]) else 0.0
    NO1_phi_a = float((np.degrees(np.arctan2(rAB[1], rAB[0])) + 360.0) % 360.0) if (rAB[0] or rAB[1]) else 0.0

    # velocity orientation from COM velocity
    _, vel_theta_deg, vel_phi_deg = cart2sph(Vcm)
    Vcm_norm = np.linalg.norm(Vcm)
    vel_theta_a = safe_acos_deg(Vcm[2] / Vcm_norm) if Vcm_norm > 0 else 0.0
    #vel_phi_a   = np.degrees(np.arccos(np.clip(Vcm[0] / np.linalg.norm([Vcm[0], Vcm[1], 0.0]), -1.0, 1.0))) if (Vcm[0] or Vcm[1]) else 0.0
    vel_phi_a = float((np.degrees(np.arctan2(Vcm[1], Vcm[0])) + 360.0) % 360.0) if (Vcm[0] or Vcm[1]) else 0.0

    # j from |L| (ħ=1 in a.u.)
    L_norm    = np.sqrt(L2)
    jrot_cont = 0.5 * (-1.0 + np.sqrt(1.0 + 4.0 * L_norm**2))
    jrot      = float(np.ceil(jrot_cont))

    # channel: 1 emitted, 0 adsorbed
    output_CH = 1 if (detector_A is not None and heightA >= detector_A) else 0

    return {
        'output'          : output_CH,
        'mol_massCenter'  : com_A,
        'mol_mCenter_vel' : vcm_Af,
        'mol_jrot'        : jrot,
        'NO1_theta'       : round(NO1_theta_deg, 2),   # O relative to COM
        'NO1_phi'         : round(NO1_phi_deg, 2),
        'NO1_theta_a'     : round(NO1_theta_a, 2),     # bond-based
        'NO1_phi_a'       : round(NO1_phi_a, 2),
        'd_NO1'           : round(d_NO1_A, 4),
        'd_mol_L3'        : round(heightA, 4),
        'mol_vel_theta'   : round(vel_theta_deg, 2),
        'mol_vel_phi'     : round(vel_phi_deg, 2),
        'mol_vel_theta_a' : round(vel_theta_a, 2),
        'mol_vel_phi_a'   : round(vel_phi_a, 2),
        'mol_Ekin'        : round(Ecm_au * autoev, 4),  # COM kinetic (Ecm)
        'mol_Epot'        : round(mol_Epot_eV, 4),
        'mol_Evib_cin'   : round(Evib_au * autoev, 4),
        'mol_Erot'       : round(Erot_au * autoev, 4),
        'mol_Evib_tot'   : round((Evib_au * autoev + mol_Epot_eV), 4)
    }

# %%
###########################################
# Load and analyze  (NO only, PBC-aware)
###########################################

summary_rows = []

for INPUT_FILE in INPUT_FILES:
    print(f"\nProcessing: {os.path.basename(INPUT_FILE)}")
    kind   = file_kind(INPUT_FILE)
    frames = load_frames(INPUT_FILE)

    print()

    if frames is None:
        print("Skip: no frames loaded.")
        continue
    
    if len(frames) < 2:
        print("Skip: need ≥2 frames.")
        continue

    # pick NO indices (falls back to symbols for VASP/XYZ)
    if DIATOM_IDS is not None:
        iA, iB = DIATOM_IDS
    else:
        ids = pick_NO_indices(frames[0], id_pair=(1,2), type_pair=(1,2), elem_pair=('N','O'))
        if ids is None:
            raise RuntimeError("NO atoms not found")
        iA, iB = ids

    sym = frames[0].get_chemical_symbols()
    print(f"Using diatomic atoms {iA},{iB} ({sym[iA]}-{sym[iB]})")

    # masses (amu)
    mA_amu = mA_default
    mB_amu = mB_default

    # velocities (Å/fs). If any frame missing or zero, fall back to finite-diff.
    vel_list, need_fd = [], []
    for k, at in enumerate(frames):
        v = get_velocities(at, vel_units=VEL_UNITS)  # ASE handles LAMMPS/VASP/XYZ
        #print(f"DEBUG: Frame {k}, velocities:\n{v}")
        bad = (v is None) or (not np.isfinite(v).all()) or np.allclose(v, 0.0)
        vel_list.append(None if bad else v)
        need_fd.append(bad)
    if any(need_fd):
        finite_diff = True
        fd = finite_diff_vel(frames, DT_FS)  # Å/fs
        for k, bad in enumerate(need_fd):
            if bad:
                vel_list[k] = fd[k]

    # slab reference and closest approach (COM height)
    zref = slab_reference_z(frames[0], simple=True, top_tol=0.10)
    heights = []
    for at in frames:
        pos = at.get_positions()
        masses = np.array([mA_amu, mB_amu])
        ABpos = pos[[iA, iB]]
        Rcm = com(masses, ABpos)
        heights.append(Rcm[2] - zref)
    heights = np.array(heights, float)
    turn_idx = int(np.argmin(heights))  # closest COM to slab
    #print(f"Turning point at frame index {turn_idx}, z_COM - z_ref = {heights[turn_idx]:.4f} Å")
    #time at turning point

    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()

    # Optional Morse potential for NO
    De, a, re = [7.645438936565258, 2.565143344509797, 1.17028471793808]

    def props_at(k):
        at = frames[k]
        pos = at.get_positions()
        Apos, Bpos = pos[iA], pos[iB]
        Avel, Bvel = vel_list[k][iA], vel_list[k][iB]
        return diatomic_properties(
            Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, zref,
            detector_A=DETECTOR_A, cell=cell, pbc=pbc,
            De=De, a=a, re=re
        )

    # per-frame properties
    props = [props_at(k) for k in range(len(frames))]
    pf = props[-1]

    # scatter only if molecule is far enough AND simulation ran past 50 frames
    far_enough = pf["d_mol_L3"] >= DETECTOR_A
    after_50frames = len(frames) > N_MIN_FRAMES

    outcome = 1 if (far_enough and after_50frames) else 0  # 1=scatter, 0=stick

    header = [
        "state",
        "t_idx",
        "d_NO(Å)",
        "COM_z-ztop(Å)",
        "NO_theta(°)",
        "NO_phi(°)",
        "Vcm_x(Å/fs)",
        "Vcm_y(Å/fs)",
        "Vcm_z(Å/fs)",
        "Vcm_theta(°)",
        "Vcm_phi(°)",
        "Ecm(eV)",
        "E_pot(eV)",
        "Evib_cin(eV)",
        "Evib_tot(eV)",
        "Erot(eV)",
        "j_rot",
        "output"
    ]

    def row(label, idx, p):
        out_flag = 0
        # mark scattered only if distance ≥ DETECTOR_A and we are past frame 50
        if (p["d_mol_L3"] >= DETECTOR_A) and (idx > N_MIN_FRAMES):
            out_flag = 1
        return [
            label, idx,
            round(p["d_NO1"],4), round(p["d_mol_L3"],3),
            round(p["NO1_theta"],2), round(p["NO1_phi"],2),
            round(p["mol_mCenter_vel"][0],5), round(p["mol_mCenter_vel"][1],5), round(p["mol_mCenter_vel"][2],5),
            round(p["mol_vel_theta"],2), round(p["mol_vel_phi"],2),
            round(p["mol_Ekin"],4), round(p["mol_Epot"],4),
            round(p["mol_Evib_cin"],4), round(p["mol_Evib_tot"],4), round(p["mol_Erot"],4),
            int(p["mol_jrot"]), out_flag
        ]

    # build rows for all frames; tag special frames
    rows_all = [
        row(
            "Start" if k == 0 else "Turn" if k == turn_idx else "End" if k == len(frames)-1 else "Frame",
            k, props[k]
        )
        for k in range(len(frames))
    ]

    # console summary shows only key frames
    rows_key = [rows_all[0], rows_all[turn_idx], rows_all[-1]]

    summary = [
        ["file", os.path.basename(INPUT_FILE)],
        ["molecule", f"{elemA}-{elemB}"],
        ["diatomic", f"{iA},{iB} ({sym[iA]}-{sym[iB]})"],
        ["detector_A", DETECTOR_A],
        ["graphite_zref_A", round(zref,3)],
        ["outcome", "scattered(0)" if outcome==0 else "stuck(1)"],
    ]
    if tabulate:
        print("\n== Summary =="); print(tabulate(summary, tablefmt="plain"))
        print("\n== Trajectory metrics (key frames) =="); print(tabulate(rows_key, headers=header, tablefmt="plain"))
    else:
        print(summary); print([header] + rows_key)

    # write per-frame CSV
    base = os.path.splitext(os.path.basename(INPUT_FILE))[0]
    out_csv = os.path.join(OUT_DIR, f"{base}_metrics.csv")
    # remove the file if it already exist (to avoid appending to old data)
    if os.path.exists(out_csv):
        os.remove(out_csv)
        print(f"Removed existing file: {out_csv}")
    np.savetxt(
        out_csv,
        np.array(rows_all, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(header),
        comments='',
        encoding='utf-8'
    )

    # batch line
    summary_rows.append([
        base, f"{elemA}-{elemB}", f"{sym[iA]}-{sym[iB]}", DETECTOR_A, round(zref,3),
        outcome,                          # <-- here
        round(pf["d_mol_L3"],3), round(pf["mol_Ekin"],4), int(pf["mol_jrot"]),
        round(pf["d_NO1"],4), round(pf["mol_mCenter_vel"][2],5), round(pf["mol_vel_theta"],2),
        round(pf["mol_Evib_tot"],4)
    ])

# Batch summary
if summary_rows:
    sum_csv = os.path.join(OUT_DIR, "batch_summary.csv")
    # remove the file if it already exist (to avoid appending to old data)
    if os.path.exists(sum_csv):
        os.remove(sum_csv)
        print(f"Removed existing file: {sum_csv}")
    hdr = [
        "file","molecule","diatomic","detector_A","zref_A","outcome(0=scat,1=stick)",
        "final_COMheight_A","final_Ecm_eV","final_jrot","final_d(Å)","final_Vcm_z(Å/fs)","final_Vcm_θ°",
        "final_Evib_tot_eV"
    ]
    np.savetxt(
        sum_csv,
        np.array(summary_rows, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(hdr),
        comments='',
        encoding='utf-8'
    )
    print(f"\nWrote {len(summary_rows)} records to {sum_csv}")
# Out:
# Processing: vasprun-21_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# No ASE velocities found — choosing another method.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-21_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.057
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1254            7.023         106.02       149.3         0              0              0                  0             0        0            0.114           0               0.114       0             0         0
# Turn         540     1.1986            2.358          75.25       150.93       -0.0002         0.00116       -0                 90.15         99.65     0.0021       0.0376          0.0869          0.1245      0.0373       14         0
# End         1157     1.1897            4.528         111.49       290.83       -0.00083        0.00126       -0.00049          108.1         123.54     0.0039       0.018           0.0919          0.11        0.0194       10         0
# Removed existing file: Normal_300K_01eV_results/vasprun-21_full_metrics.csv
#
# Processing: vasprun-20_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-20_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.111
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2218            7.029          87.37        50.88        0              0              0                  0             0        0            0.117           0               0.117       0             0         0
# Turn         553     1.2147            2.289         112.91        62.71       -0.00194       -0.00163        3e-05             89.24        219.96     0.01         0.0885          0.0194          0.1079      0.0194       10         0
# End         1207     1.1326            4.104         108.12       271.12       -0.00209       -0.00196       -0.00274          133.76        223.15     0.0244       0.0788          0.0127          0.0915      0.0086        6         0
# Removed existing file: Normal_300K_01eV_results/vasprun-20_full_metrics.csv
#
# Processing: vasprun-68_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-68_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.233
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.222             6.906          16.07        72.73        0              0               0                 0             0        0            0.118           0               0.118        0            0         0
# Turn         500     1.203             2.406          20.91       205.95       -4e-05         -0.00149        -8e-05            93.21        268.57     0.0035       0.0495          0.0491          0.0985       0.023       11         0
# End         1166     1.1333            5.798         177.17       236.22       -0.00332       -0.00179         0.0027           54.39        208.37     0.0335       0.0758          0.0167          0.0925       0.009        6         0
# Removed existing file: Normal_300K_01eV_results/vasprun-68_full_metrics.csv
#
# Processing: vasprun-69_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-69_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.141
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1251            7.041          42.18       133.08        0              0              0                  0             0        0            0.1156          0               0.1156      0             0         0
# Turn         525     1.2176            2.464          59.74       139.67        0.00058        0.00135       -3e-05             91.34         66.81     0.0034       0.1             0.0295          0.1295      0.0671       19         0
# End         1183     1.1833            4.476         149.99       269.28        0.00058        0.00127       -0.00096          124.34         65.28     0.0045       0.0083          0.1227          0.1309      0.0026        4         0
# Removed existing file: Normal_300K_01eV_results/vasprun-69_full_metrics.csv
#
# Processing: vasprun-56_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-56_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.254
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1787            6.775          75.79       127.54        0              0              0                  0             0        0            0.0035          0               0.0035      0             0         0
# Turn         541     1.2138            1.964          77.54       117.28       -0.00042        0.00019       -5e-05             96.07        155.45     0.0003       0.0854          0.0307          0.1161      0.0017        3         0
# End         1205     1.2163            6.073          82.59       112.8        -0.00201       -0.00076        0.00415           27.34        200.78     0.034        0.0948          0.0078          0.1026      0.0003        1         0
# Removed existing file: Normal_300K_01eV_results/vasprun-56_full_metrics.csv
#
# Processing: vasprun-57_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-57_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.069
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2188            7.017          99.87       316.85        0              0              0                  0             0        0            0.1047          0               0.1047       0            0         0
# Turn         534     1.2267            2.159          86.64       315.65       -0.00071        0.00092        0.00017           81.48        127.45     0.0021       0.1387          0.001           0.1398       0.046       16         0
# End         1135     1.1246            6.849          89.16       348.91        0.00176        0.00159        0.00614           21.14         42.18     0.0673       0.1182          0.0003          0.1184       0.077       19         0
# Removed existing file: Normal_300K_01eV_results/vasprun-57_full_metrics.csv
#
# Processing: vasprun-7_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-7_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.112
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1959            7.033          62.69       174.88        0              0              0                  0             0        0            0.031           0               0.031       0             0         0
# Turn         518     1.1965            2.337          40.64       200.3        -0.00203       -0.00095        0.00011           87.19        205.04     0.0079       0.0324          0.1018          0.1342      0.0417       15         0
# End         1154     1.1863            4.806          50.33        21.75       -0.00383       -0.00117       -0.00016           92.31        197.04     0.025        0.0124          0.1369          0.1492      0.0311       13         0
# Removed existing file: Normal_300K_01eV_results/vasprun-7_full_metrics.csv
#
# Processing: vasprun-6_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-6_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.209
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1923            6.902         153.23       171.63        0              0              0                  0             0        0            0.0231          0               0.0231      0             0         0
# Turn         542     1.1215            2.523         128.28       220.72       -0.00038       -0.00149        0                 89.96        255.71     0.0037       0.1357          0.0002          0.1359      0.0889       20         0
# End         1174     1.2041            4.231         136.93        48.2        -0.00036       -0.00077       -0.00137          148.39        245.12     0.004        0.0528          0.1032          0.156       0.0136        8         0
# Removed existing file: Normal_300K_01eV_results/vasprun-6_full_metrics.csv
#
# Processing: vasprun-62_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-62_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.19
# outcome          stuck(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.167             6.961          85.32       317.12        0              0              0                  0             0        0            0.0006          0               0.0006      0             0         0
# Turn         572     1.1424            2.007          65.34       328.55       -0.00042       -0.00315        4e-05             89.3         262.46     0.0157       0.0419          0.0769          0.1188      0.0517       16         0
# End         1126     1.1731            7.837          29.01         8.44        0.00144       -0.00407        0.01015           23.05        289.45     0.1891       0.0004          0.1154          0.1158      0.004         4         1
# Removed existing file: Normal_300K_01eV_results/vasprun-62_full_metrics.csv
#
# Processing: vasprun-63_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-63_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.259
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1521            6.853          73.79       283.51        0              0              0                  0             0        0            0.0174          0               0.0174      0             0         0
# Turn         538     1.1361            2.111          96.53       269.02        0.00041        0.00036        9e-05             80.25         41.45     0.0005       0.0641          0.0444          0.1085      0.0127        8         0
# End         1210     1.1958            4.903         144.1         43.33        0.00032       -0.00055        0.00039           58.61        299.87     0.0009       0.0307          0.0538          0.0845      0.0176       10         0
# Removed existing file: Normal_300K_01eV_results/vasprun-63_full_metrics.csv
#
# Processing: vasprun-87_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-87_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.285
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.125             6.862         114.38       135.82        0               0             0                  0             0        0            0.1159          0               0.1159      0             0         0
# Turn         540     1.1717            2.122          78.54       134.79       -0.00173         0.0002       -6e-05             91.94        173.48     0.0047       0.0001          0.1193          0.1194      0.1377       26         0
# End         1166     1.1771            4.334          95.46       338.53       -0.00085        -0.0002       -0.00097          137.79        193.44     0.0026       0.0023          0.1249          0.1272      0.0235       11         0
# Removed existing file: Normal_300K_01eV_results/vasprun-87_full_metrics.csv
#
# Processing: vasprun-86_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-86_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.243
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.126             6.921          25.05       310.76        0              0              0                  0             0        0            0.1108          0               0.1108      0             0         0
# Turn         544     1.222             2.472          80.35       312.09       -0.00216        2e-05          2e-05             89.59        179.38     0.0072       0.1178          0.0011          0.1189      0.138        27         0
# End         1186     1.2172            5.126          43.25       143.1        -0.00282        0.00047        0.00136           64.56        170.48     0.0156       0.0985          0.0018          0.1003      0.0185       10         0
# Removed existing file: Normal_300K_01eV_results/vasprun-86_full_metrics.csv
#
# Processing: vasprun-15_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-15_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.169
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1916            6.919         120.69       315.73        0              0              0                  0             0        0            0.0216          0               0.0216      0             0         0
# Turn         544     1.1625            2.233          71.43       305.52       -0.00181       -0.00055        7e-05             88           196.99     0.0056       0.0031          0.0985          0.1016      0.1176       24         0
# End         1179     1.2184            6.855          84.26        94.89       -0.00251        0.00117        0.00575           25.72        155.13     0.0634       0.1029          0.0133          0.1163      0.0216       11         0
# Removed existing file: Normal_300K_01eV_results/vasprun-15_full_metrics.csv
#
# Processing: vasprun-14_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-14_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.145
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.13              6.989         121.32        81.44        0              0              0                  0             0        0            0.0904          0               0.0904      0             0         0
# Turn         554     1.1261            2.164          68.2         81.74        0.00086       -0.0002        -0.0001            96.54        347.13     0.0012       0.1099          0.0036          0.1136      0.0942       21         0
# End         1164     1.1511            5.825          15.51       182.12        0.001         -0.00375        0.00355           47.57        284.98     0.043        0.0194          0.0705          0.0899      0.0477       15         0
# Removed existing file: Normal_300K_01eV_results/vasprun-14_full_metrics.csv
#
# Processing: vasprun-36_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-36_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.21
# outcome          stuck(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1652            6.878         111.29       226.08        0              0               0                 0             0        0            0.0013          0               0.0013      0             0         0
# Turn         536     1.1411            2.085          94.54       231.82        0.00102        0.00139         6e-05            87.96         53.76     0.0046       0.0462          0.0727          0.1188      0.0346       13         0
# End         1080     1.2137            7.718          91.78        67.31        0.00123        0.00108         0.0095            9.78         41.16     0.1445       0.0848          0.0467          0.1315      0.0194       10         1
# Removed existing file: Normal_300K_01eV_results/vasprun-36_full_metrics.csv
#
# Processing: vasprun-37_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-37_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.143
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2061            6.99           59.27       111.24        0              0              0                  0             0        0            0.059           0               0.059       0             0         0
# Turn         549     1.1424            2.254         109.63       103.01        0.00033       -0.00095        0.00013           82.38        289.33     0.0016       0.0421          0.0517          0.0938      0.0347       13         0
# End         1179     1.2116            6.777         136.35       106.68       -0.00046       -0.00142        0.00541           15.41        251.87     0.0489       0.0775          0.0066          0.0841      0.0488       16         0
# Removed existing file: Normal_300K_01eV_results/vasprun-37_full_metrics.csv
#
# Processing: vasprun-41_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-41_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.156
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2004            6.994          59.05        90.21        0              0              0                  0             0        0            0.0422          0               0.0422      0             0         0
# Turn         541     1.2               2.203          68.52       136.34        0.00167        0.00365        7e-05             89.02         65.46     0.025        0.0412          0.0561          0.0973      0.0676       19         0
# End         1193     1.1954            6.12           51.65        76.85        0.00094        0.00402        0.00387           46.87         76.9      0.0498       0.0298          0.0842          0.114       0.0351       13         0
# Removed existing file: Normal_300K_01eV_results/vasprun-41_full_metrics.csv
#
# Processing: vasprun-40_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-40_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.175
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1247            6.956          55.1        162.9         0              0              0                  0             0        0            0.1174          0               0.1174      0             0         0
# Turn         504     1.1911            2.388          36.64       220.16       -0.00253        0.00137       -0.00015           93.02        151.55     0.0129       0.0207          0.0959          0.1166      0.081        20         0
# End         1159     1.128             4.828         121.01       241.88       -0.00308        0.00038       -0.00018           93.37        173.02     0.0151       0.1006          0.0337          0.1343      0.0763       19         0
# Removed existing file: Normal_300K_01eV_results/vasprun-40_full_metrics.csv
#
# Processing: vasprun-75_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-75_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.315
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1256            6.829          42.2         14.72        0              0              0                  0             0        0            0.1125          0               0.1125      0             0         0
# Turn         514     1.1737            2.311          67.42       336.74        0.00109       -0.0004        -5e-05             92.64        339.85     0.0021       0.0006          0.1203          0.1209      0.0698       19         0
# End         1171     1.2263            4.224          33.28       323           0.00052       -0.00025       -0.00182          162.27        334.18     0.0056       0.1371          0.0022          0.1393      0.0396       15         0
# Removed existing file: Normal_300K_01eV_results/vasprun-75_full_metrics.csv
#
# Processing: vasprun-74_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-74_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.157
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2208            6.958         108.29       129.49        0              0              0                  0             0        0            0.1131          0               0.1131      0             0         0
# Turn         533     1.2084            2.013          82.11       114.39        0.00343        0.00022       -0.0001            91.68          3.72     0.0184       0.0663          0.0604          0.1267      0.0173       10         0
# End         1165     1.192             4.577          60.34       275.57        0.00558        0.00037       -0.00109          101.04          3.79     0.0504       0.0224          0.0816          0.104       0.0084        7         0
# Removed existing file: Normal_300K_01eV_results/vasprun-74_full_metrics.csv
#
# Processing: vasprun-90_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-90_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.171
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1246            6.91          140.13       263.16        0              0              0                  0             0        0            0.1181          0               0.1181      0             0         0
# Turn         503     1.1772            2.424         133.25       263.72        0.00146        0.00031       -0.0001            93.83         11.84     0.0035       0.0023          0.1097          0.112       0.0674       18         0
# End         1147     1.1348            5.125         166.43       213.33        0.00205        0.00034        0.00097           64.88          9.33     0.0082       0.0696          0.0157          0.0854      0.1945       30         0
# Removed existing file: Normal_300K_01eV_results/vasprun-90_full_metrics.csv
#
# Processing: vasprun-91_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-91_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.22
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1316            6.976          20.61       226.21        0              0              0                  0             0        0            0.083           0               0.083       0             0         0
# Turn         537     1.1255            2.277          45.84       303.11        0.00077       -0.00229        7e-05             88.36        288.52     0.0091       0.1135          0.0393          0.1528      0.0499       15         0
# End         1165     1.16              5.204         166.34       285.48        0.00072       -0.00209        0.00146           56.58        288.94     0.0109       0.0054          0.1102          0.1156      0.0947       21         0
# Removed existing file: Normal_300K_01eV_results/vasprun-91_full_metrics.csv
#
# Processing: vasprun-78_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-78_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.128
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2147            7.02           95.38       111.2         0              0              0                  0             0        0            0.0885          0               0.0885      0             0         0
# Turn         542     1.1396            2.09           59.86       102.97       -0.00276        0.0001        -3e-05             90.52        177.89     0.0119       0.0514          0.0765          0.1278      0.0215       10         0
# End         1167     1.1456            4.422          12.35       307.79       -0.00351        0.00094       -0.00133          110.04        164.98     0.0233       0.0326          0.1112          0.1438      0.0185        9         0
# Removed existing file: Normal_300K_01eV_results/vasprun-78_full_metrics.csv
#
# Processing: vasprun-79_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-79_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.082
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.166             7.007         156.15         2.31        0              0              0                  0             0        0            0.0009          0               0.0009      0             0         0
# Turn         517     1.1784            2.624         127.3         23.51        0.00158        0.00135        1e-05             89.67         40.49     0.0067       0.0033          0.1051          0.1084      0.1174       24         0
# End         1191     1.2144            5.938         155.5        162.38        0.00122        0.00212        0.00332           36.34         60.11     0.0265       0.0874          0.0116          0.099       0.0161        9         0
# Removed existing file: Normal_300K_01eV_results/vasprun-79_full_metrics.csv
#
# Processing: vasprun-31_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-31_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.247
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2016            6.889         100.72       156.59        0              0               0                 0             0        0            0.0455          0               0.0455      0             0         0
# Turn         547     1.1619            2.013          54.79       181.36       -0.00315        0.00011        -6e-05            91.06        178.01     0.0155       0.0037          0.1179          0.1216      0.0606       17         0
# End         1134     1.123             5.231          72.19        32.54       -0.00252        0.00032         0.0029           41.16        172.85     0.0231       0.1273          0.0008          0.1282      0.0265       11         0
# Removed existing file: Normal_300K_01eV_results/vasprun-31_full_metrics.csv
#
# Processing: vasprun-30_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-30_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.242
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2132            6.817          63.11       128.83        0              0              0                  0             0        0            0.0832          0               0.0832      0             0         0
# Turn         520     1.2126            2.281          60.62       158.75       -0.00208        0.00184       -0.0001            92.04        138.6      0.012        0.0809          0.0486          0.1294      0.0417       15         0
# End         1152     1.1243            6.777           0.57       342.61       -0.00303        0.00213        0.00591           32.09        144.94     0.0756       0.1201          0.0002          0.1203      0.0397       13         0
# Removed existing file: Normal_300K_01eV_results/vasprun-30_full_metrics.csv
#
# Processing: vasprun-100_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-100_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.166
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2175            6.995          36.39       320.49        0              0              0                  0             0        0            0.0993          0               0.0993      0             0         0
# Turn         521     1.1719            2.495          26.2        125.8         0.00161       -0.00083        6e-05             88.12        332.57     0.0051       0.0001          0.1209          0.121       0.0596       17         0
# End         1198     1.2225            3.422          71.52       116.91       -0.00068       -0.00059       -0.00209          156.65        221.02     0.008        0.12            0.0038          0.1238      0.068        19         0
# Removed existing file: Normal_300K_01eV_results/vasprun-100_full_metrics.csv
#
# Processing: vasprun-46_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-46_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.253
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1461            6.836         107.72        59.78         0             0              0                  0             0        0            0.0313          0               0.0313      0             0         0
# Turn         520     1.1269            2.226          80.23        59.2          3e-05         0.00036        6e-05             80.39         84.52     0.0002       0.106           0.0001          0.1061      0.0821       19         0
# End         1193     1.1694            4.253          55.22       326.43         0.0008       -0.0021        -0.00199          131.62        290.9      0.014        0               0.095           0.0951      0.0407       14         0
# Removed existing file: Normal_300K_01eV_results/vasprun-46_full_metrics.csv
#
# Processing: vasprun-47_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-47_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.049
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2049            7.059          65.57        48.81        0              0              0                  0             0        0            0.0553          0               0.0553      0             0         0
# Turn         547     1.1679            2.346          84.1        108.34        0.00235        0.00113        2e-05             89.64         25.65     0.0106       0.0003          0.1282          0.1284      0.0424       14         0
# End         1166     1.159             5.95           81.59         9.7         0.00345        0.00114        0.00348           46.2          18.22     0.0394       0.0066          0.134           0.1405      0.0308       12         0
# Removed existing file: Normal_300K_01eV_results/vasprun-47_full_metrics.csv
#
# Processing: vasprun-72_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-72_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.159
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1258            6.921         142.69       115.09        0              0              0                  0             0        0            0.1118          0               0.1118      0             0         0
# Turn         549     1.171             2.386          95.57       114.19       -0.00045       -0.00037       -4e-05             93.75        219.27     0.0005       0               0.1048          0.1049      0.1278       25         0
# End         1196     1.1265            6.311         148.49       291.95       -0.00143       -0.00223        0.00449           30.51        237.22     0.0423       0.1082          0.0005          0.1087      0.0156        8         0
# Removed existing file: Normal_300K_01eV_results/vasprun-72_full_metrics.csv
#
# Processing: vasprun-73_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-73_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.138
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1412            7.009          29.6        319.63        0              0              0                   0            0        0            0.046           0               0.046       0             0         0
# Turn         492     1.1897            2.643          26.04       331.97       -0.00143       -0.00011       -4e-05              91.7        184.59     0.0032       0.018           0.1129          0.1309      0.0877       21         0
# End         1159     1.2205            3.566         104.06       339.78       -0.00154       -0.00049       -0.00369           156.3        197.78     0.0253       0.1117          0.0228          0.1344      0.232        35         0
# Removed existing file: Normal_300K_01eV_results/vasprun-73_full_metrics.csv
#
# Processing: vasprun-97_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-97_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.131
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1768            6.984         108.47       136.46        0              0               0                 0             0        0            0.0021          0               0.0021      0             0         0
# Turn         533     1.2205            2.212          79.46       123.41        0.00166       -0.00165        -0.0001           92.34        315.25     0.0085       0.1116          0.0229          0.1345      0.017        10         0
# End         1163     1.1933            4.206         101.54       151.77        0.00314       -0.00071        -0.0021          123.14        347.34     0.023        0.0252          0.0862          0.1114      0.0419       15         0
# Removed existing file: Normal_300K_01eV_results/vasprun-97_full_metrics.csv
#
# Processing: vasprun-96_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-96_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.157
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.143             6.958         110.16       296.74        0              0              0                  0             0        0            0.0402          0               0.0402      0             0         0
# Turn         538     1.1278            2.03           72.69       295.23       -0.00352       -7e-05          0.0001            88.33        181.11     0.0193       0.1011          0.0012          0.1023      0.0021        3         0
# End         1177     1.1318            5.768          40.19       112.09       -0.00439       -0.00371        0.00279           64.11        220.18     0.0634       0.0824          0.0314          0.1138      0.0147        8         0
# Removed existing file: Normal_300K_01eV_results/vasprun-96_full_metrics.csv
#
# Processing: vasprun-26_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-26_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.249
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2036            6.866          68.1        202.79        0              0              0                  0             0        0            0.0513          0               0.0513      0             0         0
# Turn         525     1.1262            2.178          99.55       218.07       -0.00135       -0.00053       -0.00012           94.59        201.53     0.0033       0.1097          0.0383          0.148       0.0287       11         0
# End         1172     1.1302            4.143         147.12       184.02       -0.00271       -0.00284       -0.00202          117.26        226.35     0.0303       0.0898          0.0232          0.1131      0.0376       13         0
# Removed existing file: Normal_300K_01eV_results/vasprun-26_full_metrics.csv
#
# Processing: vasprun-27_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-27_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.15
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1741            6.997          59.64       356.51        0              0              0                  0             0        0            0.0007          0               0.0007      0             0         0
# Turn         551     1.1273            2.246         107.52        17.03       -3e-05         -0.00051       -0.00012          102.97        266.15     0.0004       0.104           0.0159          0.1199      0.0392       13         0
# End         1172     1.1437            6.512         114.11        18.6         0.00052       -0.00081        0.00506           10.81        302.68     0.0413       0.0382          0.0885          0.1267      0.0643       17         0
# Removed existing file: Normal_300K_01eV_results/vasprun-27_full_metrics.csv
#
# Processing: vasprun-18_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-18_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.173
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1277            6.822         112.43       201.84        0              0                0                0             0        0            0.1018          0               0.1018      0             0         0
# Turn         504     1.1558            2.574          59.37       204.87       -0.00139       -0.0013          -3e-05           90.84        223.1      0.0056       0.0109          0.1113          0.1222      0.0968       22         0
# ...
# detector_A       7.0
# graphite_zref_A  7.075
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1806            7.026         125.28       346.9         0              0              0                  0             0        0            0.0052          0               0.0052      0             0         0
# Turn         518     1.2006            2.414         118.71         0.05        0.00064        0.00044        0.00011           81.84         34.51     0.0009       0.0429          0.0628          0.1057      0.0683       19         0
# End         1199     1.2181            6.085          31.4         10.17        0.00163        0.00044        0.00344           26.11         15.28     0.0229       0.1017          0.02            0.1217      0.0578       18         0
# Removed existing file: Normal_300K_01eV_results/vasprun-52_full_metrics.csv
#
# Processing: vasprun-53_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-53_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.283
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2163            6.874          98.04        42.66        0              0              0                  0             0        0            0.0949          0               0.0949      0             0         0
# Turn         538     1.1959            1.976          73.43        44.02        0.00076       -0.00053       -5e-05             93.35        325.07     0.0013       0.031           0.0911          0.1221      0.0078        6         0
# End         1150     1.1285            5.429          69.4        355.22        0.00263       -0.00037        0.00299           41.55        352.08     0.0248       0.0977          0.0461          0.1438      0.0513       15         0
# Removed existing file: Normal_300K_01eV_results/vasprun-53_full_metrics.csv
#
# Processing: vasprun-38_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-38_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.21
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1341            6.926         120.92       116.44        0              0              0                  0             0        0            0.0722          0               0.0722      0             0         0
# Turn         539     1.1546            2.18           86.01       100.24       -0.00014       -0.00107       -9e-05             94.71        262.35     0.0018       0.0128          0.1218          0.1347      0.1084       23         0
# End         1140     1.1637            6.611         150.93       203.51       -0.00123       -0.00058        0.00608           12.59        205.1      0.0604       0.0022          0.1458          0.148       0.0242       11         0
# Removed existing file: Normal_300K_01eV_results/vasprun-38_full_metrics.csv
#
# Processing: vasprun-39_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-39_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.228
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1252            6.904          25.54       116.31        0               0             0                  0             0        0            0.1149          0               0.1149      0             0         0
# Turn         501     1.1572            2.564          21.26       147.95        6e-05           0.0004        0                 89.48         81.55     0.0003       0.0089          0.1123          0.1212      0.039        14         0
# End         1192     1.228             3.3            30.18       149.63        0.00167         6e-05        -0.00134          128.73          2.08     0.0071       0.1449          0.002           0.1469      0.1494       28         0
# Removed existing file: Normal_300K_01eV_results/vasprun-39_full_metrics.csv
#
# Processing: vasprun-71_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-71_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.173
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1732            6.898         168.63       195.29        0              0              0                  0             0        0            0.0004          0               0.0004      0             0         0
# Turn         492     1.1437            2.642         156.25       161.95       -0.00177        0.00112       -0                 90.05        147.72     0.0068       0.0381          0.0767          0.1148      0.0653       17         0
# End         1191     1.127             3.979         141.43       156.16       -0.00226        0.0018        -0.00262          132.18        141.46     0.0237       0.1057          0.0251          0.1308      0.0348       13         0
# Removed existing file: Normal_300K_01eV_results/vasprun-71_full_metrics.csv
#
# Processing: vasprun-70_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-70_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.28
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.128             6.872         102.35       258.45        0              0              0                  0             0        0            0.1005          0               0.1005      0             0         0
# Turn         531     1.1974            1.965          82.51       260.29        0.00161        0.00155       -1e-05             90.14         43.94     0.0078       0.0345          0.0731          0.1076      0.0074        6         0
# End         1254     1.1435            2.902          87.01       107.49        0.00227        0.00129       -0.00091          109.16         29.59     0.0118       0.0386          0.0819          0.1205      0.0113        7         0
# Removed existing file: Normal_300K_01eV_results/vasprun-70_full_metrics.csv
#
# Processing: vasprun-94_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-94_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.175
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1485            6.982          49.27       152.02        0              0              0                  0             0        0            0.0251          0               0.0251      0             0         0
# Turn         518     1.1361            2.6            39.24       138.49       -0.00274        0.00166        3e-05             89.5         148.73     0.0159       0.0642          0.0757          0.1398      0.0189        9         0
# End         1215     1.1365            3.265         108.56       148.62       -0.0023         0.00192       -0.00162          118.39        140.21     0.018        0.0626          0.0906          0.1532      0.0757       19         0
# Removed existing file: Normal_300K_01eV_results/vasprun-94_full_metrics.csv
#
# Processing: vasprun-95_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-95_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.207
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1398            6.981           8.49       145.44        0              0              0                  0             0        0            0.0506          0               0.0506      0             0         0
# Turn         494     1.1634            2.775          15.37        65.5        -0.00071       -0.00018       -2e-05             91.84        194.02     0.0008       0.0024          0.1344          0.1368      0.0195       10         0
# End         1195     1.171             3.935         127.14        74.48       -0.00096       -0.00097        0.00113           50.34        225.31     0.0049       0               0.1391          0.1391      0.0695       18         0
# Removed existing file: Normal_300K_01eV_results/vasprun-95_full_metrics.csv
#
# Processing: vasprun-32_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-32_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.176
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1445            6.959          48.62        34.64        0              0               0                 0             0        0            0.0358          0               0.0358      0             0         0
# Turn         531     1.1489            2.454          82.56        31.79       -0.00082       -0.00071        -1e-05            90.3         221.12     0.0018       0.0244          0.1042          0.1286      0.2027       31         0
# End         1166     1.2023            4.93           21.3        307.04       -0.00064        0.00053         0.0005           59.29        140.25     0.0015       0.0475          0.115           0.1625      0.0328       13         0
# Removed existing file: Normal_300K_01eV_results/vasprun-32_full_metrics.csv
#
# Processing: vasprun-33_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-33_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.207
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1271            6.841          59.25       118.3         0              0              0                  0             0        0            0.1051          0               0.1051      0             0         0
# Turn         501     1.1265            2.385          85.84       103.3        -0.00115        6e-05          8e-05             86.13        177.09     0.0021       0.1082          0.0023          0.1106      0.0312       12         0
# End         1222     1.2158            3.212          93.18       289.42       -0.00115        0.00064       -0.00586          167.31        151        0.056        0.0927          0.0153          0.108       0.0019        3         0
# Removed existing file: Normal_300K_01eV_results/vasprun-33_full_metrics.csv
#
# Processing: vasprun-45_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-45_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.282
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.222             6.837         111.93       323.36        0              0              0                  0             0        0            0.1182          0               0.1182      0             0         0
# Turn         538     1.2078            1.97           78.35       329.32       -0.00176       -0.00052        3e-05             89.14        196.52     0.0052       0.0643          0.0463          0.1106      0.0008        2         0
# End         1191     1.1564            3.739          73.08       142.68       -0.00186        0.00019       -0.00346          151.62        174.23     0.024        0.01            0.0834          0.0934      0.0105        7         0
# Removed existing file: Normal_300K_01eV_results/vasprun-45_full_metrics.csv
#
# Processing: vasprun-44_full.xml
#
# Using diatomic atoms 0,1 (N-O)
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-44_full.xml
# molecule         N-O
# diatomic         0,1 (N-O)
# detector_A       7.0
# graphite_zref_A  7.234
# outcome          scattered(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.1257            6.941          63.94       176.67        0              0              0                  0             0        0            0.1123          0               0.1123      0             0         0
# Turn         551     1.1611            2.173         110.98       183.08        0.0002        -0.00092       -3e-05             91.88        282.34     0.0014       0.0043          0.1229          0.1272      0.0394       14         0
# End         1167     1.1937            3.768         126.76       322.62       -0.00081       -0.00121       -0.00335          156.49        236.25     0.0208       0.026           0.1181          0.144       0.0182       10         0
# Removed existing file: Normal_300K_01eV_results/vasprun-44_full_metrics.csv
# Removed existing file: Normal_300K_01eV_results/batch_summary.csv
#
# Wrote 100 records to Normal_300K_01eV_results/batch_summary.csv
