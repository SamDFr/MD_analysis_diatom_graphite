# %% [markdown]
# # NO Scattering Analysis — Notebook Documentation
#
# ## Purpose
# Analyze diatomic scattering trajectories on a graphite slab.
# Compute center-of-mass (COM) kinematics, rotational/vibrational energies, bond geometry, and outcome labels.
# Export per-frame metrics and a batch summary for all input files.
#
# ---
#
# ## Scope and Assumptions
# - **System:** Diatomic molecule, default `NO` (supports homonuclear like `O2`).
# - **Formats:** VASP `vasprun.xml` and text LAMMPS dumps (`.lammpstrj` / `.dump`). XYZ supported for positions.
# - **Velocities:** Uses stored velocities if present. Falls back to finite-difference if missing.
# - **Surface:** Graphite slab. Top reference plane estimated from top C layer.
#
# ---
#
# ## Inputs
# - Directory pattern:
#   `base_dir = "{Incidence}_{Temperature}K_{Energy}eV_vasp_files/"`
# - Files discovered by extension: `.xyz`, `.lammpstrj`, `.xml`, `OUTCAR`, `.dump`
# - Key user config (edit in the header cell):
#   - `incidence` (`'Normal'`), `temperature` (K), `energy` (eV string like `'01'`)
#   - `file_format` (`'VASP'` info only)
#   - `molecule` (`'NO'`, `'CO'`, `'O2'`, `'N2'`)
#   - `DETECTOR_A` (Å): height threshold to count as “scattered”
#   - `DIATOM_IDS` (tuple or `None`): force atom indices if known
#   - `N_MIN_FRAMES` (int): require sufficient frames before labeling scatter
#   - **LAMMPS helpers:** `SPECORDER`, `TIMESTEP_FS`, `DUMP_STRIDE`, `VEL_UNITS`
#
# ---
#
# ## Outputs
# Writes to `OUT_DIR = "{Incidence}_{Temperature}K_{Energy}eV_results"`:
#
# 1. **Per-trajectory CSV:** `<file>_metrics.csv`
#    Per-frame measurements with labeled “Start/Turn/End/Frame”.
# 2. **Batch summary:** `batch_summary.csv`
#    One line per trajectory with final-frame indicators.
#
# Old files are removed before writing.
#
# ---
#
# ## Dependencies
# - Python 3, NumPy, ASE
# - Optional: MDAnalysis (reads velocities from LAMMPS dumps), `tabulate` (prettified console tables)
#
# ```bash
# pip install numpy ase MDAnalysis tabulate

# %%
import os, sys, numpy as np
from math import sqrt
from ase.io import read
from ase.io.vasp import read_vasp_xml
from ase.data import atomic_masses, chemical_symbols
# Optional tabulate helper
sys.path.append(os.path.expanduser('~/bin/tabulate'))
try:
    from tabulate import tabulate
except Exception:
    tabulate = None

# %%
###########################################
# Units and constants
###########################################
# ========================================
# CONSTANTES CORRECTES (du code original)
# ========================================
# Conversions FROM atomic units
autoev   = 27.211383858491185
autofs   = 0.02418884326505      # a.u. time → fs
autoan   = 0.52917720859         # bohr → Å
autoamu  = 0.0005485799092659504
autoanf  = 21.876912541518593    # a.u. velocity → Å/fs

# Conversions TO atomic units
evtoau   = 0.03674932540
fstoau   = 41.341373336561364
antoau   = 1.8897261328856432
amutoau  = 1822.888485540950
anftoau  = 0.045710289242239875  # Å/fs → a.u. velocity

# %%
###########################################
# User config
###########################################

incidence   = 'Normal'
temperature = 110        # K
energy      = '02'       # eV
file_format = 'VASP'     # 'LAMMPS'   # info only
molecule    = 'O2'       # e.g. 'NO','CO','O2','N2'
DETECTOR_A  = 7.0        # Å
#DIATOM_IDS  = None      # e.g., (0,1)
DIATOM_IDS  = (0,1)      # e.g., (0,1)
N_MIN_FRAMES = 50   # require at least 50 frames before counting as scattered

# --- LAMMPS mapping and timing ---
SPECORDER   = ['N','O','C']  # type 1=N, 2=O, 3=C. Adjust to your dump.
TIMESTEP_FS = 1.0            # MD timestep in fs
DUMP_STRIDE = 1             # steps between dumped frames
DT_FS       = TIMESTEP_FS * DUMP_STRIDE  # finite-diff dt if no velocities
VEL_UNITS   = 'A_per_ps'     # 'A_per_fs' or 'A_per_ps'

#base_dir = f"{incidence}_{int(temperature)}K_{energy}eV_vasp_files/"
#base_dir = f"./data/AL1/{incidence}_{int(temperature)}K_{energy}eV/1000traj"
base_dir = f"./data/vaspdata.Ei.0.2.Ts.110.O2.parx.nozpe"

INPUT_FILES = [
    os.path.join(base_dir, f)
    for f in os.listdir(base_dir)
    if f.endswith(('.xyz', '.lammpstrj', '.xml', 'OUTCAR', '.dump'))
]
print(f"Found {len(INPUT_FILES)} input files. format={file_format}")
OUT_DIR = f"results/{incidence}_{temperature}K_{energy}eV_results"
os.makedirs(OUT_DIR, exist_ok=True)

# Define element composition from molecule string
molecule = molecule.strip().upper()
if len(molecule) == 2 and not molecule[1].isdigit():  # e.g. 'NO'
    elemA, elemB = molecule[0], molecule[1]
elif len(molecule) == 2 and molecule[1].isdigit():    # e.g. 'O2'
    elemA, elemB = molecule[0], molecule[0]
else:
    raise ValueError(f"Unsupported diatomic format: {molecule}")
print(f"Molecule: {elemA}-{elemB}")

mA_default = atomic_masses[chemical_symbols.index(elemA)]
mB_default = atomic_masses[chemical_symbols.index(elemB)]
print(f"Masses: {elemA}={mA_default:.4f} amu, {elemB}={mB_default:.4f} amu")
# Out:
# Found 80 input files. format=VASP
# Molecule: O-O
# Masses: O=15.9990 amu, O=15.9990 amu

# %%
###########################################
# Helpers  (PBC-aware, NO only outputs)
###########################################

def file_kind(path):
    n = os.path.basename(path).lower()
    if n.endswith('.lammpstrj') or n.endswith('.dump') or 'lammpstrj' in n:
        return 'lammps-dump-text'
        #return "LAMMPSDUMP"
    if n == 'outcar':
        return 'vasp-outcar'
    if n.endswith('.xml') or n == 'vasprun.xml':
        return 'vasp-xml'
    if n.endswith('.xyz'):
        return 'xyz'
    return 'auto'

def load_frames(path):
    """Return list[Atoms]. Uses ASE readers. Adds no extra arrays."""
    kind = file_kind(path)

    if kind == 'lammps-dump-text':
        frames = read(path, format='lammps-dump-text', index=":", specorder=SPECORDER)
        # Try to get velocities via MDAnalysis
        import MDAnalysis as mda
        u = mda.Universe(path, format="LAMMPSDUMP")
        n_frames = len(u.trajectory)
        n_atoms = u.atoms.n_atoms
        V = np.empty((n_frames, n_atoms, 3), dtype=np.float64) if u.trajectory.ts.has_velocities else None

        for i, ts in enumerate(u.trajectory):
            if V is not None:
                vel = u.atoms.velocities
                if vel is None:
                    if i == 0:
                        print("No velocities found; skipping velocity extraction.")
                    V = None
                else:
                    V[i] = vel
        for i, atoms in enumerate(frames):
            atoms.set_velocities(V[i])

    if kind == 'vasp-xml':
        frames = read(path, index=":")
    return frames if isinstance(frames, list) else [frames]



def get_velocities(at, vel_units='A_per_ps'):
    """
    Return per-atom velocities in Å/fs.

    Order of preference:
      1) ASE internal velocities (Atoms.get_velocities)
      2) vx,vy,vz arrays (LAMMPS, usually Å/ps)
      3) 'velocities' or 'velocity' arrays (Å/fs)
      4) 'momenta' (amu·Å/fs) divided by atomic masses
    """
    import numpy as np

        # static attribute to avoid re-printing
    if not hasattr(get_velocities, "_ase_vel_printed"):
        get_velocities._ase_vel_printed = False

    arr = at.arrays
    v = None

    # 1) ASE internal velocities
    try:
        v = at.get_velocities()
        if v is not None and np.any(v): # si v est pas "None" et different de 0
            if not get_velocities._ase_vel_printed:
                print("Using ASE internal velocities.")
                get_velocities._ase_vel_printed = True
                
            if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
                v = np.asarray(v, float) / 1000.0
            return np.asarray(v, float)
        else:
            if not get_velocities._ase_vel_printed:
                print("No ASE velocities found — choosing another method.")
                get_velocities._ase_vel_printed = True
    except Exception:
        if not get_velocities._ase_vel_printed:
            print("No ASE velocities found — choosing another method.")
            get_velocities._ase_vel_printed = True

    # 2) explicit vx,vy,vz (LAMMPS)
    if all(k in arr for k in ('vx', 'vy', 'vz')):
        if not get_velocities._ase_vel_printed:
            print("Using 'vx','vy','vz' arrays.")
            get_velocities._ase_vel_printed = True
        v = np.column_stack((arr['vx'], arr['vy'], arr['vz'])).astype(float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 3) velocities arrays (ASE)
    if 'velocities' in arr or 'velocity' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'velocities' or 'velocity' array.")
            get_velocities._ase_vel_printed = True
        v = np.asarray(arr.get('velocities', arr.get('velocity')), float)
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    # 4) momenta → velocities
    if 'momenta' in arr:
        if not get_velocities._ase_vel_printed:
            print("Using 'momenta' array to compute velocities.")
            get_velocities._ase_vel_printed = True
        m = at.get_masses()[:, None]
        p = np.asarray(arr['momenta'], float)
        v = p / m
        if vel_units == 'A_per_ps':
            v /= 1000.0
        return v

    if not get_velocities._ase_vel_printed:
        print("No velocity data found in any source.")
        get_velocities._ase_vel_printed = True
        
    return None

def _mic(dr, cell, pbc):
    if cell is None or not np.any(pbc):
        return dr
    from ase.geometry import find_mic
    mic_dr, _ = find_mic(dr, cell=cell, pbc=pbc)
    return mic_dr

def finite_diff_vel(frames, dt_fs, vel_units='A_per_fs'):
    print("CAREFUL - using finite-difference velocities!")
    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()
    pos = [f.get_positions() for f in frames]
    v = [np.zeros_like(pos[0])]
    for k in range(1, len(frames)-1):
        dr = pos[k+1] - pos[k-1]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/(2.0*dt_fs))
    if len(frames) > 1:
        dr = pos[-1] - pos[-2]
        for i in range(dr.shape[0]):
            dr[i] = _mic(dr[i], cell, pbc)
        v.append(dr/dt_fs)
    if vel_units == 'A_per_ps':  # convert Å/ps → Å/fs
        v /= 1000.
    return v

def _lz(at) -> float:
    # Works for non-orthorhombic too
    return float(np.linalg.norm(at.cell[2]))

def slab_reference_z(at, simple=False, top_tol=0.10, probe_z=None):
    """
    Reference z for a graphite slab.

    If probe_z is None:
        Original behavior (simple=True: mean near global zmax; else k=3 z-clustering).
    If probe_z is not None:
        Return the average z of C atoms within top_tol Å of the highest C layer
        that is *below or equal to* probe_z, using minimum-image wrapping on z.
        Excludes atoms 0 and 1.
    """
    pos = at.get_positions()
    Z   = at.get_atomic_numbers()

    Cidx = np.where(Z == 6)[0]
    Cidx = Cidx[(Cidx != 0) & (Cidx != 1)]
    if Cidx.size == 0:
        return float(np.percentile(pos[:, 2], 10))

    Cz = pos[Cidx, 2].astype(float)

    # ---- New path: reference layer below a probe, PBC-safe
    if probe_z is not None:
        pbc = at.get_pbc()
        Lz  = _lz(at)
        dz = Cz - float(probe_z)
        if pbc[2] and Lz > 0.0:
            dz -= np.rint(dz / Lz) * Lz  # minimum-image along z

        below = dz <= 0.0
        if not np.any(below):
            # Edge case: everything wrapped above. Shift once.
            dz -= Lz
            below = dz <= 0.0
            if not np.any(below):
                # Fallback: use classic top-of-C around global max
                zmax = float(Cz.max())
                band = Cz[Cz >= zmax - float(top_tol)]
                return float(band.mean() if band.size else zmax)

        dz_below = dz[below]
        z_ref = float(probe_z + np.max(dz_below))

        # Average a thin band for robustness
        Cz_unwrapped_below = probe_z + dz_below
        band = np.abs(Cz_unwrapped_below - z_ref) <= float(top_tol)
        return float(Cz_unwrapped_below[band].mean()) if np.any(band) else z_ref

    # ---- Old behavior unchanged below
    if Cz.size < 3:
        return float(Cz.mean())

    if simple:
        zmax = float(Cz.max())
        top = Cz[Cz >= zmax - float(top_tol)]
        return float(top.mean()) if top.size else zmax

    # k=3 clustering on z
    k = 3
    cent = np.percentile(Cz, [10, 50, 90]).astype(float)
    for _ in range(15):
        d = np.abs(Cz[:, None] - cent[None, :])
        lab = np.argmin(d, axis=1)
        new_cent = np.array([Cz[lab == i].mean() if np.any(lab == i) else cent[i] for i in range(k)])
        if np.allclose(new_cent, cent):
            break
        cent = new_cent
    top_cluster = int(np.argmax(cent))
    top_vals = Cz[lab == top_cluster]
    if top_vals.size == 0:
        top_vals = Cz[Cz >= np.percentile(Cz, 80)]
    return float(top_vals.mean() if top_vals.size else Cz.mean())

def pick_NO_indices(at, id_pair=(1, 2), type_pair=(1, 2), elem_pair=('N','O')):
    ids   = at.arrays.get('id')
    types = at.arrays.get('type')
    if ids is not None and id_pair is not None:
        wN = np.where(ids == id_pair[0])[0]
        wO = np.where(ids == id_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if types is not None and type_pair is not None:
        wN = np.where(types == type_pair[0])[0]
        wO = np.where(types == type_pair[1])[0]
        if wN.size and wO.size:
            return int(wN[0]), int(wO[0])
    if elem_pair is not None:
        sym = at.get_chemical_symbols()
        try:
            iN = next(i for i,s in enumerate(sym) if s == elem_pair[0])
            iO = next(i for i,s in enumerate(sym) if s == elem_pair[1])
            return (iN, iO)
        except StopIteration:
            pass
    return None

def com(masses, pos):
    M = np.sum(masses)
    return (pos * masses[:,None]).sum(0) / M

def safe_acos_deg(x):
    return np.degrees(np.arccos(np.clip(x, -1.0, 1.0)))

# %%
def diatomic_properties(Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, slab_z_ref,
                        detector_A=None, cell=None, pbc=None, De=None, a=None, re=None):
    # MIC bond in Å
    dAB = Bpos - Apos
    rAB_A = dAB if (cell is None or pbc is None) else _mic(dAB, cell, pbc)
    Bpos_contig = Apos + rAB_A

    # to a.u.
    qA, qB = Apos * antoau, Bpos_contig * antoau
    vA, vB = Avel * anftoau, Bvel * anftoau
    mA, mB = mA_amu * amutoau, mB_amu * amutoau
    ## test 

    # geometry + COM
    rAB  = qB - qA
    r    = np.linalg.norm(rAB) if np.any(rAB) else 1.0
    rhat = rAB / r
    M    = mA + mB
    Rcm  = (mA*qA + mB*qB) / M
    Vcm  = (mA*vA + mB*vB) / M

    # reduced motion
    mu    = (mA*mB) / M
    vrel  = vB - vA
    p_rel = mu * vrel
    p_par = float(np.dot(p_rel, rhat))
    #L_vec = np.cross(p_rel, rAB)
    L_vec = np.cross(rAB, p_rel)
    L2    = float(np.dot(L_vec, L_vec))

    # energies (a.u.)
    Ecm_au  = 0.5 * M * np.dot(Vcm, Vcm)
    Evib_au = 0.5 * (p_par**2) / mu
    Erot_au = 0.5 * L2 / (mu * r**2)

    # optional Morse (eV): r in Å here
    mol_Epot_eV = De * (1.0 - np.exp(-a * (r/antoau - re)))**2 if (De is not None and a is not None and re is not None) else 0.0

    # back to lab
    com_A   = (Rcm / antoau).tolist()
    vcm_Af  = (Vcm / anftoau).tolist()  # <--- CORRECT : utiliser anftoau pour reconvertir
    d_NO1_A = r / antoau
    heightA = (Rcm / antoau)[2] - slab_z_ref

    # orientations
    def cart2sph(v):
        R = np.linalg.norm(v)
        if R == 0:
            return (0.0, 0.0, 0.0)
            #return None
        theta = np.degrees(np.arccos(np.clip(v[2]/R, -1.0, 1.0)))  # angle from +z
        phi   = np.degrees(np.arctan2(v[1], v[0])) % 360.0
        return (R, theta, phi)

    # match get_Params:
    # - NO1_theta/phi from O position relative to COM
    O_rel_cm = qB - Rcm
    _, NO1_theta_deg, NO1_phi_deg = cart2sph(O_rel_cm)

    # - *_a variants from the bond vector rAB
    NO1_theta_a = safe_acos_deg(rAB[2] / r)
    #NO1_phi_a   = np.degrees(np.arccos(np.clip(rAB[0] / np.linalg.norm([rAB[0], rAB[1], 0.0]), -1.0, 1.0))) if (rAB[0] or rAB[1]) else 0.0
    NO1_phi_a = float((np.degrees(np.arctan2(rAB[1], rAB[0])) + 360.0) % 360.0) if (rAB[0] or rAB[1]) else 0.0

    # velocity orientation from COM velocity
    _, vel_theta_deg, vel_phi_deg = cart2sph(Vcm)
    Vcm_norm = np.linalg.norm(Vcm)
    vel_theta_a = safe_acos_deg(Vcm[2] / Vcm_norm) if Vcm_norm > 0 else 0.0
    #vel_phi_a   = np.degrees(np.arccos(np.clip(Vcm[0] / np.linalg.norm([Vcm[0], Vcm[1], 0.0]), -1.0, 1.0))) if (Vcm[0] or Vcm[1]) else 0.0
    vel_phi_a = float((np.degrees(np.arctan2(Vcm[1], Vcm[0])) + 360.0) % 360.0) if (Vcm[0] or Vcm[1]) else 0.0

    # j from |L| (ħ=1 in a.u.)
    L_norm    = np.sqrt(L2)
    jrot_cont = 0.5 * (-1.0 + np.sqrt(1.0 + 4.0 * L_norm**2))
    #jrot      = float(np.ceil(jrot_cont))
    jrot = float(np.rint(jrot_cont))  # round to nearest

    # channel: 1 emitted, 0 adsorbed
    output_CH = 1 if (detector_A is not None and heightA >= detector_A) else 0

    return {
        'output'          : output_CH,
        'mol_massCenter'  : com_A,
        'mol_mCenter_vel' : vcm_Af,
        'mol_jrot'        : jrot,
        'NO1_theta'       : round(NO1_theta_deg, 2),   # O relative to COM
        'NO1_phi'         : round(NO1_phi_deg, 2),
        'NO1_theta_a'     : round(NO1_theta_a, 2),     # bond-based
        'NO1_phi_a'       : round(NO1_phi_a, 2),
        'd_NO1'           : round(d_NO1_A, 4),
        'd_mol_L3'        : round(heightA, 4),
        'mol_vel_theta'   : round(vel_theta_deg, 2),
        'mol_vel_phi'     : round(vel_phi_deg, 2),
        'mol_vel_theta_a' : round(vel_theta_a, 2),
        'mol_vel_phi_a'   : round(vel_phi_a, 2),
        'mol_Ekin'        : round(Ecm_au * autoev, 4),  # COM kinetic (Ecm)
        'mol_Epot'        : round(mol_Epot_eV, 4),
        'mol_Evib_cin'   : round(Evib_au * autoev, 4),
        'mol_Erot'       : round(Erot_au * autoev, 4),
        'mol_Evib_tot'   : round((Evib_au * autoev + mol_Epot_eV), 4)
    }

# %%
###########################################
# Load and analyze  (NO only, PBC-aware)
###########################################

summary_rows = []

for INPUT_FILE in INPUT_FILES:
    print(f"\nProcessing: {os.path.basename(INPUT_FILE)}")
    kind   = file_kind(INPUT_FILE)
    frames = load_frames(INPUT_FILE)
    print()

    if frames is None:
        print("Skip: no frames loaded.")
        continue
    
    if len(frames) < 2:
        print("Skip: need ≥2 frames.")
        continue

    # --- Identify NO atoms
    if DIATOM_IDS is not None:
        iA, iB = DIATOM_IDS
    else:
        ids = pick_NO_indices(frames[0], id_pair=(1,2), type_pair=(1,2), elem_pair=('N','O'))
        if ids is None:
            raise RuntimeError("NO atoms not found")
        iA, iB = ids

    sym = frames[0].get_chemical_symbols()
    print(f"Using diatomic atoms {iA},{iB} ({sym[iA]}-{sym[iB]})")

    # --- Masses (amu)
    mA_amu = mA_default
    mB_amu = mB_default

    # --- Velocities (Å/fs)
    vel_list, need_fd = [], []
    for k, at in enumerate(frames):
        v = get_velocities(at, vel_units=VEL_UNITS)
        bad = (v is None) or (not np.isfinite(v).all()) or np.allclose(v, 0.0)
        vel_list.append(None if bad else v)
        need_fd.append(bad)
    if any(need_fd):
        print("Computing finite-difference velocities for missing frames.")
        fd = finite_diff_vel(frames, DT_FS)
        for k, bad in enumerate(need_fd):
            if bad:
                vel_list[k] = fd[k]

    # --- Helper: probe_z = lower NO atom or COM
    def probe_z(at, use_min_atom=True):
        zA, zB = at.positions[iA, 2], at.positions[iB, 2]
        if use_min_atom:
            return float(min(zA, zB))
        masses = np.array([mA_amu, mB_amu], float)
        return float(com(masses, at.positions[[iA, iB]])[2])

    # --- Reference z for first frame (for reporting)
    zref0 = slab_reference_z(frames[0], top_tol=0.10, probe_z=probe_z(frames[0]))

    # --- Heights of probe over the slab (per frame)
    heights = []
    for at in frames:
        z_probe = probe_z(at, use_min_atom=True)
        zref_k  = slab_reference_z(at, top_tol=0.10, probe_z=z_probe)
        heights.append(max(0.0, z_probe - zref_k))
    heights  = np.array(heights, float)
    turn_idx = int(np.argmin(heights))

    cell = frames[0].get_cell()
    pbc  = frames[0].get_pbc()

    # --- Optional Morse parameters for NO
    De, a, re = [7.645438936565258, 2.565143344509797, 1.17028471793808]

    # --- Frame-wise properties
    def props_at(k):
        at = frames[k]
        pos = at.get_positions()
        Apos, Bpos = pos[iA], pos[iB]
        Avel, Bvel = vel_list[k][iA], vel_list[k][iB]
        z_probe = probe_z(at, use_min_atom=True)
        zref_k  = slab_reference_z(at, top_tol=0.10, probe_z=z_probe)
        return diatomic_properties(
            Apos, Bpos, Avel, Bvel, mA_amu, mB_amu, zref_k,
            detector_A=DETECTOR_A, cell=cell, pbc=pbc,
            De=De, a=a, re=re
        )

    props = [props_at(k) for k in range(len(frames))]
    pf = props[-1]

    # --- Scatter criterion
    far_enough = pf["d_mol_L3"] >= DETECTOR_A
    after_50frames = len(frames) > N_MIN_FRAMES
    outcome = 1 if (far_enough and after_50frames) else 0  # 1=scatter, 0=stick

    # --- Output headers
    header = [
        "state","t_idx","d_NO(Å)","COM_z-ztop(Å)","NO_theta(°)","NO_phi(°)",
        "Vcm_x(Å/fs)","Vcm_y(Å/fs)","Vcm_z(Å/fs)",
        "Vcm_theta(°)","Vcm_phi(°)",
        "Ecm(eV)","E_pot(eV)","Evib_cin(eV)","Evib_tot(eV)",
        "Erot(eV)","j_rot","output"
    ]

    # --- Row builder
    def row(label, idx, p):
        out_flag = 1 if (p["d_mol_L3"] >= DETECTOR_A and idx > N_MIN_FRAMES) else 0
        return [
            label, idx,
            round(p["d_NO1"],4), round(p["d_mol_L3"],3),
            round(p["NO1_theta"],2), round(p["NO1_phi"],2),
            round(p["mol_mCenter_vel"][0],5), round(p["mol_mCenter_vel"][1],5), round(p["mol_mCenter_vel"][2],5),
            round(p["mol_vel_theta"],2), round(p["mol_vel_phi"],2),
            round(p["mol_Ekin"],4), round(p["mol_Epot"],4),
            round(p["mol_Evib_cin"],4), round(p["mol_Evib_tot"],4), round(p["mol_Erot"],4),
            int(p["mol_jrot"]), out_flag
        ]

    rows_all = [
        row(
            "Start" if k == 0 else "Turn" if k == turn_idx else "End" if k == len(frames)-1 else "Frame",
            k, props[k]
        )
        for k in range(len(frames))
    ]
    rows_key = [rows_all[0], rows_all[turn_idx], rows_all[-1]]

    # --- Summary
    summary = [
        ["file", os.path.basename(INPUT_FILE)],
        ["molecule", f"{elemA}-{elemB}"],
        ["diatomic", f"{iA},{iB} ({sym[iA]}-{sym[iB]})"],
        ["detector_A", DETECTOR_A],
        ["graphite_zref_A", round(zref0,3)],
        ["outcome", "scattered(1)" if outcome == 1 else "stuck(0)"],
    ]

    if tabulate:
        print("\n== Summary ==")
        print(tabulate(summary, tablefmt="plain"))
        print("\n== Trajectory metrics (key frames) ==")
        print(tabulate(rows_key, headers=header, tablefmt="plain"))
    else:
        print(summary)
        print([header] + rows_key)

    # --- Write per-frame CSV
    base = os.path.splitext(os.path.basename(INPUT_FILE))[0]
    out_csv = os.path.join(OUT_DIR, f"{base}_metrics.csv")
    if os.path.exists(out_csv):
        os.remove(out_csv)
        print(f"Removed existing file: {out_csv}")

    np.savetxt(
        out_csv,
        np.array(rows_all, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(header),
        comments='',
        encoding='utf-8'
    )

    # --- Batch summary row
    summary_rows.append([
        base, f"{elemA}-{elemB}", f"{sym[iA]}-{sym[iB]}", DETECTOR_A, round(zref0,3),
        outcome,
        round(pf["d_mol_L3"],3), round(pf["mol_Ekin"],4), int(pf["mol_jrot"]),
        round(pf["d_NO1"],4), round(pf["mol_mCenter_vel"][2],5), round(pf["mol_vel_theta"],2),
        round(pf["mol_Evib_tot"],4)
    ])

# --- Batch summary file
if summary_rows:
    sum_csv = os.path.join(OUT_DIR, "batch_summary.csv")
    if os.path.exists(sum_csv):
        os.remove(sum_csv)
        print(f"Removed existing file: {sum_csv}")
    hdr = [
        "file","molecule","diatomic","detector_A","zref_A","outcome(1=scat,0=stick)",
        "final_COMheight_A","final_Ecm_eV","final_jrot","final_d(Å)",
        "final_Vcm_z(Å/fs)","final_Vcm_θ°","final_Evib_tot_eV"
    ]
    np.savetxt(
        sum_csv,
        np.array(summary_rows, dtype=object),
        fmt='%s',
        delimiter=',',
        header=','.join(hdr),
        comments='',
        encoding='utf-8'
    )
    print(f"\nWrote {len(summary_rows)} records to {sum_csv}")
# Out:
# Processing: vasprun-6.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-6.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.641
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.391          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         418     1.2448            2.536          90.43       181.88        0.00233        0.00332        0.00056           82.14         54.9      0.0278       0.2313          0.0008          0.2321      0.0002        1         0
# End         1727     1.2349            8.213         122          216.73        0.00257        0.00305        0.00252           57.71         49.84     0.0369       0.1785          0.0006          0.1791      0.0006        1         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-6_metrics.csv
#
# Processing: vasprun-19.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-19.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.015
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.409          90          180            0             0              0                  0             0        0            0.1442               0          0.1442      0             0         0
# Turn        1826     1.2489            2.977         146.28       304.72         0.0026       -0.00164        0.00017           86.84        327.76     0.0157       0.2548               0          0.2548      0.0067        6         0
# End         3999     1.2276            2.977         138.08       134.24         0.0037       -0.00111       -0.00408          136.58        343.22     0.0523       0.143                0          0.143       0.0639       19         0
# Removed existing file: results/Normal_110K_02eV_results/vasprun-19_metrics.csv
#
# Processing: vasprun-31.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-31.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.203
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.396          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         507     1.2416            2.52           89.78       181.45        0.00311       -0.00338       -0.0024           117.59        312.53     0.0445       0.2139          0.0007          0.2146      0.0001        0         0
# End         1852     1.2415            7.727         102.98         5.38        0.00367       -0.00376        0.00247           64.82        314.33     0.0559       0.2134          0.0019          0.2152      0.0047        5         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-31_metrics.csv
#
# Processing: vasprun-25.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-25.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.144
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.408          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         501     1.2541            2.496          87.61       180.34        0.00259       -0.0027        -0.00156          112.57        313.79     0.0273       0.2863          0               0.2863      0.0003        1         0
# End         3999     1.2518            6.089         153.04       218.3         0.00247       -0.00297        0.00105           74.8         309.8      0.0265       0.2723          0.0007          0.273       0.0561       18         0
# Removed existing file: results/Normal_110K_02eV_results/vasprun-25_metrics.csv
#
# Processing: vasprun-24.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-24.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.084
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.395          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn        3876     1.2361            2.583          98.22        55.72        0.00269       -0.00228       -0.00011           91.73        319.72     0.0206       0.1847          0.003           0.1877      0.0013        2         0
# End         3999     1.2486            3.319          81.72        48.01        0.00182       -0.00223        0.00715           21.9         309.22     0.0985       0.2533          0.0006          0.2539      0.0046        5         0
# Removed existing file: results/Normal_110K_02eV_results/vasprun-24_metrics.csv
#
# Processing: vasprun-30.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-30.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.2
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.4            90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         517     1.2411            2.491          90.61       181.29        0.00446        0.00062       -8e-05             91.01          7.93     0.0336       0.2111          0.0014          0.2125      0.0002        1         0
# End         1972     1.2388            7.507          19.53       223.74        0.00428       -0.00016        0.00212           63.68        357.85     0.0378       0.1986          0.0013          0.2         0.0018        3         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-30_metrics.csv
#
# Processing: vasprun-18.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-18.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.011
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.409          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         465     1.2387            2.544          89.39       180.41        0.00413        0.00043       -0.00324          127.98          5.96     0.0461       0.1979          0.0006          0.1985      0.0003        1         0
# End         3999     1.2527            3.057          96.86       325.01        0.00559       -0.00042        0.0021            69.51        355.74     0.0595       0.2776          0.0001          0.2776      0.0242       12         0
# Removed existing file: results/Normal_110K_02eV_results/vasprun-18_metrics.csv
#
# Processing: vasprun-7.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-7.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.681
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.363          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         415     1.2548            2.487          88.61       182.31        0.0031        -0.00198       -0.00168          114.49        327.43     0.0271       0.2905          0.0016          0.2921      0.001         2         0
# End         1206     1.2259            7.514         110.83       265.65        0.00274       -0.00182        0.0056            30.37        326.4      0.0699       0.1352          0.0015          0.1367      0.0024        3         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-7_metrics.csv
#
# Processing: vasprun-5.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-5.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.623
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.364          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         421     1.2418            2.454          89.76       179.4         0.00394       -0.00056        0.00042           83.96        351.9      0.0266       0.215           0.0007          0.2157      0.0002        1         0
# End         1078     1.2407            7.595          85.17       169.58        0.0039        -0.00034        0.00716           28.68        354.98     0.1103       0.2085          0               0.2085      0.0001        0         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-5_metrics.csv
#
# Processing: vasprun-26.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-26.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.171
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.39           90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         500     1.2448            2.493          89.04       180.17        0.0002        -0.00428       -0.00161          110.55        272.74     0.0348       0.2312          0.0009          0.2321      0.0001        1         0
# End         3999     1.2442            6.938          79.33       185.42       -0.00122       -0.00437        0.00249           61.18        254.4      0.0444       0.2283          0               0.2284      0.0104        7         0
# Removed existing file: results/Normal_110K_02eV_results/vasprun-26_metrics.csv
#
# Processing: vasprun-32.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-32.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.187
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.391          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         525     1.249             2.45           88.34       181.23        0.0044        -0.00221        0.00355           54.2         333.31     0.0611       0.2557          0.001           0.2566      0.0005        1         0
# End         1162     1.2343            7.549         123.86       170.73        0.00388       -0.00207        0.0079            29.11        331.91     0.1355       0.1751          0.0009          0.1761      0.0012        2         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-32_metrics.csv
#
# Processing: vasprun-33.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-33.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.185
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.392          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         501     1.2484            2.4            89.49       179.63        0.00179       -0.00428       -0.00539          139.29        292.72     0.084        0.2519          0.0001          0.252       0.0002        1         0
# End         1108     1.2412            7.539          86.18       169.29        0.00105       -0.00452        0.00896           27.41        283.08     0.1688       0.2117          0.002           0.2137      0.0001        0         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-33_metrics.csv
#
# Processing: vasprun-27.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-27.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.169
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.394          90          180           0              0              0                  0             0        0            0.1442          0               0.1442       0            0         0
# Turn        1800     1.2435            2.63          109.59         2.49        0.00332       -3e-05          0.00264           51.56        359.54     0.0298       0.224           0.0013          0.2253       0            0         0
# End         2518     1.2514            7.959         164.65       356.6         0.00308       -0.00069        0.0063            26.63        347.32     0.0823       0.2697          0.0036          0.2732       0.036       14         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-27_metrics.csv
#
# Processing: vasprun-4.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-4.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.621
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.365          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         410     1.2472            2.48           90.21       181.52       -0.00017        0.00476       -0.00169          109.58         92.05     0.0423       0.2451          0.0006          0.2457      0.0001        1         0
# End         1155     1.2307            7.584          38.23       237.23       -0.00029        0.00549        0.00609           42.1          93.05     0.1116       0.1577          0.0002          0.1578      0.0025        3         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-4_metrics.csv
#
# Processing: vasprun-37.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-37.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.164
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.407          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         510     1.2375            2.446          90.01       179.99        0.00187        0.00403       -0.0017           110.94         65.09     0.0375       0.1919          0.0044          0.1963      0.0002        1         0
# End         1095     1.2287            7.546         117.31       141.44        0.00235        0.00427        0.00912           28.12         61.23     0.1772       0.1482          0.0013          0.1496      0.0017        3         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-37_metrics.csv
#
# Processing: vasprun-36.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-36.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.17
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.402          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         517     1.2337            2.43           90.05       180.79        0.0015         0.00405        0.00058           82.38         69.66     0.0315       0.1722          0.0015          0.1737      0             0         0
# End         1110     1.2373            7.56          101.42       185.04        0.00166        0.00296        0.00892           20.81         60.75     0.1509       0.1907          0.0056          0.1963      0.0001        1         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-36_metrics.csv
#
# Processing: vasprun-1.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-1.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.572
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.383          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         421     1.2411            2.44           89.94       180.35        0.00308        0.00307        0.00047           83.8          44.93     0.0317       0.2109          0.0014          0.2123      0             0         0
# End         1029     1.2371            7.789         125.48       177.84        0.00349        0.00276        0.00798           29.13         38.36     0.1384       0.1894          0.0001          0.1895      0.0011        2         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-1_metrics.csv
#
# Processing: vasprun-3.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-3.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.581
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.387          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         408     1.2438            2.453          89.92       180.82        0.00401        0.00027       -0.00277          124.53          3.88     0.0395       0.2257          0.0008          0.2265      0.0001        0         0
# End         1040     1.2356            7.662          90.51       206.47        0.00427       -1e-05          0.0077            29.01        359.83     0.1287       0.1822          0.0014          0.1836      0.0004        1         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-3_metrics.csv
#
# Processing: vasprun-34.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-34.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.178
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.398          90          180           0              0              0                  0             0        0            0.1442          0               0.1442           0        0         0
# Turn         496     1.241             2.454          89.5        180.33        0.00285       -0.00315       -0.00556          142.63        312.16     0.081        0.2105          0.0006          0.2111           0        0         0
# End         1131     1.2411            7.587          91.96       176.84        0.00279       -0.00335        0.00847           27.24        309.78     0.1505       0.2108          0.0025          0.2132           0        0         1
# Removed existing file: results/Normal_110K_02eV_results/vasprun-34_metrics.csv
#
# Processing: vasprun-20.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-20.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.028
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.413          90          180           0               0             0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         463     1.2471            2.542          90.37       184.57        0.00211        -0.0043       -0.00418          131.1         296.17     0.0671       0.2448          0.0066          0.2514      0.0002        1         0
# End         2751     1.2392            8.138         122.33       175.3         0.0011         -0.0044        0.00426           46.77        284.08     0.0642       0.2005          0.0064          0.207       0.0006        1         1
#
# Processing: vasprun-21.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-21.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.078
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.391          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         491     1.2331            2.53           87.92       179.17        0.00314       -0.00181        0.00047           82.61        330.01     0.0222       0.1692          0.0008          0.17        0.0009        2         0
# End         2874     1.2448            8.098         157.6        252.88        0.00257       -0.00239        0.00376           43.08        317.09     0.0439       0.2314          0.0001          0.2315      0.003         4         1
#
# Processing: vasprun-35.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-35.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.172
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.402          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         515     1.2344            2.45           88.77       180.13        0.00198       -0.00374        0.00019           87.45        297.93     0.0297       0.1756          0               0.1756      0.0001        1         0
# End         1117     1.2288            7.573          73.1        180.41        0.00155       -0.0036         0.00873           24.2         293.25     0.1518       0.1487          0.0007          0.1493      0.0003        1         1
#
# Processing: vasprun-91.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-91.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.035
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.389          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         477     1.2491            2.54           89.24       181.19        0.00409       -0.00132       -0.00293          124.32        342.06     0.0449       0.2561          0.0011          0.2573      0.0002        1         0
# End         3999     1.2412            3.462          34.66        66.59        0.0042        -0.00136       -0.00171          111.2         342.03     0.0372       0.2113          0.0025          0.2138      0.0889       22         0
#
# Processing: vasprun-85.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-85.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.835
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.381          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         434     1.248             2.502          91.39       180.36        0.00073        0.00409       -0.00206          116.35         79.91     0.0356       0.25            0.0008          0.2508      0             0         0
# End         2782     1.2519            8.018         150.94       206.1         0.001          0.00477        0.00479           45.52         78.13     0.0775       0.2729          0               0.2729      0.0022        3         1
#
# Processing: vasprun-46.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-46.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.096
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.4            90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         501     1.2499            2.435          90.21       181.76        0.00037        0.00514       -0.00019           92.09         85.91     0.0441       0.261           0.0007          0.2616      0.0001        0         0
# End         1164     1.2371            7.691          75.41       191.43        0.00043        0.00564        0.00765           36.5          85.65     0.1501       0.1897          0.0051          0.1947      0.0003        1         1
#
# Processing: vasprun-53.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-53.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.945
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.401          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         483     1.2497            2.434          91.75       182.99        0.00441        0.00052        0.00061           82.14          6.75     0.0333       0.2597          0.0054          0.2651      0.001         2         0
# End         1043     1.2312            7.807          70.46       234.52        0.00472       -0.00011        0.00921           27.13        358.72     0.1775       0.1602          0.0048          0.1651      0.0022        3         1
#
# Processing: vasprun-84.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-84.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.824
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.388          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn        3840     1.2496            3.05           22.15       177.44        0.00213       -0.00059       -0.00198          131.79        344.66     0.0146       0.2591          0               0.2591      0.0079        6         0
# End         3999     1.2492            3.755          59.96       214.21        0.00291       -0.00033        0.00582           26.76        353.62     0.0704       0.2565          0.0002          0.2566      0.0293       13         0
#
# Processing: vasprun-86.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-86.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.027
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.376          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         481     1.2501            2.545          91.47       178.6         0.00193        0.00411       -0.00091          101.34         64.82     0.0355       0.2619          0.0001          0.2619      0.0004        1         0
# End         3999     1.2279            3.44          120.15       182.54        0.0019         0.00495       -0.00263          116.39         69.04     0.0582       0.1441          0               0.1442      0.025        12         0
#
# Processing: vasprun-92.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-92.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.036
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.39           90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         479     1.2496            2.547          91.15       180.39        0.00363       -0.00137       -0.0025           122.76        339.31     0.0353       0.259           0.0001          0.2591      0.0001        0         0
# End         3999     1.2334            5.596         172.32       107.01        0.00341       -0.00108        0.00099           74.46        342.49     0.0229       0.1707          0.0091          0.1798      0.0079        6         0
#
# Processing: vasprun-79.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-79.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.745
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.382          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         430     1.2427            2.53           90.28       181.75        0.00365       -0.00135       -0.00032           94.67        339.66     0.0254       0.2198          0.0018          0.2216      0.0001        0         0
# End         1906     1.2446            8.01           87.15       159.63        0.00395       -0.00133        0.00204           63.95        341.37     0.0357       0.2304          0.005           0.2354      0             0         1
#
# Processing: vasprun-51.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-51.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.03
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.383          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         494     1.2398            2.319          89.36       181.05        0.0037         8e-05          0.00032           85.1           1.27     0.0229       0.2037          0.0063          0.21        0.0003        1         0
# End         1003     1.2293            7.809          78.86       202.86        0.00318        0.00076        0.01053           17.25         13.5      0.2018       0.151           0.0012          0.1521      0.0005        1         1
#
# Processing: vasprun-50.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-50.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.033
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.382          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         494     1.2374            2.343          89.89       181.44        0.00116        0.00479        0.00056           83.56         76.45     0.0408       0.1912          0.0062          0.1974      0.0001        0         0
# End         1082     1.2474            7.76           92.3        170.46        0.00121        0.00483        0.0088            29.53         75.9      0.1695       0.2464          0.0024          0.2487      0             0         1
#
# Processing: vasprun-44.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-44.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.101
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.4            90          180           0              0              0                   0            0         0           0.1442          0               0.1442      0             0         0
# Turn         502     1.2469            2.43           88.85       182.85        0.00223       -0.00287        0.00025            86          307.84      0.022       0.2433          0.0003          0.2436      0.0012        2         0
# End         1082     1.2442            7.682         104.34       254.25        0.00213       -0.00272        0.0091             20.8        308.12      0.157       0.2281          0               0.2281      0.0031        4         1
#
# Processing: vasprun-78.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-78.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.745
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.378          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         423     1.2341            2.463          90.47       180.26        0.00235       -0.00416       -0.00195          112.2         299.53     0.0441       0.1744          0.0002          0.1746      0.0001        0         0
# End         1612     1.2458            8.015          60.74       211.62        0.00224       -0.00361        0.00291           55.61        301.75     0.044        0.2371          0.0063          0.2434      0.0006        1         1
#
# Processing: vasprun-83.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-83.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.82
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.389          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         432     1.247             2.517          90.24       181.94        0.00251        0.00227       -0.0018           117.97         42.2      0.0244       0.244           0.0011          0.2451      0.0001        0         0
# End         2741     1.2531            8.028          38.58        14.89        0.00134        0.00037        0.00574           13.65         15.55     0.0579       0.2801          0.0027          0.2828      0.0034        4         1
#
# Processing: vasprun-97.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-97.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.052
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# ...
#
# Processing: vasprun-11.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-11.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.69
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.363          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         417     1.2413            2.513          89.14       183.64        0.00124       -0.00301       -0.00015           92.67        292.35     0.0176       0.2121          0.0014          0.2134      0.0005        1         0
# End         1487     1.2267            7.588          86.47       281.17        0.00078       -0.00307        0.00345           42.57        284.3      0.0363       0.1388          0.0029          0.1417      0.0012        2         1
#
# Processing: vasprun-39.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-39.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.153
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.415          90          180            0             0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         514     1.2262            2.449          89.78       180.68         0.0002        0.0044        -0.00011           91.49         87.44     0.0321       0.1365          0.0007          0.1372      0.0002        1         0
# End         1092     1.2234            7.588          90.78       139.67         0.0003        0.00504        0.00921           28.73         86.58     0.1831       0.1239          0               0.1239      0.001         2         1
#
# Processing: vasprun-13.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-13.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.867
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.377          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         437     1.2471            2.496          91.35       179.93        0.00247        0.00358       -0.00356          129.28         55.41     0.0523       0.2446          0.0011          0.2457      0.0013        2         0
# End         2693     1.2467            8.162         108.91       161.79        0.00198        0.00356        0.00595           34.39         60.97     0.0863       0.2425          0.0082          0.2506      0.0316       13         1
#
# Processing: vasprun-12.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-12.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.866
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.373          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         439     1.2448            2.454          90.09       180.65        0.00035       -0.00397       -0.00325          129.2         275.09     0.0438       0.2316          0.0032          0.2347      0             0         0
# End         3999     1.2223            5.328          66.35       314.69        0.00087       -0.00248       -0.00082          107.38        289.46     0.0126       0.1192          0               0.1192      0.0067        6         0
#
# Processing: vasprun-9.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-9.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.687
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.362          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         414     1.2525            2.539          91.06       182.92        0.00369        0.0014        -0.00113          105.92         20.84     0.028        0.2762          0.0016          0.2778      0.0004        1         0
# End         1813     1.2547            8.117          36.33         0.09        0.00391        0.00127        0.0022            61.85         18.02     0.0361       0.2899          0.0013          0.2912      0.0027        4         1
#
# Processing: vasprun-16.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-16.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.982
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.38           90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         454     1.2525            2.521          88.9        181.34        0.00054        0.00395       -0.00377          133.36         82.16     0.05         0.2766          0.0031          0.2798      0.0002        1         0
# End         2801     1.2217            8.327          74.51       339.76       -0.00082        0.00294        0.00486           32.13        105.51     0.0545       0.1166          0.0004          0.117       0.005         5         1
#
# Processing: vasprun-17.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-17.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.99
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.376          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         461     1.2457            2.541          89.53       179.86        0.00382       -0.00301       -0.00269          118.98        321.78     0.0511       0.2364          0.0038          0.2402      0.0008        2         0
# End         3999     1.2414            3.806         139.87       171.51        0.00388       -0.00456        0.00096           80.91        310.44     0.061        0.2126          0.004           0.2165      0.0033        4         0
#
# Processing: vasprun-8.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-8.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.684
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.362          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         415     1.2528            2.492          88.11       179.8         0.00083       -0.00432       -0.00179          112.2         280.86     0.0374       0.2784          0.0031          0.2816      0.0009        2         0
# End         1384     1.2293            7.483          85.53       122.17       -4e-05         -0.00481        0.00404           49.93        269.49     0.0654       0.1507          0.0045          0.1552      0.0007        2         1
#
# Processing: vasprun-15.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-15.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.877
# outcome          stuck(0)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.376          90          180           0              0              0                  0             0        0            0.1442          0               0.1442       0            0         0
# Turn        3999     1.2377            2.97          140.98        48.36        0.00267       -0.00053       -0.00366          143.37        348.82     0.0346       0.1929          0.0013          0.1942       0.025       12         0
# Turn        3999     1.2377            2.97          140.98        48.36        0.00267       -0.00053       -0.00366          143.37        348.82     0.0346       0.1929          0.0013          0.1942       0.025       12         0
#
# Processing: vasprun-29.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-29.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.2
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.4            90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         514     1.235             2.509          89.29       178.99        0.00237        0.00289       -0.00215          119.92         50.6      0.0309       0.1789          0.0016          0.1805      0.0006        1         0
# End         1291     1.2274            7.617          76.14        90.52        0.00217        0.00309        0.00609           31.84         54.93     0.0852       0.1418          0.0019          0.1437      0.0029        4         1
#
# Processing: vasprun-28.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-28.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  7.202
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.397          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         512     1.2299            2.5            89.35       182.87        0.00305       -0.00255       -0.00128          107.79        320.04     0.0289       0.154           0               0.154       0.0002        1         0
# End         1547     1.2505            8.198         117.67       224.34        0.00291       -0.00271        0.00384           45.96        317.11     0.0507       0.2642          0.0006          0.2648      0.0009        2         1
#
# Processing: vasprun-14.xml
#
# Using diatomic atoms 0,1 (O-O)
# Computing finite-difference velocities for missing frames.
# CAREFUL - using finite-difference velocities!
#
# == Summary ==
# file             vasprun-14.xml
# molecule         O-O
# diatomic         0,1 (O-O)
# detector_A       7.0
# graphite_zref_A  6.873
# outcome          scattered(1)
#
# == Trajectory metrics (key frames) ==
# state      t_idx    d_NO(Å)    COM_z-ztop(Å)    NO_theta(°)    NO_phi(°)    Vcm_x(Å/fs)    Vcm_y(Å/fs)    Vcm_z(Å/fs)    Vcm_theta(°)    Vcm_phi(°)    Ecm(eV)    E_pot(eV)    Evib_cin(eV)    Evib_tot(eV)    Erot(eV)    j_rot    output
# Start          0     1.2279            7.376          90          180           0              0              0                  0             0        0            0.1442          0               0.1442      0             0         0
# Turn         436     1.2483            2.482          89.83       179.6         0.00011       -0.00359       -0.00467          142.44        271.78     0.0575       0.2516          0               0.2516      0.0002        1         0
# End         2694     1.2445            7.956         150.19       333.53       -0.00036       -0.00271        0.00098           70.26        262.48     0.014        0.2296          0.0002          0.2298      0.0028        4         1
#
# Wrote 80 records to results/Normal_110K_02eV_results/batch_summary.csv
